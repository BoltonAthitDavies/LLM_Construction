# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 0. Graph function

# %% [markdown]
# - ฟังก์ชันที่จำเป็นสำหับการพล็อตกราฟ เช่า Histogram, Bar plot, Box plot เป็นต้น

# %%
def plot_boxplots(df, cols=None, ncols=2, showfliers=True, notch=False, whis=1.5,
                  horizontal=False, order_by_median=False):
    """
    Plot box plots for numeric columns.

    Args:
        df (pd.DataFrame): your data
        cols (list[str] | None): which numeric columns to plot;
                                 if None, auto-detect numeric columns
        ncols (int): number of subplots per row
        showfliers (bool): show outlier points
        notch (bool): draw a notch to display the median CI
        whis (float | tuple): IQR whisker length or (lo, hi) percentiles (e.g., (5,95))
        horizontal (bool): if True, draw horizontal boxes
        order_by_median (bool): if True, sort columns by median before plotting
    """
    import numpy as np
    import matplotlib.pyplot as plt
    import seaborn as sns

    # Pick numeric columns if not provided
    if cols is None:
        cols = df.select_dtypes(include=[np.number]).columns.tolist()
    if not cols:
        raise ValueError("No numeric columns to plot.")

    # Optionally sort by column medians (ascending)
    if order_by_median:
        med = df[cols].median(numeric_only=True).sort_values()
        cols = med.index.tolist()

    nrows = -(-len(cols) // ncols)  # ceiling division
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(6*ncols, 4*nrows))
    axes = np.atleast_1d(axes).ravel()

    for i, col in enumerate(cols):
        ax = axes[i]
        data = df[col].dropna()

        # seaborn handles nicer stats & fliers; orientation via x/y
        if horizontal:
            sns.boxplot(x=data, ax=ax, showfliers=showfliers, notch=notch, whis=whis)
            ax.set_xlabel(col)
            ax.set_ylabel("")
        else:
            sns.boxplot(y=data, ax=ax, showfliers=showfliers, notch=notch, whis=whis)
            ax.set_ylabel(col)
            ax.set_xlabel("")

        ax.set_title(f"{col} box plot")
        ax.grid(axis="y" if not horizontal else "x", linestyle="--", alpha=0.5)
        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)

    # Remove any unused axes
    for j in range(len(cols), len(axes)):
        fig.delaxes(axes[j])

    plt.tight_layout()
    plt.show()

# %%
def plot_numeric_distributions(
    df,
    cols=None,
    bins=30,
    ncols=2,
    kde=True,
    show_stats=True,          # <- new: show mean/var/std box
    ddof=1,                   # <- new: variance/SD degrees of freedom (1 = sample, 0 = population)
    stats_loc=(0.98, 0.98),   # <- new: box location in axes coords (x,y), 0..1
):
    """
    Plot histogram distributions for numeric columns, with robust column handling
    and per-plot statistics overlays (mean line, mean/variance/std box).

    Parameters
    ----------
    df : pandas.DataFrame
    cols : list[str] | None
        Which columns to plot; default = all numeric columns in df.
    bins : int
        Histogram bins.
    ncols : int
        Number of subplot columns.
    kde : bool
        Whether to draw a KDE curve (seaborn).
    show_stats : bool
        If True, annotate each chart with mean/variance/std and draw a mean line.
    ddof : int
        Delta degrees of freedom for var/std: 1 = sample, 0 = population.
    stats_loc : tuple[float, float]
        (x, y) in axes coordinates for the stats box (e.g., (0.02, 0.98) for top-left).
    """
    import numpy as np
    import pandas as pd
    import matplotlib.pyplot as plt
    import seaborn as sns
    from pandas.api.types import is_numeric_dtype
    from scipy import stats

    # 1) Decide candidate columns
    if cols is None:
        cols = df.select_dtypes(include=[np.number]).columns.tolist()
    else:
        cols = list(cols)

    # 2) Split into present vs. missing
    present = [c for c in cols if c in df.columns]
    missing = sorted(set(cols) - set(present))

    # 3) Keep only numeric among present
    non_numeric = [c for c in present if not is_numeric_dtype(df[c])]
    numeric_present = [c for c in present if is_numeric_dtype(df[c])]

    if missing:
        print(f"[plot_numeric_distributions] Skipped missing columns: {missing}")
    if non_numeric:
        print(f"[plot_numeric_distributions] Skipped non-numeric columns: {non_numeric}")

    if not numeric_present:
        raise ValueError("No valid numeric columns to plot after filtering.")

    # 5) Make grid
    ncols = max(1, int(ncols))
    n = len(numeric_present)
    nrows = -(-n // ncols)

    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(6*ncols, 4*nrows))
    axes = np.atleast_1d(axes).ravel()

    # 6) Plot each numeric column
    for i, col in enumerate(numeric_present):
        ax = axes[i]
        data = df[col].dropna().astype(float)

        ax.hist(data, bins=bins, alpha=0.7, color='skyblue',
                edgecolor='black', density=True)

        if kde:
            kde_x = np.linspace(data.min(), data.max(), 200)
            kde_estimator = stats.gaussian_kde(data)
            ax.plot(kde_x, kde_estimator(kde_x), 'r-', linewidth=2, label='KDE')

            mu, sigma = data.mean(), data.std()
            normal_curve = stats.norm.pdf(kde_x, mu, sigma)
            ax.plot(kde_x, normal_curve, 'g--', linewidth=2,
                    label='Normal Distribution')

        # ===========================
        # ADD MEAN & MEDIAN LINES
        # ===========================
        mean = float(data.mean())
        median = float(data.median())

        ax.axvline(x=mean, color='red', linestyle='--',
                   linewidth=2, alpha=0.7, label="Mean")
        ax.axvline(x=median, color='orange', linestyle='--',
                   linewidth=2, alpha=0.7, label="Median")

        ax.set_title(f"{col} distribution", fontweight='bold')
        ax.set_xlabel(col, fontweight='bold')
        ax.set_ylabel("Density", fontweight='bold')
        ax.grid(alpha=0.3)
        ax.legend(loc='upper right')

        if show_stats and len(data):
            var = float(data.var(ddof=ddof))
            std = float(data.std(ddof=ddof))
            skewness = float(stats.skew(data))

            stats_text = (
                f"Mean:   {mean:.3f}\n"
                f"Median: {median:.3f}\n"
                f"Std:    {std:.3f}\n"
                f"Skew:   {skewness:.3f}"
            )

            ax.text(
                0.05, 0.95, stats_text,
                transform=ax.transAxes,
                ha="left", va="top",
                fontsize=9,
                bbox=dict(boxstyle='round',
                          facecolor='wheat', alpha=0.5)
            )

    for j in range(len(numeric_present), len(axes)):
        fig.delaxes(axes[j])

    plt.tight_layout()
    plt.show()

# %%
# categorical bar chart

def plot_bar_charts_grid(df, cols, top_n=None, normalize=False, ncols=3):
    """
    Grid of bar charts for categorical columns.

    Args:
        df (pd.DataFrame): your data
        cols (list[str]): columns to plot
        top_n (int|None): show only top N most frequent categories
        normalize (bool): if True, show percentages instead of raw counts
        ncols (int): number of charts per row
    """
    import matplotlib.pyplot as plt
    from matplotlib.ticker import FuncFormatter

    def k_format(x, _):
        if x >= 1_000_000: return f"{int(x/1_000_000)}M"
        if x >= 1_000:     return f"{int(x/1_000)}k"
        return str(int(x))

    nrows = -(-len(cols) // ncols)  # ceiling division
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(4*ncols, 3*nrows))
    axes = axes.flatten()

    for i, col in enumerate(cols):
        ax = axes[i]
        counts = (
            df[col]
            .astype("category")
            .cat.add_categories(["<NaN>"])
            .fillna("<NaN>")
            .value_counts(dropna=False)
            .sort_values(ascending=False)
        )
        if top_n:
            counts = counts.iloc[:top_n]

        vals = (counts / counts.sum() * 100.0).round(1) if normalize else counts

        vals.plot(kind="bar", ax=ax, color="skyblue", edgecolor="black")

        ax.set_title(f"{col} distribution")
        ax.set_xlabel("")
        ax.set_ylabel("Percent" if normalize else "Count")
        ax.grid(axis="y", linestyle="--", alpha=0.5)
        ax.tick_params(axis="x", labelrotation=30)
        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)

        if not normalize:
            ax.yaxis.set_major_formatter(FuncFormatter(k_format))

        # annotate bars
        for rect, v in zip(ax.patches, vals.values):
            h = rect.get_height()
            label = f"{v:.1f}%" if normalize else f"{int(h)}"
            ax.annotate(label,
                        (rect.get_x() + rect.get_width()/2, h),
                        ha="center", va="bottom",
                        fontsize=0.5, xytext=(0, 3), textcoords="offset points")

    # remove unused subplots if cols not multiple of ncols
    for j in range(len(cols), len(axes)):
        fig.delaxes(axes[j])

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Preparing

# %%
root_path = os.getcwd().replace('script', '')
q_example = pd.read_csv(f'{root_path}\\table\\Q_Example.csv')
q_example
# Out:
#                                                 คำถาม  \
# 0   ระยะหุ้มคอนกรีตด้านล่าง และด้านข้างเท่าเท่าไหร...
# 1   Tolerance ของระยะหุ้มคอนกรีต ในงาน Precast อุโ...
# 2                          Concrete ใช้ Mix Code อะไร
# 3                           ค่าการยุบตัว Slump เท่าใด
# 4                Defect Void มีขนาดเท่าไหร่ ถึงจะซ่อม
# 5   วัสดุซ่อม ที่ใช้ซ่อม Defect แต่ละอย่าง ใช้อะไร...
# 6                      คอนกรีตควรเทให้หมดภายในกี่นาที
# 7                  น้ำมันทาแบบที่ Appove มียี่ห้ออะไร
# 8            น้ำยาบ่มคอนกรีต ที่ Appove ใช้ยี่ห้ออะไร
# 9     เหล็กเส้นรูปพรรณที่ใช้ในโครงสร้าง ใช้ SD เท่าใด
# 10                ระยะความยาวของแบบหล่อต้องเป็นเท่าใด
# 11              ระยะความกว้างของแบบหล่อต้องเป็นเท่าใด
# 12                 Tolerance ของแบบหล่อกว้างยาวเท่าใด
# 13  กำลังอัดของคอนกรีตเท่าไหร่ จึงสามารถยกชิ้นงานอ...
# 14                           น้ำมันทาแบบใช้ยี่ห้ออะไร
# 15  ค่าการยอมรับ Tolerance ตำแหน่งของอุปกรณ์ฝังมีค...
# 16              เหล็กที่อนุมัติจากโครงการมียี่ห้ออะไร
# 17           แบบที่ใช้ในโครงการ มี revise ใหม่หรือไม่
# 18  การประกอบ Assembly งานอุโมงค์ มีข้อกำหนดทดสอบ ...
# 19             แผนงานการผลิตแต่ละเดือน ต้องผลิตเท่าได
# 20                       แผนการขนส่งวันนี้ มีอะไรบ้าง
#
#                        หมวดหมู่            ผู้รับผิดชอบต้องตอบ
# 0            Reinforcement work  Quality Control (QC) Engineer
# 1            Reinforcement work  Quality Control (QC) Engineer
# 2              Pouring Concrete            Production Engineer
# 3              Pouring Concrete            Production Engineer
# 4                   Repair Work  Quality Control (QC) Engineer
# 5                   Repair Work            Production Engineer
# 6              Pouring Concrete            Production Engineer
# 7                      Material  Quality Control (QC) Engineer
# 8                      Material  Quality Control (QC) Engineer
# 9            Reinforcement work  Quality Control (QC) Engineer
# 10        Mold Preparation work            Production Engineer
# 11        Mold Preparation work            Production Engineer
# 12        Mold Preparation work  Quality Control (QC) Engineer
# 13             Pouring Concrete            Production Engineer
# 14                     Material            Production Engineer
# 15        Mold Preparation work  Quality Control (QC) Engineer
# 16                     Material  Quality Control (QC) Engineer
# 17        Mold Preparation work            Production Engineer
# 18                    Test work  Quality Control (QC) Engineer
# 19            Construction plan            Production Engineer
# 20  Transportation for Erection            Production Engineer

# %%
qa_example = pd.read_csv(f'{root_path}\\table\\QA_Example.csv')
qa_example = qa_example.drop(columns=['ชื่อผู้ประเมิน : ', 'ชื่อผู้ประเมิน : .1', 'ชื่อผู้ประเมิน : .2', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8'])
qa_example[1:6]
# Out:
#                                              Column1  \
# 1  ระยะหุ้มคอนกรีตด้านล่าง และด้านข้างเท่าเท่าไหร...
# 2  Tolerance ของระยะหุ้มคอนกรีต ในงาน Precast อุโ...
# 3                         Concrete ใช้ Mix Code อะไร
# 4    เกณฑ์การยอมรับ Tolerance ของ Segment มีอะไรบ้าง
# 5  การประกอบ Assembly งานอุโมงค์ มีข้อกำหนดทดสอบ ...
#
#                                              Column2  \
# 1  ระยะหุ้มคอนกรีต (Covering) ในงาน Precast อุโมง...
# 2  ตามข้อมูลที่ให้ไว้บน page_31 และ page_43 ในส่ว...
# 3  ข้อมูลเกี่ยวกับ Mix Code ของคอนกรีตไม่ได้ระบุไ...
# 4  เกณฑ์การยอมรับ Tolerance ของ Segment มีดังนี้\...
# 5  ข้อกำหนดทดสอบสำหรับการประกอบ Assembly งานอุโมง...
#
#                          Column3
# 1                        หน้า 31
# 2  ข้อความนี้มาจากหน้า 31 และ 43
# 3                        หน้า 31
# 4                             43
# 5         ข้อความนี้มาจากหน้า 53

# %%
print(f"Question : {qa_example['Column1'][0]}\n++++++++++++++++++++++\nAnswer : {qa_example['Column2'][4]}\n++++++++++++++++++++++\nPage : {qa_example['Column3'][4]}\n")
# print(f"Answer : {qa_example['Column2'][4]}\n")
# print(f"Page : {qa_example['Column3'][4]}\n")
# Out:
# Question : question
# ++++++++++++++++++++++
# Answer : เกณฑ์การยอมรับ Tolerance ของ Segment มีดังนี้
#
# 1. รัศมีภายนอก -0/+4 มม.
# 2. ระยะตามแนวเส้นรอบวง +2 มม.
# 3. ระยะตามแนวทแยงของหน้าตัดฝั่งซ้าย +1 มม.
# 4. ระยะตามแนวทแยงของหน้าตัดฝั่งขวา +2 มม.
#
# นอกจากนี้ยังมีการตรวจสอบ Ring โดยมีเกณฑ์การยอมรับ Tolerance ดังนี้
# 1. รัศมีภายนอก +5 มม.
# 2. ความกว้าง +2 มม.
# ++++++++++++++++++++++
# Page : 43

# %%
from typing import Any, Dict
from venv import logger
import json
import asyncio
import vertexai
from vertexai.generative_models import GenerativeModel
# qa generation from docs using gemini
from google import genai
from google.genai import types
# genai.init(api_key="YOUR_API_KEY")
client = genai.Client(api_key='AIzaSyAmM8ChHo9VR-th73uwdgyORRpGj-JzFZ0')
def generate_qa_from_docs(docs: str, qa_example: Dict[str, Any]):
    prompt = f"""
                You are an expert civil engineering assistant specialized in tunnel construction
                and precast segment technical manuals.

                Your task is to generate 40 Question–Answer pairs strictly based on the provided document.

                IMPORTANT RULES:
                1. Use ONLY information explicitly stated in the document.
                2. Do NOT use external knowledge, assumptions, or general engineering practices.
                3. The Question must reflect a realistic engineering or site inspection inquiry
                (e.g., tolerance limits, acceptance criteria, repair conditions).
                4. The Answer must be:
                - Technically accurate
                - Clearly structured (use numbered lists if appropriate)
                5. You MUST include the page number where the answer is derived from.
                6. If the information cannot be found clearly in the document,
                do NOT generate a Question–Answer pair and tell user that there isn't enough information.

                FORMAT REQUIREMENTS (STRICT)(add <split> between sections):
                Question : <question text>
                <split>

                Answer : <answer text>
                <split>

                Page : <page number>
                <split>

                LANGUAGE:
                - Use the same language as the document (Thai or English).
                - Use technical terminology consistent with the document.

                Do not add explanations, commentary, or additional text outside the required format.

                Document:{docs}

                Example format I want you to follow:
                Question: เกณฑ์การยอมรับ Tolerance ของ Segment มีอะไรบ้าง
                <split>
                Answer: เกณฑ์การยอมรับ Tolerance ของ Segment มีดังนี้:
                    1. ความคลาดเคลื่อนของความกว้าง (Width): ± 3 มม.
                    2. ความคลาดเคลื่อนของความสูง (Height): ± 3 มม.
                    3. ความคลาดเคลื่อนของความหนา (Thickness): ± 2 มม.
                    4. ความคลาดเคลื่อนของมุม (Angle): ± 0.5 องศา
                นอกจากนี้ยังมีการตรวจสอบ Ring โดยมีเกณฑ์การยอมรับ Tolerance ดังนี้
                    1. รัศมีภายนอก +5 มม.
                    2. ความกว้าง +2 มม.
                <split>
                Page: 
                43
                <split>

                Output format (strict):
                Question: <generated question> 
                Answer: <generated answer>
                Page: <page number from the document>
                """
    # print("Generated Prompt:", prompt)
    # gemini-3-pro-preview
    # gemini-2.5
    response = client.models.generate_content(
        model='gemini-3-pro-preview', contents=prompt, 
    )

    # print(prompt)
    return response.text.strip()
    # response = genai.generate_content(
    #     model="gemini-2.5-flash",
    #     prompt=prompt,
    #     max_output_tokens=500,
    #     temperature=0.7,
    #     top_p=0.9,
    #     stop_sequences=["\n"]
    # )
    # return response.text.strip()

# %%
docs = pd.read_csv(f'{root_path}\\table\\Method_Precast_For_Repairing_Tunnel_Segment.csv')
docs.head()
# Out:
#                                       doc name  \
# 0  Method_Precast_For_Repairing_Tunnet_Segment
# 1  Method_Precast_For_Repairing_Tunnet_Segment
# 2  Method_Precast_For_Repairing_Tunnet_Segment
# 3  Method_Precast_For_Repairing_Tunnet_Segment
# 4  Method_Precast_For_Repairing_Tunnet_Segment
#
#                                              content  page  \
# 0  10_Preventative_Measures_And_Revise_Environmen...   134
# 1  10_Preventative_Measures_And_Revise_Environmen...   135
# 2  10_Preventative_Measures_And_Revise_Environmen...   136
# 3  10_Preventative_Measures_And_Revise_Environmen...   137
# 4  10_Preventative_Measures_And_Revise_Environmen...   138
#
#                                                 text  \
# 0  [\n[\n[\nSTECOR\nบริษัท ซิโน-ไทย เอ็นจีเนียริ่...
# 1  STECON\nบริษัท ซิโน-ไทย เอ็นจีเนียริ่ง แอนด์ ค...
# 2  STECON\nบริษัท ซิโน-ไทย เอ็นจีเนียริ่ง แอนด์ ค...
# 3  บริษัท ซิโน-ไทย เอ็นจีเนียริ่ง แอนด์ คอนสตรัคช...
# 4  STECON\nบริษัท ซิโน-ไทย เอ็นจิเนียริ่ง แอนด์ ค...
#
#                                               tokens  tokens_count  \
# 0  ['[', '[', '[', 'STECOR', 'บริษัท', ' ', 'ซิ',...            70
# 1  ['STECON', 'บริษัท', ' ', 'ซิ', 'โน', '-', 'ไท...           388
# 2  ['STECON', 'บริษัท', ' ', 'ซิ', 'โน', '-', 'ไท...           374
# 3  ['บริษัท', ' ', 'ซิ', 'โน', '-', 'ไทย', ' ', '...           323
# 4  ['STECON', 'บริษัท', ' ', 'ซิ', 'โน', '-', 'ไท...           328
#
#                                             pos_tags  \
# 0  [('[', 'NCMN'), ('[', 'NCMN'), ('[', 'NCMN'), ...
# 1  [('STECON', 'NCMN'), ('บริษัท', 'NCMN'), (' ',...
# 2  [('STECON', 'NCMN'), ('บริษัท', 'NCMN'), (' ',...
# 3  [('บริษัท', 'NCMN'), (' ', 'PUNC'), ('ซิ', 'NP...
# 4  [('STECON', 'NCMN'), ('บริษัท', 'NCMN'), (' ',...
#
#                                    translated_tokens  th_token_count  \
# 0  [('[', 'th'), ('[', 'th'), ('[', 'th'), ('STEC...              45
# 1  [('STECON', 'eng'), ('บริษัท', 'th'), (' ', 't...             331
# 2  [('STECON', 'eng'), ('บริษัท', 'th'), (' ', 't...             334
# 3  [('บริษัท', 'th'), (' ', 'th'), ('ซิ', 'th'), ...             270
# 4  [('STECON', 'eng'), ('บริษัท', 'th'), (' ', 't...             288
#
#    en_token_count                                   embedded_vectors
# 0              25  [[-0.04175 -0.00967  0.0136  ...  0.02718 -0.0...
# 1              57  [[-0.01999    0.003365   0.01293   ... -0.0037...
# 2              40  [[-0.02942  -0.001525  0.003607 ...  0.001076 ...
# 3              53  [[-0.0409    0.005707  0.00486  ...  0.003038 ...
# 4              40  [[-0.02533  -0.004368 -0.000689 ... -0.002272 ...

# %% [markdown]
# # 1_Guildline_For_Repair

# %%
context = ""
for i in range(len(docs[docs['content'] == '1_Guildline_For_Repair'])):
    context += f"Page {docs[docs['content'] == '1_Guildline_For_Repair']['page'].iloc[i]}:\n{docs[docs['content'] == '1_Guildline_For_Repair']['text'].iloc[i]}\n\n"
    # print(docs[docs['content'] == '1_Guildline_For_Repair']['page'].iloc[i])
# print(context)

# %%
qa_result = generate_qa_from_docs(context, qa_example.iloc[0])

# %%
qa_result
# Out:
# 'Question: เอกสารฉบับนี้จัดทำขึ้นเพื่อวัตถุประสงค์อะไร\n<split>\nAnswer: เอกสารฉบับนี้จัดทำขึ้นเพื่อเป็นแนวทาง (Guideline) สำหรับการซ่อมผิวคอนกรีตของชิ้นส่วนผนังอุโมงค์ สำหรับโครงการก่อสร้างอุโมงค์ระบายน้ำจากบึงหนองบอนลงสู่แม่น้ำเจ้าพระยา\n<split>\nPage: 2\n<split>\n\nQuestion: ข้อบกพร่องของชิ้นส่วนอุโมงค์ที่สามารถซ่อมแซมได้ตามเอกสารนี้ ต้องมีลักษณะอย่างไร\n<split>\nAnswer: ความเสียหายหรือข้อบกพร่องต้องไม่มีผลกระทบต่อโครงสร้างหลักของชิ้นส่วนผนังอุโมงค์ตามที่ออกแบบไว้\n<split>\nPage: 2\n<split>\n\nQuestion: เกณฑ์ความเสียหายจากการผลิตที่ยอมรับได้ โดยไม่ต้องทบทวนกระบวนการผลิตคือเท่าใด\n<split>\nAnswer: ความเสียหายจากการผลิตต้องไม่เกิน 5% ของจำนวน Rings ที่ผลิตได้\n<split>\nPage: 2\n<split>\n\nQuestion: เกณฑ์ความเสียหายจากการขนส่งและการขนย้ายที่ยอมรับได้ คือเท่าใด\n<split>\nAnswer: ความเสียหายจากการขนส่งและการขนย้ายต้องไม่เกิน 2% ของจำนวน Rings ของการขนส่ง\n<split>\nPage: 2\n<split>\n\nQuestion: ความเสียหายที่เกิดขึ้นกับชิ้นงานแบ่งออกเป็น 4 ลักษณะ อะไรบ้าง\n<split>\nAnswer: ความเสียหายแบ่งเป็น:\n1. รอยร้าว (Crack)\n2. แตกบิ่นที่ขอบ (Spalling Edge)\n3. แตกบิ่นบริเวณ Gasket (Spalling Recesses)\n4. รูฟองอากาศ (Voids or Blowholes)\n<split>\nPage: 2\n<split>\n\nQuestion: เกณฑ์การพิจารณา "ไม่ต้องซ่อมแซม" (No Repair) สำหรับรอยร้าวประเภท Hard Crack คืออะไร\n<split>\nAnswer: เมื่อรอยร้าวมีความกว้าง (A) น้อยกว่าหรือเท่ากับ 0.1 มม.\n<split>\nPage: 3\n<split>\n\nQuestion: เกณฑ์การพิจารณา "ไม่ต้องซ่อมแซม" (No Repair) สำหรับรอยร้าวประเภท Shrinkage Crack คืออะไร\n<split>\nAnswer: เมื่อรอยร้าวมีความกว้าง (B) น้อยกว่าหรือเท่ากับ 0.3 มม. และมีความลึกน้อยกว่า 15 มม.\n<split>\nPage: 3\n<split>\n\nQuestion: วิธีการซ่อมแซมรอยร้าวประเภท Hard Crack ที่มีความกว้างมากกว่า 0.1 มม. แต่น้อยกว่า 0.3 มม. คือวิธีใด\n<split>\nAnswer: ซ่อมแซมด้วย Cementitious Mortar (วิธีการอ้างอิง RP-TN-01)\n<split>\nPage: 3\n<split>\n\nQuestion: หากรอยร้าวมีความกว้างตั้งแต่ 0.3 มม. ถึง 0.5 มม. และมีความลึกมากกว่า 15 มม. ต้องซ่อมแซมด้วยวิธีใด\n<split>\nAnswer: ซ่อมแซมด้วย Epoxy Resin (วิธีการอ้างอิง RP-TN-02)\n<split>\nPage: 3\n<split>\n\nQuestion: เกณฑ์การปฏิเสธชิ้นงาน (Reject) สำหรับความเสียหายประเภท "รอยร้าว" (Crack) คืออะไร\n<split>\nAnswer: เมื่อรอยร้าวมีความกว้างมากกว่า 0.5 มม. หรือมีความลึกถึงชั้น Hydro swelling (Depth to hydro swelling)\n<split>\nPage: 3\n<split>\n\nQuestion: ลักษณะตำแหน่งการแตกบิ่นที่ขอบ (Spalling Edge) แบ่งออกเป็น 3 แบบ คืออะไรบ้าง\n<split>\nAnswer: 1. Sharp Edge\n2. Chamfered Edge\n3. At Corners\n<split>\nPage: 4\n<split>\n\nQuestion: เกณฑ์ขนาดความเสียหายของ Spalling Edge ที่ "ไม่ต้องซ่อมแซม" (No Repair) คือเท่าใด\n<split>\nAnswer: เมื่อขนาดความเสียหาย A, B และ C มีค่าน้อยกว่า 5 มม.\n<split>\nPage: 4\n<split>\n\nQuestion: ช่วงขนาดความเสียหายของ Spalling Edge ที่ต้องซ่อมแซมด้วย Cementitious Mortar (RP-TN-03) คือเท่าใด\n<split>\nAnswer:\n- ด้าน A: 5-50 มม.\n- ด้าน B: 5-50 มม.\n- ด้าน C: 5-70 มม.\n<split>\nPage: 4\n<split>\n\nQuestion: เกณฑ์การปฏิเสธชิ้นงาน (Reject) สำหรับ Spalling Edge ในกรณีที่วัดขนาดความเสียหาย คือเท่าใด\n<split>\nAnswer: เมื่อขนาดความเสียหาย A > 50 มม. หรือ B > 50 มม. หรือ C > 70 มม.\n<split>\nPage: 4\n<split>\n\nQuestion: นอกเหนือจากขนาดความเสียหาย หากเกิด Spalling Edge แล้วพบสิ่งใด จึงถือว่าต้องปฏิเสธชิ้นงาน (Reject) ทันที\n<split>\nAnswer: เมื่อเหล็กเสริมโผล่ (Rebar exposed)\n<split>\nPage: 4\n<split>\n\nQuestion: เกณฑ์ขนาดความเสียหายบริเวณร่อง Gasket (Spalling Recesses) ที่ "ไม่ต้องซ่อมแซม" คือเท่าใด\n<split>\nAnswer: เมื่อขนาดความเสียหาย A < 2 มม. และ B < 2 มม.\n<split>\nPage: 5\n<split>\n\nQuestion: วิธีการซ่อมแซมความเสียหายประเภท Spalling Recesses คือวิธีใด และอ้างอิง Method ใด\n<split>\nAnswer: ซ่อมแซมด้วย Cementitious Mortar ตามวิธีการอ้างอิง RP-TN-03\n<split>\nPage: 5\n<split>\n\nQuestion: ช่วงขนาดความเสียหายของ Spalling Recesses ที่สามารถซ่อมแซมได้คือเท่าใด\n<split>\nAnswer:\n- ด้าน A: 2-10 มม.\n- ด้าน B: 5-30 มม.\n- ด้าน C: 0-10 มม.\n<split>\nPage: 5\n<split>\n\nQuestion: เกณฑ์การปฏิเสธชิ้นงาน (Reject) สำหรับความเสียหายประเภท Spalling Recesses คือเท่าใด\n<split>\nAnswer: เมื่อขนาดความเสียหาย A > 10 มม. หรือ B > 30 มม. หรือ ...

# %%
print(qa_result.split('<split>'))
qa_result_list = []
for qa in qa_result.split('<split>'):
    if qa != '++++++++++++++++++++++' and qa != '':
        qa_result_list.append(qa)
print(qa_result_list)
print(len(qa_result_list))
# Out:
# ['Question: เอกสารฉบับนี้จัดทำขึ้นเพื่อวัตถุประสงค์อะไร\n', '\nAnswer: เอกสารฉบับนี้จัดทำขึ้นเพื่อเป็นแนวทาง (Guideline) สำหรับการซ่อมผิวคอนกรีตของชิ้นส่วนผนังอุโมงค์ สำหรับโครงการก่อสร้างอุโมงค์ระบายน้ำจากบึงหนองบอนลงสู่แม่น้ำเจ้าพระยา\n', '\nPage: 2\n', '\n\nQuestion: ข้อบกพร่องของชิ้นส่วนอุโมงค์ที่สามารถซ่อมแซมได้ตามเอกสารนี้ ต้องมีลักษณะอย่างไร\n', '\nAnswer: ความเสียหายหรือข้อบกพร่องต้องไม่มีผลกระทบต่อโครงสร้างหลักของชิ้นส่วนผนังอุโมงค์ตามที่ออกแบบไว้\n', '\nPage: 2\n', '\n\nQuestion: เกณฑ์ความเสียหายจากการผลิตที่ยอมรับได้ โดยไม่ต้องทบทวนกระบวนการผลิตคือเท่าใด\n', '\nAnswer: ความเสียหายจากการผลิตต้องไม่เกิน 5% ของจำนวน Rings ที่ผลิตได้\n', '\nPage: 2\n', '\n\nQuestion: เกณฑ์ความเสียหายจากการขนส่งและการขนย้ายที่ยอมรับได้ คือเท่าใด\n', '\nAnswer: ความเสียหายจากการขนส่งและการขนย้ายต้องไม่เกิน 2% ของจำนวน Rings ของการขนส่ง\n', '\nPage: 2\n', '\n\nQuestion: ความเสียหายที่เกิดขึ้นกับชิ้นงานแบ่งออกเป็น 4 ลักษณะ อะไรบ้าง\n', '\nAnswer: ความเสียหายแบ่งเป็น:\n1. รอยร้าว (Crack)\n2. แตกบิ่นที่ขอบ (Spalling Edge)\n3. แตกบิ่นบริเวณ Gasket (Spalling Recesses)\n4. รูฟองอากาศ (Voids or Blowholes)\n', '\nPage: 2\n', '\n\nQuestion: เกณฑ์การพิจารณา "ไม่ต้องซ่อมแซม" (No Repair) สำหรับรอยร้าวประเภท Hard Crack คืออะไร\n', '\nAnswer: เมื่อรอยร้าวมีความกว้าง (A) น้อยกว่าหรือเท่ากับ 0.1 มม.\n', '\nPage: 3\n', '\n\nQuestion: เกณฑ์การพิจารณา "ไม่ต้องซ่อมแซม" (No Repair) สำหรับรอยร้าวประเภท Shrinkage Crack คืออะไร\n', '\nAnswer: เมื่อรอยร้าวมีความกว้าง (B) น้อยกว่าหรือเท่ากับ 0.3 มม. และมีความลึกน้อยกว่า 15 มม.\n', '\nPage: 3\n', '\n\nQuestion: วิธีการซ่อมแซมรอยร้าวประเภท Hard Crack ที่มีความกว้างมากกว่า 0.1 มม. แต่น้อยกว่า 0.3 มม. คือวิธีใด\n', '\nAnswer: ซ่อมแซมด้วย Cementitious Mortar (วิธีการอ้างอิง RP-TN-01)\n', '\nPage: 3\n', '\n\nQuestion: หากรอยร้าวมีความกว้างตั้งแต่ 0.3 มม. ถึง 0.5 มม. และมีความลึกมากกว่า 15 มม. ต้องซ่อมแซมด้วยวิธีใด\n', '\nAnswer: ซ่อมแซมด้วย Epoxy Resin (วิธีการอ้างอิง RP-TN-02)\n', '\nPage: 3\n', '\n\nQuestion: เกณฑ์การปฏิเสธชิ้นงาน (Reject) สำหรับความเสียหายประเภท "รอยร้าว" (Crack) คืออะไร\n', '\nAnswer: เมื่อรอยร้าวมีความกว้างมากกว่า 0.5 มม. หรือมีความลึกถึงชั้น Hydro swelling (Depth to hydro swelling)\n', '\nPage: 3\n', '\n\nQuestion: ลักษณะตำแหน่งการแตกบิ่นที่ขอบ (Spalling Edge) แบ่งออกเป็น 3 แบบ คืออะไรบ้าง\n', '\nAnswer: 1. Sharp Edge\n2. Chamfered Edge\n3. At Corners\n', '\nPage: 4\n', '\n\nQuestion: เกณฑ์ขนาดความเสียหายของ Spalling Edge ที่ "ไม่ต้องซ่อมแซม" (No Repair) คือเท่าใด\n', '\nAnswer: เมื่อขนาดความเสียหาย A, B และ C มีค่าน้อยกว่า 5 มม.\n', '\nPage: 4\n', '\n\nQuestion: ช่วงขนาดความเสียหายของ Spalling Edge ที่ต้องซ่อมแซมด้วย Cementitious Mortar (RP-TN-03) คือเท่าใด\n', '\nAnswer:\n- ด้าน A: 5-50 มม.\n- ด้าน B: 5-50 มม.\n- ด้าน C: 5-70 มม.\n', '\nPage: 4\n', '\n\nQuestion: เกณฑ์การปฏิเสธชิ้นงาน (Reject) สำหรับ Spalling Edge ในกรณีที่วัดขนาดความเสียหาย คือเท่าใด\n', '\nAnswer: เมื่อขนาดความเสียหาย A > 50 มม. หรือ B > 50 มม. หรือ C > 70 มม.\n', '\nPage: 4\n', '\n\nQuestion: นอกเหนือจากขนาดความเสียหาย หากเกิด Spalling Edge แล้วพบสิ่งใด จึงถือว่าต้องปฏิเสธชิ้นงาน (Reject) ทันที\n', '\nAnswer: เมื่อเหล็กเสริมโผล่ (Rebar exposed)\n', '\nPage: 4\n', '\n\nQuestion: เกณฑ์ขนาดความเสียหายบริเวณร่อง Gasket (Spalling Recesses) ที่ "ไม่ต้องซ่อมแซม" คือเท่าใด\n', '\nAnswer: เมื่อขนาดความเสียหาย A < 2 มม. และ B < 2 มม.\n', '\nPage: 5\n', '\n\nQuestion: วิธีการซ่อมแซมความเสียหายประเภท Spalling Recesses คือวิธีใด และอ้างอิง Method ใด\n', '\nAnswer: ซ่อมแซมด้วย Cementitious Mortar ตามวิธีการอ้างอิง RP-TN-03\n', '\nPage: 5\n', '\n\nQuestion: ช่วงขนาดความเสียหายของ Spalling Recesses ที่สามารถซ่อมแซมได้คือเท่าใด\n', '\nAnswer:\n- ด้าน A: 2-10 มม.\n- ด้าน B: 5-30 มม.\n- ด้าน C: 0-10 มม.\n', '\nPage: 5\n', '\n\nQuestion: เกณฑ์การปฏิเสธชิ้นงาน (Reject) สำหรับความเสียหายประเภท Spalling Recesses คือเท่าใด\n', '\nAnswer: เมื่อขนาดความเสียหาย A > 10 มม. หรือ B > 30 มม. หรือ C > 10 มม.\n', '\nPage: 5\n', '\n\nQuestion: การตรวจสอบรูฟองอากาศ (Voids or Blowholes) แบ่งตำแหน่งการตรวจสอบเป็นกี่จุด อะไรบ้าง\n', '\nAnswer: แบ่งเป็น 3 จุด ได้แก ...
# ['Question: เอกสารฉบับนี้จัดทำขึ้นเพื่อวัตถุประสงค์อะไร\n', '\nAnswer: เอกสารฉบับนี้จัดทำขึ้นเพื่อเป็นแนวทาง (Guideline) สำหรับการซ่อมผิวคอนกรีตของชิ้นส่วนผนังอุโมงค์ สำหรับโครงการก่อสร้างอุโมงค์ระบายน้ำจากบึงหนองบอนลงสู่แม่น้ำเจ้าพระยา\n', '\nPage: 2\n', '\n\nQuestion: ข้อบกพร่องของชิ้นส่วนอุโมงค์ที่สามารถซ่อมแซมได้ตามเอกสารนี้ ต้องมีลักษณะอย่างไร\n', '\nAnswer: ความเสียหายหรือข้อบกพร่องต้องไม่มีผลกระทบต่อโครงสร้างหลักของชิ้นส่วนผนังอุโมงค์ตามที่ออกแบบไว้\n', '\nPage: 2\n', '\n\nQuestion: เกณฑ์ความเสียหายจากการผลิตที่ยอมรับได้ โดยไม่ต้องทบทวนกระบวนการผลิตคือเท่าใด\n', '\nAnswer: ความเสียหายจากการผลิตต้องไม่เกิน 5% ของจำนวน Rings ที่ผลิตได้\n', '\nPage: 2\n', '\n\nQuestion: เกณฑ์ความเสียหายจากการขนส่งและการขนย้ายที่ยอมรับได้ คือเท่าใด\n', '\nAnswer: ความเสียหายจากการขนส่งและการขนย้ายต้องไม่เกิน 2% ของจำนวน Rings ของการขนส่ง\n', '\nPage: 2\n', '\n\nQuestion: ความเสียหายที่เกิดขึ้นกับชิ้นงานแบ่งออกเป็น 4 ลักษณะ อะไรบ้าง\n', '\nAnswer: ความเสียหายแบ่งเป็น:\n1. รอยร้าว (Crack)\n2. แตกบิ่นที่ขอบ (Spalling Edge)\n3. แตกบิ่นบริเวณ Gasket (Spalling Recesses)\n4. รูฟองอากาศ (Voids or Blowholes)\n', '\nPage: 2\n', '\n\nQuestion: เกณฑ์การพิจารณา "ไม่ต้องซ่อมแซม" (No Repair) สำหรับรอยร้าวประเภท Hard Crack คืออะไร\n', '\nAnswer: เมื่อรอยร้าวมีความกว้าง (A) น้อยกว่าหรือเท่ากับ 0.1 มม.\n', '\nPage: 3\n', '\n\nQuestion: เกณฑ์การพิจารณา "ไม่ต้องซ่อมแซม" (No Repair) สำหรับรอยร้าวประเภท Shrinkage Crack คืออะไร\n', '\nAnswer: เมื่อรอยร้าวมีความกว้าง (B) น้อยกว่าหรือเท่ากับ 0.3 มม. และมีความลึกน้อยกว่า 15 มม.\n', '\nPage: 3\n', '\n\nQuestion: วิธีการซ่อมแซมรอยร้าวประเภท Hard Crack ที่มีความกว้างมากกว่า 0.1 มม. แต่น้อยกว่า 0.3 มม. คือวิธีใด\n', '\nAnswer: ซ่อมแซมด้วย Cementitious Mortar (วิธีการอ้างอิง RP-TN-01)\n', '\nPage: 3\n', '\n\nQuestion: หากรอยร้าวมีความกว้างตั้งแต่ 0.3 มม. ถึง 0.5 มม. และมีความลึกมากกว่า 15 มม. ต้องซ่อมแซมด้วยวิธีใด\n', '\nAnswer: ซ่อมแซมด้วย Epoxy Resin (วิธีการอ้างอิง RP-TN-02)\n', '\nPage: 3\n', '\n\nQuestion: เกณฑ์การปฏิเสธชิ้นงาน (Reject) สำหรับความเสียหายประเภท "รอยร้าว" (Crack) คืออะไร\n', '\nAnswer: เมื่อรอยร้าวมีความกว้างมากกว่า 0.5 มม. หรือมีความลึกถึงชั้น Hydro swelling (Depth to hydro swelling)\n', '\nPage: 3\n', '\n\nQuestion: ลักษณะตำแหน่งการแตกบิ่นที่ขอบ (Spalling Edge) แบ่งออกเป็น 3 แบบ คืออะไรบ้าง\n', '\nAnswer: 1. Sharp Edge\n2. Chamfered Edge\n3. At Corners\n', '\nPage: 4\n', '\n\nQuestion: เกณฑ์ขนาดความเสียหายของ Spalling Edge ที่ "ไม่ต้องซ่อมแซม" (No Repair) คือเท่าใด\n', '\nAnswer: เมื่อขนาดความเสียหาย A, B และ C มีค่าน้อยกว่า 5 มม.\n', '\nPage: 4\n', '\n\nQuestion: ช่วงขนาดความเสียหายของ Spalling Edge ที่ต้องซ่อมแซมด้วย Cementitious Mortar (RP-TN-03) คือเท่าใด\n', '\nAnswer:\n- ด้าน A: 5-50 มม.\n- ด้าน B: 5-50 มม.\n- ด้าน C: 5-70 มม.\n', '\nPage: 4\n', '\n\nQuestion: เกณฑ์การปฏิเสธชิ้นงาน (Reject) สำหรับ Spalling Edge ในกรณีที่วัดขนาดความเสียหาย คือเท่าใด\n', '\nAnswer: เมื่อขนาดความเสียหาย A > 50 มม. หรือ B > 50 มม. หรือ C > 70 มม.\n', '\nPage: 4\n', '\n\nQuestion: นอกเหนือจากขนาดความเสียหาย หากเกิด Spalling Edge แล้วพบสิ่งใด จึงถือว่าต้องปฏิเสธชิ้นงาน (Reject) ทันที\n', '\nAnswer: เมื่อเหล็กเสริมโผล่ (Rebar exposed)\n', '\nPage: 4\n', '\n\nQuestion: เกณฑ์ขนาดความเสียหายบริเวณร่อง Gasket (Spalling Recesses) ที่ "ไม่ต้องซ่อมแซม" คือเท่าใด\n', '\nAnswer: เมื่อขนาดความเสียหาย A < 2 มม. และ B < 2 มม.\n', '\nPage: 5\n', '\n\nQuestion: วิธีการซ่อมแซมความเสียหายประเภท Spalling Recesses คือวิธีใด และอ้างอิง Method ใด\n', '\nAnswer: ซ่อมแซมด้วย Cementitious Mortar ตามวิธีการอ้างอิง RP-TN-03\n', '\nPage: 5\n', '\n\nQuestion: ช่วงขนาดความเสียหายของ Spalling Recesses ที่สามารถซ่อมแซมได้คือเท่าใด\n', '\nAnswer:\n- ด้าน A: 2-10 มม.\n- ด้าน B: 5-30 มม.\n- ด้าน C: 0-10 มม.\n', '\nPage: 5\n', '\n\nQuestion: เกณฑ์การปฏิเสธชิ้นงาน (Reject) สำหรับความเสียหายประเภท Spalling Recesses คือเท่าใด\n', '\nAnswer: เมื่อขนาดความเสียหาย A > 10 มม. หรือ B > 30 มม. หรือ C > 10 มม.\n', '\nPage: 5\n', '\n\nQuestion: การตรวจสอบรูฟองอากาศ (Voids or Blowholes) แบ่งตำแหน่งการตรวจสอบเป็นกี่จุด อะไรบ้าง\n', '\nAnswer: แบ่งเป็น 3 จุด ได้แก ...
# 120

# %%
new_qa = []

for i in range(0, len(qa_result_list)-1, 3):
    # print(i)
    new_qa.append({
        'Question': qa_result_list[i].replace('Question :', '').replace('++++++++++++++++++++++', '').replace('\n', '').replace('Question:', ''),
        'Answer': qa_result_list[i+1].replace('Answer :', '').replace('++++++++++++++++++++++', '').replace('\n', '').replace('Answer:', ''),
        'Page': qa_result_list[i+2].replace('++++++++++++++++++++++', '').replace('\n', '').replace('Page :', '').replace('Page:', '')
    })

# print(new_qa)

new_qa_df = pd.DataFrame(new_qa)
new_qa_df
# Out:
#                                              Question  \
# 0         เอกสารฉบับนี้จัดทำขึ้นเพื่อวัตถุประสงค์อะไร
# 1    ข้อบกพร่องของชิ้นส่วนอุโมงค์ที่สามารถซ่อมแซมไ...
# 2    เกณฑ์ความเสียหายจากการผลิตที่ยอมรับได้ โดยไม่...
# 3    เกณฑ์ความเสียหายจากการขนส่งและการขนย้ายที่ยอม...
# 4    ความเสียหายที่เกิดขึ้นกับชิ้นงานแบ่งออกเป็น 4...
# 5    เกณฑ์การพิจารณา "ไม่ต้องซ่อมแซม" (No Repair) ...
# 6    เกณฑ์การพิจารณา "ไม่ต้องซ่อมแซม" (No Repair) ...
# 7    วิธีการซ่อมแซมรอยร้าวประเภท Hard Crack ที่มีค...
# 8    หากรอยร้าวมีความกว้างตั้งแต่ 0.3 มม. ถึง 0.5 ...
# 9    เกณฑ์การปฏิเสธชิ้นงาน (Reject) สำหรับความเสีย...
# 10   ลักษณะตำแหน่งการแตกบิ่นที่ขอบ (Spalling Edge)...
# 11   เกณฑ์ขนาดความเสียหายของ Spalling Edge ที่ "ไม...
# 12   ช่วงขนาดความเสียหายของ Spalling Edge ที่ต้องซ...
# 13   เกณฑ์การปฏิเสธชิ้นงาน (Reject) สำหรับ Spallin...
# 14   นอกเหนือจากขนาดความเสียหาย หากเกิด Spalling E...
# 15   เกณฑ์ขนาดความเสียหายบริเวณร่อง Gasket (Spalli...
# 16   วิธีการซ่อมแซมความเสียหายประเภท Spalling Rece...
# 17   ช่วงขนาดความเสียหายของ Spalling Recesses ที่ส...
# 18   เกณฑ์การปฏิเสธชิ้นงาน (Reject) สำหรับความเสีย...
# 19   การตรวจสอบรูฟองอากาศ (Voids or Blowholes) แบ่...
# 20   เกณฑ์ "ไม่ต้องซ่อมแซม" สำหรับรูฟองอากาศบริเวณ...
# 21   หากพบรูฟองอากาศ (Voids) กว้างไม่เกิน 10 มม. แ...
# 22   หากพบรูฟองอากาศ (Voids) ที่มีความกว้างมากกว่า...
# 23   เกณฑ์การปฏิเสธชิ้นงาน (Reject) สำหรับความเสีย...
# 24   วิธีการซ่อมแซม RP-TN-01 ใช้สำหรับความเสียหายป...
# 25           วิธีการซ่อมแซม RP-TN-02 ใช้วัสดุประเภทใด
# 26   การซ่อมแซม Spalling Edge และ Spalling Recesse...
# 27   วัสดุประเภท "ปูนฉาบซ่อมกำลังอัดสูง" (High Str...
# 28   วัสดุชื่อ "Sika Skim Coat" เป็นวัสดุซ่อมประเภทใด
# 29   ปูนฉาบซ่อม "Renderoc Skim Coat" เป็นผลิตภัณฑ์...
# 30   ปูนฉาบตราผึ้ง 124 และ 124L มีสถานะการใช้งานอย...
# 31   วัสดุ "Conpatch 300" ของแบรนด์ CORMIX มีสถานะ...
# 32   วัสดุปูนฉาบซ่อมกำลังอัดสูง "ปูนฉาบตราผึ้ง 135...
# 33   วัสดุ Epoxy Resin ที่เสนอขออนุมัติใช้งานคือรุ...
# 34   วัสดุประเภทอีพ็อกซี่มอร์ต้าร์ (Epoxy Mortar) ...
# 35   วัสดุเชื่อมประสานคอนกรีต (Bonding Agent) ที่ร...
# 36   สำหรับการซ่อมแบบ RP-TN-04 (Voids or Blowholes...
# 37   การซ่อมรอยร้าวที่มีความลึกน้อยกว่า 15 มม. สำห...
# 38   ข้อกำหนดเพิ่มเติมในตาราง Guideline for Voids ...
# 39   เอกสารอ้างอิง (Document No.) ของ Guideline ฉบ...
#
#                                                Answer Page
# 0    เอกสารฉบับนี้จัดทำขึ้นเพื่อเป็นแนวทาง (Guidel...    2
# 1    ความเสียหายหรือข้อบกพร่องต้องไม่มีผลกระทบต่อโ...    2
# 2    ความเสียหายจากการผลิตต้องไม่เกิน 5% ของจำนวน ...    2
# 3    ความเสียหายจากการขนส่งและการขนย้ายต้องไม่เกิน...    2
# 4    ความเสียหายแบ่งเป็น:1. รอยร้าว (Crack)2. แตกบ...    2
# 5    เมื่อรอยร้าวมีความกว้าง (A) น้อยกว่าหรือเท่าก...    3
# 6    เมื่อรอยร้าวมีความกว้าง (B) น้อยกว่าหรือเท่าก...    3
# 7    ซ่อมแซมด้วย Cementitious Mortar (วิธีการอ้างอ...    3
# 8    ซ่อมแซมด้วย Epoxy Resin (วิธีการอ้างอิง RP-TN...    3
# 9    เมื่อรอยร้าวมีความกว้างมากกว่า 0.5 มม. หรือมี...    3
# 10        1. Sharp Edge2. Chamfered Edge3. At Corners    4
# 11   เมื่อขนาดความเสียหาย A, B และ C มีค่าน้อยกว่า...    4
# 12  - ด้าน A: 5-50 มม.- ด้าน B: 5-50 มม.- ด้าน C: ...    4
# 13   เมื่อขนาดความเสียหาย A > 50 มม. หรือ B > 50 ม...    4
# 14                เมื่อเหล็กเสริมโผล่ (Rebar exposed)    4
# 15       เมื่อขนาดความเสียหาย A < 2 มม. และ B < 2 มม.    5
# 16   ซ่อมแซมด้วย Cementitious Mortar ตามวิธีการอ้า...    5
# 17  - ด้าน A: 2-10 มม.- ด้าน B: 5-30 มม.- ด้าน C: ...    5
# 18   เมื่อขนาดความเสียหาย A > 10 มม. หรือ B > 30 ม...    5
# 19   แบ่งเป็น 3 จุด ได้แก่:A. Outside Surface (ผิว...    6
# 20   ไม่มีการกำหนดขนาดสำหรับการ "ไม่ซ่อมแซม" ที่ผิ...    6
# 21   ซ่อมแซมด้วย Cementitious Mortar (วิธีการอ้างอ...    6
# 22   ซ่อมแซมด้วย High Strength Mortar (วิธีการอ้าง...    6
# 23                เมื่อเหล็กเสริมโผล่ (Rebar exposed)    6
# 24   ใช้สำหรับซ่อมรอยร้าว (Crack) โดยใช้วัสดุประเภ...    7
# 25                      อีพ็อกซี่เรซิ่น (Epoxy Resin)    7
# 26                            วิธีการอ้างอิง RP-TN-03    7
# 27                                           RP-TN-05    7
# 28                   ปูนฉาบซ่อม (Cementitious Mortar)    8
# 29                                             FOSROC    8
# 30                             ได้รับการอนุมัติใช้งาน    8
# 31                             ได้รับการอนุมัติใช้งาน    8
# 32                                เสนอขออนุมัติใช้งาน    8
# 33   Sikadur 52 TH (แบรนด์ SIKA) และ Condur SC (แบ...    8
# 34      Sikadur 41 CF Normal และ Sikadur 31 CF Normal    8
# 35                                      Sikadur 32 TH    8
# 36                                Cementitious Mortar    7
# 37   หากความกว้าง B <= 0.3 มม. ถือว่า "ไม่ต้องซ่อม...    3
# 38   ความกว้าง (Wide) C ต้องน้อยกว่าหรือเท่ากับ 10...    6
# 39                                           TB-RP-01    1

# %%
new_qa_df.to_csv(f'{root_path}\\table\\QA_content_1.csv', index=False)

# %% [markdown]
# # 2_Repair_With_Cementitious_Mortar

# %%
context = ""
for i in range(len(docs[docs['content'] == '2_Repair_With_Cementitious_Mortar'])):
    context += f"Page {docs[docs['content'] == '2_Repair_With_Cementitious_Mortar']['page'].iloc[i]}:\n{docs[docs['content'] == '2_Repair_With_Cementitious_Mortar']['text'].iloc[i]}\n\n"
    # print(docs[docs['content'] == '2_Repair_With_Cementitious_Mortar']['page'].iloc[i])
# print(context)

# %%
qa_result = generate_qa_from_docs(context, qa_example.iloc[0])

# %%
qa_result
# Out:
# 'Question : วิธีการ Repair With Cementitious Mortar ใช้ในการซ่อมแซมรอยร้าวทั่วไปที่มีขนาดความกว้างและความลึกเท่าใด\n<split>\nAnswer : ใช้ซ่อมแซมรอยร้าวทั่วไปที่มีความกว้างมากกว่า 0.1 มม. แต่ไม่ถึง 0.3 มม. และความลึกของรอยร้าวมากกว่า 15 มม.\n<split>\nPage : 10\n<split>\n\nQuestion : วิธีการ Repair With Cementitious Mortar ใช้ซ่อมแซมรอยร้าวแบบ Shrinkage Crack ที่มีความกว้างเท่าใด\n<split>\nAnswer : รอยร้าวแบบ Shrinkage Crack ที่มีความกว้าง 0.3 - 0.5 มม.\n<split>\nPage : 10\n<split>\n\nQuestion : การวัดความกว้างของรอยร้าวต้องใช้อุปกรณ์ใด\n<split>\nAnswer : แผ่น Crack Width Indicator\n<split>\nPage : 10\n<split>\n\nQuestion : ผงซีเมนต์ที่ใช้ในการซ่อมแซมต้องมีคุณสมบัติอย่างไรบ้าง\n<split>\nAnswer : มีคุณสมบัติในการต้านทานการสึกหรอ สามารถยึดเกาะกับผิวคอนกรีตเดิมได้ดี และมีสีที่ใกล้เคียงกับสีคอนกรีต\n<split>\nPage : 10\n<split>\n\nQuestion : อุปกรณ์ข้อที่ 1.1 ที่ใช้ในการซ่อมแซมคืออะไร\n<split>\nAnswer : เครื่องเป่าลม\n<split>\nPage : 11\n<split>\n\nQuestion : อุปกรณ์ข้อที่ 1.2 ที่ใช้ในการซ่อมแซมคืออะไร\n<split>\nAnswer : เกรียง\n<split>\nPage : 11\n<split>\n\nQuestion : อุปกรณ์ข้อที่ 1.3 ที่ใช้ในการซ่อมแซมคืออะไร\n<split>\nAnswer : ฟองน้ำหรือลูกกลิ้ง\n<split>\nPage : 11\n<split>\n\nQuestion : อุปกรณ์ข้อที่ 1.4 ที่ใช้ในการซ่อมแซมคืออะไร\n<split>\nAnswer : กระดาษทราย\n<split>\nPage : 11\n<split>\n\nQuestion : อัตราส่วนผสมของวัสดุ Sika Skim Coat คือเท่าใด\n<split>\nAnswer : ปูน : น้ำ = 1 : 0.35 โดยน้ำหนัก\n<split>\nPage : 11\n<split>\n\nQuestion : อัตราส่วนผสมของวัสดุ Renderoc Skim Coat คือเท่าใด\n<split>\nAnswer : ปูน : น้ำ = 1 : 0.11 โดยน้ำหนัก\n<split>\nPage : 11\n<split>\n\nQuestion : อัตราส่วนผสมของวัสดุ ปูนฉาบแต่งตราผึ้ง 124 คือเท่าใด\n<split>\nAnswer : ปูน : น้ำ = 1 : 0.4 โดยน้ำหนัก\n<split>\nPage : 11\n<split>\n\nQuestion : อัตราส่วนผสมของวัสดุ ปูนฉาบแต่งตราผึ้ง 124L คือเท่าใด\n<split>\nAnswer : ปูน : น้ำ = 1 : 0.4 โดยน้ำหนัก\n<split>\nPage : 11\n<split>\n\nQuestion : อัตราส่วนผสมของวัสดุ Conpatch 300 คือเท่าใด\n<split>\nAnswer : ปูน : น้ำ = 1 : 0.2 โดยน้ำหนัก\n<split>\nPage : 11\n<split>\n\nQuestion : วัสดุ Renderoc Skim Coat เป็นผลิตภัณฑ์ของ Brand ใด\n<split>\nAnswer : FOSROC\n<split>\nPage : 11\n<split>\n\nQuestion : วัสดุ Conpatch 300 เป็นผลิตภัณฑ์ของ Brand ใด\n<split>\nAnswer : CORMIX\n<split>\nPage : 11\n<split>\n\nQuestion : วัสดุ ปูนฉาบแต่งตราผึ้ง 124 เป็นผลิตภัณฑ์ของ Brand ใด\n<split>\nAnswer : ปูนตราผึ้ง\n<split>\nPage : 11\n<split>\n\nQuestion : ในขั้นตอนการซ่อมแซมข้อที่ 3.1 ต้องใช้อุปกรณ์ใดทำความสะอาดผิวคอนกรีต\n<split>\nAnswer : เครื่องเป่าลม\n<split>\nPage : 12\n<split>\n\nQuestion : ก่อนทำการซ่อมแซมในขั้นตอนที่ 3.1 ต้องตรวจสอบสิ่งใด\n<split>\nAnswer : ตรวจสอบความสะอาด\n<split>\nPage : 12\n<split>\n\nQuestion : การฉาบปูนซ่อมลงบนผิวคอนกรีตในขั้นตอนที่ 3.2 ต้องเริ่มจากจุดใด\n<split>\nAnswer : เริ่มจากปลายด้านใดด้านหนึ่งของรอยร้าว\n<split>\nPage : 12\n<split>\n\nQuestion : ในขั้นตอนที่ 3.3 ต้องรอให้เกิดสภาพใดก่อนจึงจะใช้กระดาษทรายขัดได้\n<split>\nAnswer : รอให้ปูนฉาบแห้งแล้ว\n<split>\nPage : 13\n<split>\n\nQuestion : ในขั้นตอนที่ 3.3 ใช้กระดาษทรายขัดบริเวณที่ฉาบเพื่อวัตถุประสงค์ใด\n<split>\nAnswer : เพื่อให้มีผิวเรียบเสมอกับผิวคอนกรีตบริเวณอื่น\n<split>\nPage : 13\n<split>\n\nQuestion : ในขั้นตอนที่ 3.4 ต้องเตรียมปูนฉาบในลักษณะใด\n<split>\nAnswer : ผสมปูนฉาบให้เหลว\n<split>\nPage : 13\n<split>\n\nQuestion : อุปกรณ์ใดที่ใช้จุ่มปูนฉาบเหลวเพื่อลูบผิวคอนกรีตในขั้นตอนที่ 3.4\n<split>\nAnswer : ฟองน้ำหรือลูกกลิ้ง\n<split>\nPage : 13\n<split>\n\nQuestion : การลูบผิวคอนกรีตด้วยปูนฉาบเหลวในขั้นตอนที่ 3.4 มีวัตถุประสงค์เพื่ออะไร\n<split>\nAnswer : เพื่อให้ผิวคอนกรีตมีสีสม่ำเสมอ\n<split>\nPage : 13\n<split>\n\nQuestion : ในขั้นตอนที่ 3.5 ต้องรอให้เกิดสภาพใดก่อนทำการตรวจสอบรอยร้าว\n<split>\nAnswer : รอให้น้ำปูนแห้งแล้ว\n<split>\nPage : 14\n<split>\n\nQuestion : ขั้นตอนสุดท้ายหลังจากการซ่อมแซมเสร็จสิ้น (ข้อ 3.5) คืออะไร\n<split>\nAnswer : ตรวจสอบรอยร้าวอีกครั้งโดยละเอียด\n<split>\nPage : 14\n<split>\n\nQuestion : รูปที่ 1 ในเอกสารแสดงการปฏิบัติงานอะไร\n<split>\nAnswer : แสดงการวัดความกว้างของรอยร้าวโดยใช้ Crack Width Indicator\n<s ...

# %%
print(qa_result.split('<split>'))
qa_result_list = []
for qa in qa_result.split('<split>'):
    if qa != '++++++++++++++++++++++' and qa != '':
        qa_result_list.append(qa)
print(qa_result_list)
print(len(qa_result_list))
# Out:
# ['Question : วิธีการ Repair With Cementitious Mortar ใช้ในการซ่อมแซมรอยร้าวทั่วไปที่มีขนาดความกว้างและความลึกเท่าใด\n', '\nAnswer : ใช้ซ่อมแซมรอยร้าวทั่วไปที่มีความกว้างมากกว่า 0.1 มม. แต่ไม่ถึง 0.3 มม. และความลึกของรอยร้าวมากกว่า 15 มม.\n', '\nPage : 10\n', '\n\nQuestion : วิธีการ Repair With Cementitious Mortar ใช้ซ่อมแซมรอยร้าวแบบ Shrinkage Crack ที่มีความกว้างเท่าใด\n', '\nAnswer : รอยร้าวแบบ Shrinkage Crack ที่มีความกว้าง 0.3 - 0.5 มม.\n', '\nPage : 10\n', '\n\nQuestion : การวัดความกว้างของรอยร้าวต้องใช้อุปกรณ์ใด\n', '\nAnswer : แผ่น Crack Width Indicator\n', '\nPage : 10\n', '\n\nQuestion : ผงซีเมนต์ที่ใช้ในการซ่อมแซมต้องมีคุณสมบัติอย่างไรบ้าง\n', '\nAnswer : มีคุณสมบัติในการต้านทานการสึกหรอ สามารถยึดเกาะกับผิวคอนกรีตเดิมได้ดี และมีสีที่ใกล้เคียงกับสีคอนกรีต\n', '\nPage : 10\n', '\n\nQuestion : อุปกรณ์ข้อที่ 1.1 ที่ใช้ในการซ่อมแซมคืออะไร\n', '\nAnswer : เครื่องเป่าลม\n', '\nPage : 11\n', '\n\nQuestion : อุปกรณ์ข้อที่ 1.2 ที่ใช้ในการซ่อมแซมคืออะไร\n', '\nAnswer : เกรียง\n', '\nPage : 11\n', '\n\nQuestion : อุปกรณ์ข้อที่ 1.3 ที่ใช้ในการซ่อมแซมคืออะไร\n', '\nAnswer : ฟองน้ำหรือลูกกลิ้ง\n', '\nPage : 11\n', '\n\nQuestion : อุปกรณ์ข้อที่ 1.4 ที่ใช้ในการซ่อมแซมคืออะไร\n', '\nAnswer : กระดาษทราย\n', '\nPage : 11\n', '\n\nQuestion : อัตราส่วนผสมของวัสดุ Sika Skim Coat คือเท่าใด\n', '\nAnswer : ปูน : น้ำ = 1 : 0.35 โดยน้ำหนัก\n', '\nPage : 11\n', '\n\nQuestion : อัตราส่วนผสมของวัสดุ Renderoc Skim Coat คือเท่าใด\n', '\nAnswer : ปูน : น้ำ = 1 : 0.11 โดยน้ำหนัก\n', '\nPage : 11\n', '\n\nQuestion : อัตราส่วนผสมของวัสดุ ปูนฉาบแต่งตราผึ้ง 124 คือเท่าใด\n', '\nAnswer : ปูน : น้ำ = 1 : 0.4 โดยน้ำหนัก\n', '\nPage : 11\n', '\n\nQuestion : อัตราส่วนผสมของวัสดุ ปูนฉาบแต่งตราผึ้ง 124L คือเท่าใด\n', '\nAnswer : ปูน : น้ำ = 1 : 0.4 โดยน้ำหนัก\n', '\nPage : 11\n', '\n\nQuestion : อัตราส่วนผสมของวัสดุ Conpatch 300 คือเท่าใด\n', '\nAnswer : ปูน : น้ำ = 1 : 0.2 โดยน้ำหนัก\n', '\nPage : 11\n', '\n\nQuestion : วัสดุ Renderoc Skim Coat เป็นผลิตภัณฑ์ของ Brand ใด\n', '\nAnswer : FOSROC\n', '\nPage : 11\n', '\n\nQuestion : วัสดุ Conpatch 300 เป็นผลิตภัณฑ์ของ Brand ใด\n', '\nAnswer : CORMIX\n', '\nPage : 11\n', '\n\nQuestion : วัสดุ ปูนฉาบแต่งตราผึ้ง 124 เป็นผลิตภัณฑ์ของ Brand ใด\n', '\nAnswer : ปูนตราผึ้ง\n', '\nPage : 11\n', '\n\nQuestion : ในขั้นตอนการซ่อมแซมข้อที่ 3.1 ต้องใช้อุปกรณ์ใดทำความสะอาดผิวคอนกรีต\n', '\nAnswer : เครื่องเป่าลม\n', '\nPage : 12\n', '\n\nQuestion : ก่อนทำการซ่อมแซมในขั้นตอนที่ 3.1 ต้องตรวจสอบสิ่งใด\n', '\nAnswer : ตรวจสอบความสะอาด\n', '\nPage : 12\n', '\n\nQuestion : การฉาบปูนซ่อมลงบนผิวคอนกรีตในขั้นตอนที่ 3.2 ต้องเริ่มจากจุดใด\n', '\nAnswer : เริ่มจากปลายด้านใดด้านหนึ่งของรอยร้าว\n', '\nPage : 12\n', '\n\nQuestion : ในขั้นตอนที่ 3.3 ต้องรอให้เกิดสภาพใดก่อนจึงจะใช้กระดาษทรายขัดได้\n', '\nAnswer : รอให้ปูนฉาบแห้งแล้ว\n', '\nPage : 13\n', '\n\nQuestion : ในขั้นตอนที่ 3.3 ใช้กระดาษทรายขัดบริเวณที่ฉาบเพื่อวัตถุประสงค์ใด\n', '\nAnswer : เพื่อให้มีผิวเรียบเสมอกับผิวคอนกรีตบริเวณอื่น\n', '\nPage : 13\n', '\n\nQuestion : ในขั้นตอนที่ 3.4 ต้องเตรียมปูนฉาบในลักษณะใด\n', '\nAnswer : ผสมปูนฉาบให้เหลว\n', '\nPage : 13\n', '\n\nQuestion : อุปกรณ์ใดที่ใช้จุ่มปูนฉาบเหลวเพื่อลูบผิวคอนกรีตในขั้นตอนที่ 3.4\n', '\nAnswer : ฟองน้ำหรือลูกกลิ้ง\n', '\nPage : 13\n', '\n\nQuestion : การลูบผิวคอนกรีตด้วยปูนฉาบเหลวในขั้นตอนที่ 3.4 มีวัตถุประสงค์เพื่ออะไร\n', '\nAnswer : เพื่อให้ผิวคอนกรีตมีสีสม่ำเสมอ\n', '\nPage : 13\n', '\n\nQuestion : ในขั้นตอนที่ 3.5 ต้องรอให้เกิดสภาพใดก่อนทำการตรวจสอบรอยร้าว\n', '\nAnswer : รอให้น้ำปูนแห้งแล้ว\n', '\nPage : 14\n', '\n\nQuestion : ขั้นตอนสุดท้ายหลังจากการซ่อมแซมเสร็จสิ้น (ข้อ 3.5) คืออะไร\n', '\nAnswer : ตรวจสอบรอยร้าวอีกครั้งโดยละเอียด\n', '\nPage : 14\n', '\n\nQuestion : รูปที่ 1 ในเอกสารแสดงการปฏิบัติงานอะไร\n', '\nAnswer : แสดงการวัดความกว้างของรอยร้าวโดยใช้ Crack Width Indicator\n', '\nPage : 10\n', '\n\nQuestion : รูปที่ 3 ในเอกสารแสดงการปฏิบัติงานอะไร\n', '\nAnswer : แสดงการฉาบแต่งรอยร้าว\n', '\nPage : 12\n', '\n\nQuestion : รูปที่ 4 ในเอกสารแสดงการปฏิบัติงานอะไร\n', '\nAnswer : แสดงการขัดผิวปูนฉาบ\n', '\nPage : ...
# ['Question : วิธีการ Repair With Cementitious Mortar ใช้ในการซ่อมแซมรอยร้าวทั่วไปที่มีขนาดความกว้างและความลึกเท่าใด\n', '\nAnswer : ใช้ซ่อมแซมรอยร้าวทั่วไปที่มีความกว้างมากกว่า 0.1 มม. แต่ไม่ถึง 0.3 มม. และความลึกของรอยร้าวมากกว่า 15 มม.\n', '\nPage : 10\n', '\n\nQuestion : วิธีการ Repair With Cementitious Mortar ใช้ซ่อมแซมรอยร้าวแบบ Shrinkage Crack ที่มีความกว้างเท่าใด\n', '\nAnswer : รอยร้าวแบบ Shrinkage Crack ที่มีความกว้าง 0.3 - 0.5 มม.\n', '\nPage : 10\n', '\n\nQuestion : การวัดความกว้างของรอยร้าวต้องใช้อุปกรณ์ใด\n', '\nAnswer : แผ่น Crack Width Indicator\n', '\nPage : 10\n', '\n\nQuestion : ผงซีเมนต์ที่ใช้ในการซ่อมแซมต้องมีคุณสมบัติอย่างไรบ้าง\n', '\nAnswer : มีคุณสมบัติในการต้านทานการสึกหรอ สามารถยึดเกาะกับผิวคอนกรีตเดิมได้ดี และมีสีที่ใกล้เคียงกับสีคอนกรีต\n', '\nPage : 10\n', '\n\nQuestion : อุปกรณ์ข้อที่ 1.1 ที่ใช้ในการซ่อมแซมคืออะไร\n', '\nAnswer : เครื่องเป่าลม\n', '\nPage : 11\n', '\n\nQuestion : อุปกรณ์ข้อที่ 1.2 ที่ใช้ในการซ่อมแซมคืออะไร\n', '\nAnswer : เกรียง\n', '\nPage : 11\n', '\n\nQuestion : อุปกรณ์ข้อที่ 1.3 ที่ใช้ในการซ่อมแซมคืออะไร\n', '\nAnswer : ฟองน้ำหรือลูกกลิ้ง\n', '\nPage : 11\n', '\n\nQuestion : อุปกรณ์ข้อที่ 1.4 ที่ใช้ในการซ่อมแซมคืออะไร\n', '\nAnswer : กระดาษทราย\n', '\nPage : 11\n', '\n\nQuestion : อัตราส่วนผสมของวัสดุ Sika Skim Coat คือเท่าใด\n', '\nAnswer : ปูน : น้ำ = 1 : 0.35 โดยน้ำหนัก\n', '\nPage : 11\n', '\n\nQuestion : อัตราส่วนผสมของวัสดุ Renderoc Skim Coat คือเท่าใด\n', '\nAnswer : ปูน : น้ำ = 1 : 0.11 โดยน้ำหนัก\n', '\nPage : 11\n', '\n\nQuestion : อัตราส่วนผสมของวัสดุ ปูนฉาบแต่งตราผึ้ง 124 คือเท่าใด\n', '\nAnswer : ปูน : น้ำ = 1 : 0.4 โดยน้ำหนัก\n', '\nPage : 11\n', '\n\nQuestion : อัตราส่วนผสมของวัสดุ ปูนฉาบแต่งตราผึ้ง 124L คือเท่าใด\n', '\nAnswer : ปูน : น้ำ = 1 : 0.4 โดยน้ำหนัก\n', '\nPage : 11\n', '\n\nQuestion : อัตราส่วนผสมของวัสดุ Conpatch 300 คือเท่าใด\n', '\nAnswer : ปูน : น้ำ = 1 : 0.2 โดยน้ำหนัก\n', '\nPage : 11\n', '\n\nQuestion : วัสดุ Renderoc Skim Coat เป็นผลิตภัณฑ์ของ Brand ใด\n', '\nAnswer : FOSROC\n', '\nPage : 11\n', '\n\nQuestion : วัสดุ Conpatch 300 เป็นผลิตภัณฑ์ของ Brand ใด\n', '\nAnswer : CORMIX\n', '\nPage : 11\n', '\n\nQuestion : วัสดุ ปูนฉาบแต่งตราผึ้ง 124 เป็นผลิตภัณฑ์ของ Brand ใด\n', '\nAnswer : ปูนตราผึ้ง\n', '\nPage : 11\n', '\n\nQuestion : ในขั้นตอนการซ่อมแซมข้อที่ 3.1 ต้องใช้อุปกรณ์ใดทำความสะอาดผิวคอนกรีต\n', '\nAnswer : เครื่องเป่าลม\n', '\nPage : 12\n', '\n\nQuestion : ก่อนทำการซ่อมแซมในขั้นตอนที่ 3.1 ต้องตรวจสอบสิ่งใด\n', '\nAnswer : ตรวจสอบความสะอาด\n', '\nPage : 12\n', '\n\nQuestion : การฉาบปูนซ่อมลงบนผิวคอนกรีตในขั้นตอนที่ 3.2 ต้องเริ่มจากจุดใด\n', '\nAnswer : เริ่มจากปลายด้านใดด้านหนึ่งของรอยร้าว\n', '\nPage : 12\n', '\n\nQuestion : ในขั้นตอนที่ 3.3 ต้องรอให้เกิดสภาพใดก่อนจึงจะใช้กระดาษทรายขัดได้\n', '\nAnswer : รอให้ปูนฉาบแห้งแล้ว\n', '\nPage : 13\n', '\n\nQuestion : ในขั้นตอนที่ 3.3 ใช้กระดาษทรายขัดบริเวณที่ฉาบเพื่อวัตถุประสงค์ใด\n', '\nAnswer : เพื่อให้มีผิวเรียบเสมอกับผิวคอนกรีตบริเวณอื่น\n', '\nPage : 13\n', '\n\nQuestion : ในขั้นตอนที่ 3.4 ต้องเตรียมปูนฉาบในลักษณะใด\n', '\nAnswer : ผสมปูนฉาบให้เหลว\n', '\nPage : 13\n', '\n\nQuestion : อุปกรณ์ใดที่ใช้จุ่มปูนฉาบเหลวเพื่อลูบผิวคอนกรีตในขั้นตอนที่ 3.4\n', '\nAnswer : ฟองน้ำหรือลูกกลิ้ง\n', '\nPage : 13\n', '\n\nQuestion : การลูบผิวคอนกรีตด้วยปูนฉาบเหลวในขั้นตอนที่ 3.4 มีวัตถุประสงค์เพื่ออะไร\n', '\nAnswer : เพื่อให้ผิวคอนกรีตมีสีสม่ำเสมอ\n', '\nPage : 13\n', '\n\nQuestion : ในขั้นตอนที่ 3.5 ต้องรอให้เกิดสภาพใดก่อนทำการตรวจสอบรอยร้าว\n', '\nAnswer : รอให้น้ำปูนแห้งแล้ว\n', '\nPage : 14\n', '\n\nQuestion : ขั้นตอนสุดท้ายหลังจากการซ่อมแซมเสร็จสิ้น (ข้อ 3.5) คืออะไร\n', '\nAnswer : ตรวจสอบรอยร้าวอีกครั้งโดยละเอียด\n', '\nPage : 14\n', '\n\nQuestion : รูปที่ 1 ในเอกสารแสดงการปฏิบัติงานอะไร\n', '\nAnswer : แสดงการวัดความกว้างของรอยร้าวโดยใช้ Crack Width Indicator\n', '\nPage : 10\n', '\n\nQuestion : รูปที่ 3 ในเอกสารแสดงการปฏิบัติงานอะไร\n', '\nAnswer : แสดงการฉาบแต่งรอยร้าว\n', '\nPage : 12\n', '\n\nQuestion : รูปที่ 4 ในเอกสารแสดงการปฏิบัติงานอะไร\n', '\nAnswer : แสดงการขัดผิวปูนฉาบ\n', '\nPage : ...
# 120

# %%
new_qa = []

for i in range(0, len(qa_result_list)-1, 3):
    # print(i)
    new_qa.append({
        'Question': qa_result_list[i].replace('Question :', '').replace('++++++++++++++++++++++', '').replace('\n', ''),
        'Answer': qa_result_list[i+1].replace('Answer :', '').replace('++++++++++++++++++++++', '').replace('\n', ''),
        'Page': qa_result_list[i+2].replace('++++++++++++++++++++++', '').replace('\n', '').replace('Page :', '').replace('Page:', '')
    })

# print(new_qa)

new_qa_df = pd.DataFrame(new_qa)
new_qa_df
# Out:
#                                              Question  \
# 0    วิธีการ Repair With Cementitious Mortar ใช้ใน...
# 1    วิธีการ Repair With Cementitious Mortar ใช้ซ่...
# 2           การวัดความกว้างของรอยร้าวต้องใช้อุปกรณ์ใด
# 3    ผงซีเมนต์ที่ใช้ในการซ่อมแซมต้องมีคุณสมบัติอย่...
# 4         อุปกรณ์ข้อที่ 1.1 ที่ใช้ในการซ่อมแซมคืออะไร
# 5         อุปกรณ์ข้อที่ 1.2 ที่ใช้ในการซ่อมแซมคืออะไร
# 6         อุปกรณ์ข้อที่ 1.3 ที่ใช้ในการซ่อมแซมคืออะไร
# 7         อุปกรณ์ข้อที่ 1.4 ที่ใช้ในการซ่อมแซมคืออะไร
# 8       อัตราส่วนผสมของวัสดุ Sika Skim Coat คือเท่าใด
# 9    อัตราส่วนผสมของวัสดุ Renderoc Skim Coat คือเท...
# 10   อัตราส่วนผสมของวัสดุ ปูนฉาบแต่งตราผึ้ง 124 คื...
# 11   อัตราส่วนผสมของวัสดุ ปูนฉาบแต่งตราผึ้ง 124L ค...
# 12        อัตราส่วนผสมของวัสดุ Conpatch 300 คือเท่าใด
# 13   วัสดุ Renderoc Skim Coat เป็นผลิตภัณฑ์ของ Bra...
# 14       วัสดุ Conpatch 300 เป็นผลิตภัณฑ์ของ Brand ใด
# 15   วัสดุ ปูนฉาบแต่งตราผึ้ง 124 เป็นผลิตภัณฑ์ของ ...
# 16   ในขั้นตอนการซ่อมแซมข้อที่ 3.1 ต้องใช้อุปกรณ์ใ...
# 17   ก่อนทำการซ่อมแซมในขั้นตอนที่ 3.1 ต้องตรวจสอบส...
# 18   การฉาบปูนซ่อมลงบนผิวคอนกรีตในขั้นตอนที่ 3.2 ต...
# 19   ในขั้นตอนที่ 3.3 ต้องรอให้เกิดสภาพใดก่อนจึงจะ...
# 20   ในขั้นตอนที่ 3.3 ใช้กระดาษทรายขัดบริเวณที่ฉาบ...
# 21        ในขั้นตอนที่ 3.4 ต้องเตรียมปูนฉาบในลักษณะใด
# 22   อุปกรณ์ใดที่ใช้จุ่มปูนฉาบเหลวเพื่อลูบผิวคอนกร...
# 23   การลูบผิวคอนกรีตด้วยปูนฉาบเหลวในขั้นตอนที่ 3....
# 24   ในขั้นตอนที่ 3.5 ต้องรอให้เกิดสภาพใดก่อนทำการ...
# 25   ขั้นตอนสุดท้ายหลังจากการซ่อมแซมเสร็จสิ้น (ข้อ...
# 26             รูปที่ 1 ในเอกสารแสดงการปฏิบัติงานอะไร
# 27             รูปที่ 3 ในเอกสารแสดงการปฏิบัติงานอะไร
# 28             รูปที่ 4 ในเอกสารแสดงการปฏิบัติงานอะไร
# 29             รูปที่ 5 ในเอกสารแสดงการปฏิบัติงานอะไร
# 30   รหัสเอกสาร (Document No.) ของคู่มือฉบับนี้คือ...
# 31    ชื่อโครงการ (Project) ที่ระบุในเอกสารนี้คืออะไร
# 32   การผสมปูนฉาบซ่อมตามรายการวัสดุข้อ 2.1 ใช้อัตร...
# 33   วัสดุซ่อมแซม Sika Skim Coat เป็นผลิตภัณฑ์ของ ...
# 34   ภาชนะใส่วัสดุซ่อม อยู่ในรายการอุปกรณ์ข้อที่เท...
# 35   หากรอยร้าวมีความกว้าง 0.4 มม. จะจัดอยู่ในเกณฑ...
# 36   หากรอยร้าวมีความกว้างน้อยกว่า 0.3 มม. แต่มากก...
# 37    วันที่ (Date) ของเอกสาร Issue 2 คือวันที่เท่าใด
# 38                 คำบรรยายใต้รูปที่ 6 ระบุว่าอย่างไร
# 39   คุณสมบัติของสีคอนกรีตหลังจากการลูบด้วยปูนฉาบเ...
#
#                                                Answer Page
# 0    ใช้ซ่อมแซมรอยร้าวทั่วไปที่มีความกว้างมากกว่า ...   10
# 1    รอยร้าวแบบ Shrinkage Crack ที่มีความกว้าง 0.3...   10
# 2                          แผ่น Crack Width Indicator   10
# 3    มีคุณสมบัติในการต้านทานการสึกหรอ สามารถยึดเกา...   10
# 4                                       เครื่องเป่าลม   11
# 5                                              เกรียง   11
# 6                                  ฟองน้ำหรือลูกกลิ้ง   11
# 7                                          กระดาษทราย   11
# 8                     ปูน : น้ำ = 1 : 0.35 โดยน้ำหนัก   11
# 9                     ปูน : น้ำ = 1 : 0.11 โดยน้ำหนัก   11
# 10                     ปูน : น้ำ = 1 : 0.4 โดยน้ำหนัก   11
# 11                     ปูน : น้ำ = 1 : 0.4 โดยน้ำหนัก   11
# 12                     ปูน : น้ำ = 1 : 0.2 โดยน้ำหนัก   11
# 13                                             FOSROC   11
# 14                                             CORMIX   11
# 15                                         ปูนตราผึ้ง   11
# 16                                      เครื่องเป่าลม   12
# 17                                   ตรวจสอบความสะอาด   12
# 18              เริ่มจากปลายด้านใดด้านหนึ่งของรอยร้าว   12
# 19                                รอให้ปูนฉาบแห้งแล้ว   13
# 20      เพื่อให้มีผิวเรียบเสมอกับผิวคอนกรีตบริเวณอื่น   13
# 21                                   ผสมปูนฉาบให้เหลว   13
# 22                                 ฟองน้ำหรือลูกกลิ้ง   13
# 23                     เพื่อให้ผิวคอนกรีตมีสีสม่ำเสมอ   13
# 24                                รอให้น้ำปูนแห้งแล้ว   14
# 25                   ตรวจสอบรอยร้าวอีกครั้งโดยละเอียด   14
# 26   แสดงการวัดความกว้างของรอยร้าวโดยใช้ Crack Wid...   10
# 27                              แสดงการฉาบแต่งรอยร้าว   12
# 28                                แสดงการขัดผิวปูนฉาบ   13
# 29                 แสดงการลูบผิวคอนกรีตด้วยปูนฉาบเหลว   13
# 30                                           RP-TN-01   10
# 31   SEWERAGE TUNNEL BUNG NONG BON TO CHAOPHRAYA R...   10
# 32                                         โดยน้ำหนัก   11
# 33                                               SIKA   11
# 34                                            ข้อ 1.5   11
# 35                                    Shrinkage Crack   10
# 36                                      รอยร้าวทั่วไป   10
# 37                                          20/6/2017   10
# 38                     แสดงชิ้นงานที่ซ่อมแซมเสร็จแล้ว   14
# 39                                       มีสีสม่ำเสมอ   13

# %%
new_qa_df.to_csv(f'{root_path}\\table\\QA_content_2.csv', index=False)

# %% [markdown]
# # 3_Repair_With_Epoxy_Resin

# %%
context = ""
for i in range(len(docs[docs['content'] == '3_Repair_With_Epoxy_Resin'])):
    context += f"Page {docs[docs['content'] == '3_Repair_With_Epoxy_Resin']['page'].iloc[i]}:\n{docs[docs['content'] == '3_Repair_With_Epoxy_Resin']['text'].iloc[i]}\n\n"
    # print(docs[docs['content'] == '2_Repair_With_Cementitious_Mortar']['page'].iloc[i])
# print(context)

# %%
qa_result = generate_qa_from_docs(context, qa_example.iloc[0])

# %%
print(qa_result.split('<split>'))
qa_result_list = []
for qa in qa_result.split('<split>'):
    if qa != '++++++++++++++++++++++' and qa != '':
        qa_result_list.append(qa)
print(qa_result_list)
print(len(qa_result_list))
# Out:
# ['Question : เอกสารวิธีการ Repair With Epoxy Resin (RP-TN-02) ใช้สำหรับซ่อมแซมรอยร้าวที่มีลักษณะอย่างไร\n', '\nAnswer : ใช้ซ่อมแซมรอยร้าวทั่วไปที่มีความกว้างตั้งแต่ 0.3 mm. ถึง 0.5 mm. และมีความลึกมากกว่า 15 mm. แต่ไม่ถึงเหล็กเสริม\n', '\nPage : 16\n', '\n\nQuestion : คุณสมบัติของวัสดุอีพ็อกซี่เรซิ่นที่ใช้ในการซ่อมแซมมีอะไรบ้าง\n', '\nAnswer : คุณสมบัติของวัสดุอีพ็อกซี่เรซิ่นมีดังนี้:\n1. เป็นของเหลวที่มีความหนืดต่ำ สามารถซึมผ่านช่องรอยร้าวที่มีขนาดเล็กได้ดี\n2. มีกำลังอัดและแรงยึดเกาะที่สูงกว่าคอนกรีต\n3. มีคุณสมบัติต้านทานการซึมผ่านของน้ำ\n4. ไม่มีการหดตัว\n', '\nPage : 16\n', '\n\nQuestion : อุปกรณ์ที่ใช้ในการวัดความกว้างของรอยร้าวเรียกว่าอะไร\n', '\nAnswer : Crack Width Indicator\n', '\nPage : 16\n', '\n\nQuestion : โครงการที่ระบุในเอกสารวิธีการซ่อมแซมนี้คือโครงการใด\n', '\nAnswer : PROJECT: SEWERAGE TUNNEL BUNG NONG BON TO CHAOPHRAYA RIVER\n', '\nPage : 16\n', '\n\nQuestion : อุปกรณ์ที่ใช้ในการซ่อมแซมตามเอกสาร RP-TN-02 มีรายการใดบ้าง\n', '\nAnswer : อุปกรณ์ที่ใช้ในการซ่อมแซมประกอบด้วย:\n1. เครื่องเป่าลม\n2. เกรียง\n3. ฟองน้ำหรือลูกกลิ้ง\n4. เครื่องตัดและใบตัดคอนกรีต\n5. กระดาษทราย\n6. ภาชนะใส่วัสดุซ่อม\n', '\nPage : 17\n', '\n\nQuestion : วัสดุอีพ็อกซี่ Sikadur 52TH มีอัตราส่วนผสมระหว่างวัสดุ A และวัสดุ B เท่าไหร่\n', '\nAnswer : อัตราส่วนผสม วัสดุ A : วัสดุ B = 2 : 1\n', '\nPage : 17\n', '\n\nQuestion : วัสดุอีพ็อกซี่ Condur SC เป็นผลิตภัณฑ์ของ Brand ใด และมีอัตราส่วนผสมเท่าไหร่\n', '\nAnswer : เป็นผลิตภัณฑ์ของ Brand CORMIX โดยมีอัตราส่วนผสม วัสดุ A : วัสดุ B = 4 : 1\n', '\nPage : 17\n', '\n\nQuestion : ปูนฉาบซ่อม Sika Skim Coat มีอัตราส่วนผสมโดยน้ำหนักเท่าไหร่\n', '\nAnswer : ปูน : น้ำ = 1 : 0.35 โดยน้ำหนัก\n', '\nPage : 18\n', '\n\nQuestion : ปูนฉาบซ่อม Renderoc Skim Coat ของ Brand FOSROC มีอัตราส่วนผสมเท่าไหร่\n', '\nAnswer : ปูน : น้ำ = 1 : 0.11 โดยน้ำหนัก\n', '\nPage : 18\n', '\n\nQuestion : ปูนฉาบแต่งตราผึ้ง 124 และ 124L มีอัตราส่วนผสมปูนต่อน้ำเท่าไหร่\n', '\nAnswer : ปูน : น้ำ = 1 : 0.4 โดยน้ำหนัก\n', '\nPage : 18\n', '\n\nQuestion : วัสดุ Conpatch 300 มีอัตราส่วนผสมระหว่างปูนกับน้ำเท่าไหร่\n', '\nAnswer : ปูน : น้ำ = 1 : 0.2 โดยน้ำหนัก\n', '\nPage : 18\n', '\n\nQuestion : ในขั้นตอนการซ่อมแซม การเซาะร่องตามแนวรอยร้าวควรกำหนดความกว้างบริเวณปากร่องประมาณเท่าใด\n', '\nAnswer : 3-5 mm. โดยประมาณ\n', '\nPage : 19\n', '\n\nQuestion : ลักษณะร่องที่ได้จากการใช้เครื่องตัดคอนกรีตเซาะร่องควรเป็นรูปทรงใด\n', '\nAnswer : ร่องที่มีลักษณะคล้ายตัว V\n', '\nPage : 19\n', '\n\nQuestion : ก่อนทำการซ่อมแซม ผิวคอนกรีตบริเวณที่จะซ่อมแซมต้องมีสภาพอย่างไร\n', '\nAnswer : จะต้องปราศจากฝุ่น เศษวัสดุ หรือคราบน้ำมัน\n', '\nPage : 19\n', '\n\nQuestion : ขั้นตอนการเตรียมผิวหลังจากทำความสะอาดผิวคอนกรีตแล้วต้องใช้อุปกรณ์ใดเป่าผิวคอนกรีต\n', '\nAnswer : เครื่องเป่าลม\n', '\nPage : 19\n', '\n\nQuestion : การทำแนวกั้นรอยร้าวควรเว้นระยะห่างจากรอยร้าวประมาณเท่าใด\n', '\nAnswer : ห่างจากรอยร้าวฝั่งละ 5 mm. โดยประมาณ\n', '\nPage : 20\n', '\n\nQuestion : วัตถุประสงค์ของการทำแนวกั้นขนานกับแนวรอยร้าวคืออะไร\n', '\nAnswer : เพื่อไม่ให้วัสดุซ่อมโดนผิวคอนกรีตส่วนอื่น\n', '\nPage : 20\n', '\n\nQuestion : วิธีการหยอดวัสดุซ่อมอีพ็อกซี่เรซิ่นลงในร่องที่ถูกต้องคืออย่างไร\n', '\nAnswer : หยอดโดยเริ่มจากริมฝั่งใดฝั่งหนึ่งของรอยร้าว\n', '\nPage : 20\n', '\n\nQuestion : หากสังเกตเห็นว่าระดับของวัสดุซ่อมลดลงหลังจากหยอดลงไปแล้ว ควรดำเนินการอย่างไร\n', '\nAnswer : จะต้องหยอดเพิ่มจนกว่าจะแน่ใจว่าวัสดุซ่อมเต็มรอยร้าวแล้ว\n', '\nPage : 20\n', '\n\nQuestion : ควรเอาแนวกั้นรอยร้าวออกเมื่อใด\n', '\nAnswer : หลังจากวัสดุซ่อมเซตตัวแล้ว\n', '\nPage : 21\n', '\n\nQuestion : หลังจากเอาแนวกั้นออกแล้ว ต้องทำสิ่งใดก่อนการตกแต่งผิว\n', '\nAnswer : ทำความสะอาดผิวคอนกรีตบริเวณนั้น\n', '\nPage : 21\n', '\n\nQuestion : ขั้นตอนหลังจากทำความสะอาดผิวคอนกรีตที่หยอดอีพ็อกซี่แล้วคืออะไร\n', '\nAnswer : ผสมปูนฉาบซ่อมตามอัตราส่วน แล้วฉาบทับรอยร้าวที่ได้รับการซ่อมแซมแล้ว\n', '\nPage : 21\n', '\n\nQuestion : การขัดผิวบริเวณที่ฉาบแต่งควรทำเมื่อใด\n', '\nAnswer : หลังจากปูนฉาบแห้ง\n', '\nPage : 22\n', '\n\nQuestion : อุปกรณ์ที่ใช้ในการขัดบริเวณที่ได้ทำการฉาบคืออะไร\n', '\nAnswer : กระดาษทราย\n', '\nP ...
# ['Question : เอกสารวิธีการ Repair With Epoxy Resin (RP-TN-02) ใช้สำหรับซ่อมแซมรอยร้าวที่มีลักษณะอย่างไร\n', '\nAnswer : ใช้ซ่อมแซมรอยร้าวทั่วไปที่มีความกว้างตั้งแต่ 0.3 mm. ถึง 0.5 mm. และมีความลึกมากกว่า 15 mm. แต่ไม่ถึงเหล็กเสริม\n', '\nPage : 16\n', '\n\nQuestion : คุณสมบัติของวัสดุอีพ็อกซี่เรซิ่นที่ใช้ในการซ่อมแซมมีอะไรบ้าง\n', '\nAnswer : คุณสมบัติของวัสดุอีพ็อกซี่เรซิ่นมีดังนี้:\n1. เป็นของเหลวที่มีความหนืดต่ำ สามารถซึมผ่านช่องรอยร้าวที่มีขนาดเล็กได้ดี\n2. มีกำลังอัดและแรงยึดเกาะที่สูงกว่าคอนกรีต\n3. มีคุณสมบัติต้านทานการซึมผ่านของน้ำ\n4. ไม่มีการหดตัว\n', '\nPage : 16\n', '\n\nQuestion : อุปกรณ์ที่ใช้ในการวัดความกว้างของรอยร้าวเรียกว่าอะไร\n', '\nAnswer : Crack Width Indicator\n', '\nPage : 16\n', '\n\nQuestion : โครงการที่ระบุในเอกสารวิธีการซ่อมแซมนี้คือโครงการใด\n', '\nAnswer : PROJECT: SEWERAGE TUNNEL BUNG NONG BON TO CHAOPHRAYA RIVER\n', '\nPage : 16\n', '\n\nQuestion : อุปกรณ์ที่ใช้ในการซ่อมแซมตามเอกสาร RP-TN-02 มีรายการใดบ้าง\n', '\nAnswer : อุปกรณ์ที่ใช้ในการซ่อมแซมประกอบด้วย:\n1. เครื่องเป่าลม\n2. เกรียง\n3. ฟองน้ำหรือลูกกลิ้ง\n4. เครื่องตัดและใบตัดคอนกรีต\n5. กระดาษทราย\n6. ภาชนะใส่วัสดุซ่อม\n', '\nPage : 17\n', '\n\nQuestion : วัสดุอีพ็อกซี่ Sikadur 52TH มีอัตราส่วนผสมระหว่างวัสดุ A และวัสดุ B เท่าไหร่\n', '\nAnswer : อัตราส่วนผสม วัสดุ A : วัสดุ B = 2 : 1\n', '\nPage : 17\n', '\n\nQuestion : วัสดุอีพ็อกซี่ Condur SC เป็นผลิตภัณฑ์ของ Brand ใด และมีอัตราส่วนผสมเท่าไหร่\n', '\nAnswer : เป็นผลิตภัณฑ์ของ Brand CORMIX โดยมีอัตราส่วนผสม วัสดุ A : วัสดุ B = 4 : 1\n', '\nPage : 17\n', '\n\nQuestion : ปูนฉาบซ่อม Sika Skim Coat มีอัตราส่วนผสมโดยน้ำหนักเท่าไหร่\n', '\nAnswer : ปูน : น้ำ = 1 : 0.35 โดยน้ำหนัก\n', '\nPage : 18\n', '\n\nQuestion : ปูนฉาบซ่อม Renderoc Skim Coat ของ Brand FOSROC มีอัตราส่วนผสมเท่าไหร่\n', '\nAnswer : ปูน : น้ำ = 1 : 0.11 โดยน้ำหนัก\n', '\nPage : 18\n', '\n\nQuestion : ปูนฉาบแต่งตราผึ้ง 124 และ 124L มีอัตราส่วนผสมปูนต่อน้ำเท่าไหร่\n', '\nAnswer : ปูน : น้ำ = 1 : 0.4 โดยน้ำหนัก\n', '\nPage : 18\n', '\n\nQuestion : วัสดุ Conpatch 300 มีอัตราส่วนผสมระหว่างปูนกับน้ำเท่าไหร่\n', '\nAnswer : ปูน : น้ำ = 1 : 0.2 โดยน้ำหนัก\n', '\nPage : 18\n', '\n\nQuestion : ในขั้นตอนการซ่อมแซม การเซาะร่องตามแนวรอยร้าวควรกำหนดความกว้างบริเวณปากร่องประมาณเท่าใด\n', '\nAnswer : 3-5 mm. โดยประมาณ\n', '\nPage : 19\n', '\n\nQuestion : ลักษณะร่องที่ได้จากการใช้เครื่องตัดคอนกรีตเซาะร่องควรเป็นรูปทรงใด\n', '\nAnswer : ร่องที่มีลักษณะคล้ายตัว V\n', '\nPage : 19\n', '\n\nQuestion : ก่อนทำการซ่อมแซม ผิวคอนกรีตบริเวณที่จะซ่อมแซมต้องมีสภาพอย่างไร\n', '\nAnswer : จะต้องปราศจากฝุ่น เศษวัสดุ หรือคราบน้ำมัน\n', '\nPage : 19\n', '\n\nQuestion : ขั้นตอนการเตรียมผิวหลังจากทำความสะอาดผิวคอนกรีตแล้วต้องใช้อุปกรณ์ใดเป่าผิวคอนกรีต\n', '\nAnswer : เครื่องเป่าลม\n', '\nPage : 19\n', '\n\nQuestion : การทำแนวกั้นรอยร้าวควรเว้นระยะห่างจากรอยร้าวประมาณเท่าใด\n', '\nAnswer : ห่างจากรอยร้าวฝั่งละ 5 mm. โดยประมาณ\n', '\nPage : 20\n', '\n\nQuestion : วัตถุประสงค์ของการทำแนวกั้นขนานกับแนวรอยร้าวคืออะไร\n', '\nAnswer : เพื่อไม่ให้วัสดุซ่อมโดนผิวคอนกรีตส่วนอื่น\n', '\nPage : 20\n', '\n\nQuestion : วิธีการหยอดวัสดุซ่อมอีพ็อกซี่เรซิ่นลงในร่องที่ถูกต้องคืออย่างไร\n', '\nAnswer : หยอดโดยเริ่มจากริมฝั่งใดฝั่งหนึ่งของรอยร้าว\n', '\nPage : 20\n', '\n\nQuestion : หากสังเกตเห็นว่าระดับของวัสดุซ่อมลดลงหลังจากหยอดลงไปแล้ว ควรดำเนินการอย่างไร\n', '\nAnswer : จะต้องหยอดเพิ่มจนกว่าจะแน่ใจว่าวัสดุซ่อมเต็มรอยร้าวแล้ว\n', '\nPage : 20\n', '\n\nQuestion : ควรเอาแนวกั้นรอยร้าวออกเมื่อใด\n', '\nAnswer : หลังจากวัสดุซ่อมเซตตัวแล้ว\n', '\nPage : 21\n', '\n\nQuestion : หลังจากเอาแนวกั้นออกแล้ว ต้องทำสิ่งใดก่อนการตกแต่งผิว\n', '\nAnswer : ทำความสะอาดผิวคอนกรีตบริเวณนั้น\n', '\nPage : 21\n', '\n\nQuestion : ขั้นตอนหลังจากทำความสะอาดผิวคอนกรีตที่หยอดอีพ็อกซี่แล้วคืออะไร\n', '\nAnswer : ผสมปูนฉาบซ่อมตามอัตราส่วน แล้วฉาบทับรอยร้าวที่ได้รับการซ่อมแซมแล้ว\n', '\nPage : 21\n', '\n\nQuestion : การขัดผิวบริเวณที่ฉาบแต่งควรทำเมื่อใด\n', '\nAnswer : หลังจากปูนฉาบแห้ง\n', '\nPage : 22\n', '\n\nQuestion : อุปกรณ์ที่ใช้ในการขัดบริเวณที่ได้ทำการฉาบคืออะไร\n', '\nAnswer : กระดาษทราย\n', '\nP ...
# 120

# %%
new_qa = []

for i in range(0, len(qa_result_list)-1, 3):
    # print(i)
    new_qa.append({
        'Question': qa_result_list[i].replace('Question :', '').replace('++++++++++++++++++++++', '').replace('\n', ''),
        'Answer': qa_result_list[i+1].replace('Answer :', '').replace('++++++++++++++++++++++', '').replace('\n', ''),
        'Page': qa_result_list[i+2].replace('++++++++++++++++++++++', '').replace('\n', '').replace('Page :', '').replace('Page:', '')
    })

# print(new_qa)

new_qa_df = pd.DataFrame(new_qa)
new_qa_df
# Out:
#                                              Question  \
# 0    เอกสารวิธีการ Repair With Epoxy Resin (RP-TN-...
# 1    คุณสมบัติของวัสดุอีพ็อกซี่เรซิ่นที่ใช้ในการซ่...
# 2    อุปกรณ์ที่ใช้ในการวัดความกว้างของรอยร้าวเรียก...
# 3    โครงการที่ระบุในเอกสารวิธีการซ่อมแซมนี้คือโคร...
# 4    อุปกรณ์ที่ใช้ในการซ่อมแซมตามเอกสาร RP-TN-02 ม...
# 5    วัสดุอีพ็อกซี่ Sikadur 52TH มีอัตราส่วนผสมระห...
# 6    วัสดุอีพ็อกซี่ Condur SC เป็นผลิตภัณฑ์ของ Bra...
# 7    ปูนฉาบซ่อม Sika Skim Coat มีอัตราส่วนผสมโดยน้...
# 8    ปูนฉาบซ่อม Renderoc Skim Coat ของ Brand FOSRO...
# 9    ปูนฉาบแต่งตราผึ้ง 124 และ 124L มีอัตราส่วนผสม...
# 10   วัสดุ Conpatch 300 มีอัตราส่วนผสมระหว่างปูนกั...
# 11   ในขั้นตอนการซ่อมแซม การเซาะร่องตามแนวรอยร้าวค...
# 12   ลักษณะร่องที่ได้จากการใช้เครื่องตัดคอนกรีตเซา...
# 13   ก่อนทำการซ่อมแซม ผิวคอนกรีตบริเวณที่จะซ่อมแซม...
# 14   ขั้นตอนการเตรียมผิวหลังจากทำความสะอาดผิวคอนกร...
# 15   การทำแนวกั้นรอยร้าวควรเว้นระยะห่างจากรอยร้าวป...
# 16   วัตถุประสงค์ของการทำแนวกั้นขนานกับแนวรอยร้าวค...
# 17   วิธีการหยอดวัสดุซ่อมอีพ็อกซี่เรซิ่นลงในร่องที...
# 18   หากสังเกตเห็นว่าระดับของวัสดุซ่อมลดลงหลังจากห...
# 19                     ควรเอาแนวกั้นรอยร้าวออกเมื่อใด
# 20   หลังจากเอาแนวกั้นออกแล้ว ต้องทำสิ่งใดก่อนการต...
# 21   ขั้นตอนหลังจากทำความสะอาดผิวคอนกรีตที่หยอดอีพ...
# 22              การขัดผิวบริเวณที่ฉาบแต่งควรทำเมื่อใด
# 23   อุปกรณ์ที่ใช้ในการขัดบริเวณที่ได้ทำการฉาบคืออะไร
# 24   วัตถุประสงค์ของการใช้กระดาษทรายขัดบริเวณที่ฉา...
# 25     เพื่อให้ผิวคอนกรีตมีสีสม่ำเสมอ ควรใช้วิธีการใด
# 26         ขั้นตอนสุดท้ายหลังจากน้ำปูนแห้งแล้วคืออะไร
# 27       ยี่ห้อ (Brand) ของวัสดุ Sikadur 52TH คืออะไร
# 28   รายชื่อปูนฉาบซ่อมยี่ห้อ FOSROC ที่ระบุในเอกสา...
# 29   วัสดุซ่อมแซมรอยร้าว Condur SC ต้องใช้วัสดุ A ...
# 30   รายชื่อปูนฉาบแต่งตราผึ้งที่ระบุให้ใช้ในโครงกา...
# 31   การผสม Conpatch 300 ใช้น้ำหนักน้ำคิดเป็นกี่เท...
# 32             รูปที่ 4 ในเอกสารแสดงขั้นตอนการทำงานใด
# 33   รูปที่ 5 ในเอกสารแสดงการทำความสะอาดรอยร้าวเพื...
# 34   ในขั้นตอนการหยอดอีพ็อกซี่เรซิ่น รูปที่ 7 แสดง...
# 35                      รูปที่ 10 แสดงการปฏิบัติงานใด
# 36   การลูบผิวคอนกรีตด้วยน้ำปูนตามรูปที่ 11 มีวัตถ...
# 37                           รูปที่ 12 แสดงภาพของอะไร
# 38   หมายเลขเอกสาร (Document No.) ของวิธีการซ่อมแซ...
# 39   วันที่ออกเอกสาร (Date) ของ Issue 2 คือวันที่เ...
#
#                                                Answer Page
# 0    ใช้ซ่อมแซมรอยร้าวทั่วไปที่มีความกว้างตั้งแต่ ...   16
# 1    คุณสมบัติของวัสดุอีพ็อกซี่เรซิ่นมีดังนี้:1. เ...   16
# 2                               Crack Width Indicator   16
# 3    PROJECT: SEWERAGE TUNNEL BUNG NONG BON TO CHA...   16
# 4    อุปกรณ์ที่ใช้ในการซ่อมแซมประกอบด้วย:1. เครื่อ...   17
# 5              อัตราส่วนผสม วัสดุ A : วัสดุ B = 2 : 1   17
# 6    เป็นผลิตภัณฑ์ของ Brand CORMIX โดยมีอัตราส่วนผ...   17
# 7                     ปูน : น้ำ = 1 : 0.35 โดยน้ำหนัก   18
# 8                     ปูน : น้ำ = 1 : 0.11 โดยน้ำหนัก   18
# 9                      ปูน : น้ำ = 1 : 0.4 โดยน้ำหนัก   18
# 10                     ปูน : น้ำ = 1 : 0.2 โดยน้ำหนัก   18
# 11                                  3-5 mm. โดยประมาณ   19
# 12                          ร่องที่มีลักษณะคล้ายตัว V   19
# 13          จะต้องปราศจากฝุ่น เศษวัสดุ หรือคราบน้ำมัน   19
# 14                                      เครื่องเป่าลม   19
# 15               ห่างจากรอยร้าวฝั่งละ 5 mm. โดยประมาณ   20
# 16          เพื่อไม่ให้วัสดุซ่อมโดนผิวคอนกรีตส่วนอื่น   20
# 17        หยอดโดยเริ่มจากริมฝั่งใดฝั่งหนึ่งของรอยร้าว   20
# 18   จะต้องหยอดเพิ่มจนกว่าจะแน่ใจว่าวัสดุซ่อมเต็มร...   20
# 19                         หลังจากวัสดุซ่อมเซตตัวแล้ว   21
# 20                    ทำความสะอาดผิวคอนกรีตบริเวณนั้น   21
# 21   ผสมปูนฉาบซ่อมตามอัตราส่วน แล้วฉาบทับรอยร้าวที...   21
# 22                                  หลังจากปูนฉาบแห้ง   22
# 23                                         กระดาษทราย   22
# 24      เพื่อให้มีผิวเรียบเสมอกับผิวคอนกรีตบริเวณอื่น   22
# 25   ผสมปูนฉาบซ่อมให้เหลว ใช้ฟองน้ำหรือลูกกลิ้งชุบ...   22
# 26                   ตรวจสอบรอยร้าวอีกครั้งโดยละเอียด   23
# 27                                               SIKA   17
# 28                                 Renderoc Skim Coat   18
# 29                             4 ส่วน (อัตราส่วน 4:1)   17
# 30   ปูนฉาบแต่งตราผึ้ง 124 และ ปูนฉาบแต่งตราผึ้ง 124L   18
# 31              0.2 เท่า (ปูน:น้ำ = 1:0.2 โดยน้ำหนัก)   18
# 32                       แสดงการเซาะร่องตามแนวรอยร้าว   19
# 33                                 เพื่อเตรียมซ่อมแซม   19
# 34           แสดงทิศทางการหยอดอีพ็อกซี่เรซิ่นลงในร่อง   20
# 35          แสดงการขัดผิวคอนกรีตหลังจากปูนฉาบแห้งแล้ว   22
# 36                            เพื่อให้มีสีผิวสม่ำเสมอ   22
# 37                       แสดงผิวคอนกรีตหลังการซ่อมแซม   23
# 38                                           RP-TN-02   16
# 39                                          20/6/2017   16

# %%
new_qa_df.to_csv(f'{root_path}\\table\\QA_content_3.csv', index=False)

# %% [markdown]
# # 4_Spalling_Edge_Repair

# %%
context = ""
for i in range(len(docs[docs['content'] == '4_Spalling_Edge_Repair'])):
    context += f"Page {docs[docs['content'] == '4_Spalling_Edge_Repair']['page'].iloc[i]}:\n{docs[docs['content'] == '4_Spalling_Edge_Repair']['text'].iloc[i]}\n\n"
    # print(docs[docs['content'] == '2_Repair_With_Cementitious_Mortar']['page'].iloc[i])
# print(context)

# %%
qa_result = generate_qa_from_docs(context, qa_example.iloc[0])

# %%
print(qa_result)
# Out:
# Question : เอกสาร RP-TN-03 มีชื่อหัวข้อเรื่องว่าอย่างไร
# <split>
# Answer : Spalling Edge Repair (การซ่อมแซมขอบชิ้นงานที่แตกบิ่น)
# <split>
# Page : 24
# <split>
#
# Question : เอกสารนี้ใช้สำหรับโครงการก่อสร้างชื่อว่าอะไร
# <split>
# Answer : Sewerage Tunnel Bung Nong Bon to Chaophraya River
# <split>
# Page : 24
# <split>
#
# Question : การซ่อมแซมชิ้นงานที่แตกบิ่น ต้องอ้างอิงเกณฑ์ขนาดความเสียหายจากเอกสารใด
# <split>
# Answer : TB-RP-01 (Guideline For Repair)
# <split>
# Page : 25
# <split>
#
# Question : มอร์ต้าร์ที่ใช้ในการซ่อมแซมจะต้องมีกำลังอัดขั้นต่ำเท่าใด
# <split>
# Answer : สูงกว่า 400 ksc
# <split>
# Page : 25
# <split>
#
# Question : นอกจากกำลังอัดแล้ว วัสดุซ่อมแซมต้องมีคุณสมบัติอย่างไรเกี่ยวกับการหดตัว
# <split>
# Answer : ต้องมีการหดตัวน้อย
# <split>
# Page : 25
# <split>
#
# Question : อุปกรณ์ที่ใช้ในการซ่อมแซมมีอะไรบ้าง (ระบุมา 6 รายการ)
# <split>
# Answer :
# 1. เครื่องเป่าลม
# 2. เกรียง
# 3. ฟองน้ำหรือลูกกลิ้ง
# 4. กระดาษทรายหรือเครื่องขัดผิวคอนกรีต
# 5. ภาชนะใส่วัสดุซ่อม
# 6. เครื่องตัดและใบตัดคอนกรีต
# <split>
# Page : 25
# <split>
#
# Question : วัสดุเชื่อมประสานคอนกรีตที่เสนอขออนุมัติใช้คือผลิตภัณฑ์ใด
# <split>
# Answer : Sikadur 32 TH
# <split>
# Page : 26
# <split>
#
# Question : อัตราส่วนผสมโดยน้ำหนักของ Sikadur 32 TH คือเท่าใด
# <split>
# Answer : A:B = 2:1 โดยน้ำหนัก
# <split>
# Page : 26
# <split>
#
# Question : อีพ็อกซีมอร์ต้าร์ที่เสนอขออนุมัติใช้มีกี่รายการ อะไรบ้าง
# <split>
# Answer : มี 2 รายการ ได้แก่:
# 1. Sikadur 41 CF Normal
# 2. Sikadur 31 CF Normal
# <split>
# Page : 26
# <split>
#
# Question : อัตราส่วนผสมโดยน้ำหนักของ Sikadur 41 CF Normal คือเท่าใด
# <split>
# Answer : วัสดุ A : วัสดุ B : วัสดุ C = 2 : 1 : 2.5
# <split>
# Page : 26
# <split>
#
# Question : อัตราส่วนผสมโดยน้ำหนักของ Sikadur 31 CF Normal คือเท่าใด
# <split>
# Answer : วัสดุ A : วัสดุ B = 2 : 1
# <split>
# Page : 26
# <split>
#
# Question : ปูนฉาบซ่อม Sika Skim Coat มีอัตราส่วนผสมปูนต่อน้ำเท่าใด
# <split>
# Answer : ปูน:น้ำ = 1:0.35 โดยน้ำหนัก
# <split>
# Page : 27
# <split>
#
# Question : ปูนฉาบซ่อม Renderoc Skim Coat เป็นผลิตภัณฑ์ของแบรนด์ใด
# <split>
# Answer : FOSROC
# <split>
# Page : 27
# <split>
#
# Question : อัตราส่วนผสมปูนต่อน้ำของ Renderoc Skim Coat คือเท่าใด
# <split>
# Answer : ปูน:น้ำ = 1:0.11 โดยน้ำหนัก
# <split>
# Page : 27
# <split>
#
# Question : ปูนฉาบแต่งตราผึ้ง 124 มีอัตราส่วนผสมปูนต่อน้ำเท่าใด
# <split>
# Answer : ปูน:น้ำ = 1:0.4 โดยน้ำหนัก
# <split>
# Page : 27
# <split>
#
# Question : ปูนฉาบแต่งตราผึ้ง 124L มีอัตราส่วนผสมปูนต่อน้ำเท่าใด
# <split>
# Answer : ปูน:น้ำ = 1:0.4 โดยน้ำหนัก
# <split>
# Page : 27
# <split>
#
# Question : ปูนฉาบซ่อม Conpatch 300 เป็นผลิตภัณฑ์ของแบรนด์ใด
# <split>
# Answer : CORMIX
# <split>
# Page : 27
# <split>
#
# Question : อัตราส่วนผสมปูนต่อน้ำของ Conpatch 300 คือเท่าใด
# <split>
# Answer : ปูน:น้ำ = 1:0.2 โดยน้ำหนัก
# <split>
# Page : 27
# <split>
#
# Question : ขั้นตอนแรกในการเตรียมการซ่อมแซมผิวคอนกรีตคืออะไร
# <split>
# Answer : ใช้เครื่องตัดคอนกรีตตัดขอบคอนกรีตที่แตกให้เป็นแนวชัดเจน
# <split>
# Page : 28
# <split>
#
# Question : การตัดขอบรอยแตกตามรูปที่ 5 ต้องมีลักษณะอย่างไร
# <split>
# Answer : ตัดขอบรอยแตกให้เป็นแนวเส้นตรง
# <split>
# Page : 28
# <split>
#
# Question : หลังจากตัดขอบคอนกรีตแล้ว ขั้นตอนต่อไปคืออะไร
# <split>
# Answer : ใช้เครื่องเป่าลมเป่าทำความสะอาดผิวคอนกรีต
# <split>
# Page : 29
# <split>
#
# Question : อุปกรณ์ใดที่ใช้ทำความสะอาดผิวคอนกรีตหลังจากการตัดขอบ
# <split>
# Answer : เครื่องเป่าลม
# <split>
# Page : 29
# <split>
#
# Question : การทาวัสดุประสานคอนกรีต Sikadur 32 TH ต้องทาบริเวณใด
# <split>
# Answer : ทาลงบนผิวคอนกรีตที่แตก
# <split>
# Page : 29
# <split>
#
# Question : ในขั้นตอนการพอกอีพ็อกซี่มอร์ต้าร์ ต้องใช้อุปกรณ์ใดในการพอก
# <split>
# Answer : เกรียง
# <split>
# Page : 30
# <split>
#
# Question : การพอกอีพ็อกซี่มอร์ต้าร์ต้องคำนึงถึงรูปร่างอย่างไร
# <split>
# Answer : ต้องพอกให้ได้รูปร่างและขนาดใกล้เคียงกับขนาดเดิม ขอบและมุมจะต้องเหมือนกับรูปร่างเดิม
# <split>
# Page : 30
# <split>
#
# Question : หลังจากอีพ็อกซี่มอร์ต้าร์แห้งแล้ว ต้องทำอย่างไรกับผิวที่ซ่อม
# <split>
# Answer : ใช้เครื่องขัดคอนกรีตและกระดาษทรายขัดผิวที่ทำการซ่อมให้เรียบ
# <split>
# Page : 30
# <split>
#
# Question : หลังจากการขัดแต่งผิวคอนกรีตแล้ว ต้องตรวจสอบสิ่งใดบ้าง
# <split>
# Answer : ตรวจสอบขนาด ขอบ และมุม เพื่อให้แน่ใจว่ามีขนาดที่ถูกต้อง
# <split>
# Page : 30
# <split>
#
# Question : เพื่อให้ผิวที่ซ่อมแซมมีสีที่สม่ำเสมอ ต้องดำเนินการอย่างไรในขั้นตอนที่ 3.6
# <split>
# Answer : ผสมปูนฉาบซ่อมให้เหลวแล้วใช้ฟองน้ำหรือลูกกลิ้งชุบแล้วลูบลงบนพื้นผิวที่ซ่อมแซม
# <split>
# Page : 31
# <split>
#
# Question : อุปกรณ์ใดที่ใช้ในการลูบน้ำปูนลงบนผิวคอนกรีต
# <split>
# Answer : ฟองน้ำหรือลูกกลิ้ง
# <split>
# Page : 31
# <split>
#
# Question : การตรวจสอบขั้นสุดท้ายทำหลังจากขั้นตอนใด
# <split>
# Answer : หลังจากน้ำปูนแห้งแล้ว
# <split>
# Page : 31
# <split>
#
# Question : ในการตรวจสอบขั้นสุดท้าย ต้องดูว่ามีความเสียหายใดเกิดขึ้นหรือไม่
# <split>
# Answer : รอยร้าวหรือรอยแยกของคอนกรีต
# <split>
# Page : 31
# <split>
#
# Question : รูปที่ 1 ในเอกสารแสดงข้อมูลเกี่ยวกับอะไร
# <split>
# Answer : แสดงขนาดรอยบิ่นแตก (วัดขนาดส่วนที่แตกบิ่น)
# <split>
# Page : 25
# <split>
#
# Question : รูปที่ 2 ในเอกสารแสดงวัสดุประเภทใด
# <split>
# Answer : วัสดุเชื่อมประสานคอนกรีตที่ใช้ในการซ่อมแซม (Sikadur 32 TH)
# <split>
# Page : 26
# <split>
#
# Question : รูปที่ 3 ในเอกสารแสดงวัสดุประเภทใด
# <split>
# Answer : วัสดุที่ใช้ในการซ่อมรอยแตกบิ่น (อีพ็อกซีมอร์ต้าร์)
# <split>
# Page : 27
# <split>
#
# Question : รูปที่ 4 ในเอกสารแสดงวัสดุประเภทใด
# <split>
# Answer : วัสดุฉาบที่ใช้ในการซ่อมแซม (Skim Coat Mortar)
# <split>
# Page : 28
# <split>
#
# Question : รูปที่ 5 แสดงการปฏิบัติงานในขั้นตอนใด
# <split>
# Answer : การตัดคอนกรีตบริเวณขอบรอยแตก (ตัดขอบรอยแตกให้เป็นแนวเส้นตรง)
# <split>
# Page : 28
# <split>
#
# Question : รูปที่ 7 แสดงการปฏิบัติงานในขั้นตอนใด
# <split>
# Answer : การทาน้ำยาประสานคอนกรีต
# <split>
# Page : 29
# <split>
#
# Question : รูปที่ 8 แสดงการปฏิบัติงานในขั้นตอนใด
# <split>
# Answer : การพอกอีพ็อกซี่มอร์ต้าร์
# <split>
# Page : 30
# <split>
#
# Question : รูปที่ 9 แสดงการปฏิบัติงานในขั้นตอนใด
# <split>
# Answer : การขัดด้วยเครื่องขัดผิวคอนกรีตและกระดาษทราย
# <split>
# Page : 30
# <split>
#
# Question : รูปที่ 10 แสดงการปฏิบัติงานในขั้นตอนใด
# <split>
# Answer : การลูบผิวคอนกรีตด้วยน้ำปูน
# <split>
# Page : 31
# <split>

# %%
print(qa_result.split('<split>'))
qa_result_list = []
for qa in qa_result.split('<split>'):
    if qa != '++++++++++++++++++++++' and qa != '':
        qa_result_list.append(qa)
print(qa_result_list)
print(len(qa_result_list))
# Out:
# ['Question : เอกสาร RP-TN-03 มีชื่อหัวข้อเรื่องว่าอย่างไร\n', '\nAnswer : Spalling Edge Repair (การซ่อมแซมขอบชิ้นงานที่แตกบิ่น)\n', '\nPage : 24\n', '\n\nQuestion : เอกสารนี้ใช้สำหรับโครงการก่อสร้างชื่อว่าอะไร\n', '\nAnswer : Sewerage Tunnel Bung Nong Bon to Chaophraya River\n', '\nPage : 24\n', '\n\nQuestion : การซ่อมแซมชิ้นงานที่แตกบิ่น ต้องอ้างอิงเกณฑ์ขนาดความเสียหายจากเอกสารใด\n', '\nAnswer : TB-RP-01 (Guideline For Repair)\n', '\nPage : 25\n', '\n\nQuestion : มอร์ต้าร์ที่ใช้ในการซ่อมแซมจะต้องมีกำลังอัดขั้นต่ำเท่าใด\n', '\nAnswer : สูงกว่า 400 ksc\n', '\nPage : 25\n', '\n\nQuestion : นอกจากกำลังอัดแล้ว วัสดุซ่อมแซมต้องมีคุณสมบัติอย่างไรเกี่ยวกับการหดตัว\n', '\nAnswer : ต้องมีการหดตัวน้อย\n', '\nPage : 25\n', '\n\nQuestion : อุปกรณ์ที่ใช้ในการซ่อมแซมมีอะไรบ้าง (ระบุมา 6 รายการ)\n', '\nAnswer : \n1. เครื่องเป่าลม\n2. เกรียง\n3. ฟองน้ำหรือลูกกลิ้ง\n4. กระดาษทรายหรือเครื่องขัดผิวคอนกรีต\n5. ภาชนะใส่วัสดุซ่อม\n6. เครื่องตัดและใบตัดคอนกรีต\n', '\nPage : 25\n', '\n\nQuestion : วัสดุเชื่อมประสานคอนกรีตที่เสนอขออนุมัติใช้คือผลิตภัณฑ์ใด\n', '\nAnswer : Sikadur 32 TH\n', '\nPage : 26\n', '\n\nQuestion : อัตราส่วนผสมโดยน้ำหนักของ Sikadur 32 TH คือเท่าใด\n', '\nAnswer : A:B = 2:1 โดยน้ำหนัก\n', '\nPage : 26\n', '\n\nQuestion : อีพ็อกซีมอร์ต้าร์ที่เสนอขออนุมัติใช้มีกี่รายการ อะไรบ้าง\n', '\nAnswer : มี 2 รายการ ได้แก่:\n1. Sikadur 41 CF Normal\n2. Sikadur 31 CF Normal\n', '\nPage : 26\n', '\n\nQuestion : อัตราส่วนผสมโดยน้ำหนักของ Sikadur 41 CF Normal คือเท่าใด\n', '\nAnswer : วัสดุ A : วัสดุ B : วัสดุ C = 2 : 1 : 2.5\n', '\nPage : 26\n', '\n\nQuestion : อัตราส่วนผสมโดยน้ำหนักของ Sikadur 31 CF Normal คือเท่าใด\n', '\nAnswer : วัสดุ A : วัสดุ B = 2 : 1\n', '\nPage : 26\n', '\n\nQuestion : ปูนฉาบซ่อม Sika Skim Coat มีอัตราส่วนผสมปูนต่อน้ำเท่าใด\n', '\nAnswer : ปูน:น้ำ = 1:0.35 โดยน้ำหนัก\n', '\nPage : 27\n', '\n\nQuestion : ปูนฉาบซ่อม Renderoc Skim Coat เป็นผลิตภัณฑ์ของแบรนด์ใด\n', '\nAnswer : FOSROC\n', '\nPage : 27\n', '\n\nQuestion : อัตราส่วนผสมปูนต่อน้ำของ Renderoc Skim Coat คือเท่าใด\n', '\nAnswer : ปูน:น้ำ = 1:0.11 โดยน้ำหนัก\n', '\nPage : 27\n', '\n\nQuestion : ปูนฉาบแต่งตราผึ้ง 124 มีอัตราส่วนผสมปูนต่อน้ำเท่าใด\n', '\nAnswer : ปูน:น้ำ = 1:0.4 โดยน้ำหนัก\n', '\nPage : 27\n', '\n\nQuestion : ปูนฉาบแต่งตราผึ้ง 124L มีอัตราส่วนผสมปูนต่อน้ำเท่าใด\n', '\nAnswer : ปูน:น้ำ = 1:0.4 โดยน้ำหนัก\n', '\nPage : 27\n', '\n\nQuestion : ปูนฉาบซ่อม Conpatch 300 เป็นผลิตภัณฑ์ของแบรนด์ใด\n', '\nAnswer : CORMIX\n', '\nPage : 27\n', '\n\nQuestion : อัตราส่วนผสมปูนต่อน้ำของ Conpatch 300 คือเท่าใด\n', '\nAnswer : ปูน:น้ำ = 1:0.2 โดยน้ำหนัก\n', '\nPage : 27\n', '\n\nQuestion : ขั้นตอนแรกในการเตรียมการซ่อมแซมผิวคอนกรีตคืออะไร\n', '\nAnswer : ใช้เครื่องตัดคอนกรีตตัดขอบคอนกรีตที่แตกให้เป็นแนวชัดเจน\n', '\nPage : 28\n', '\n\nQuestion : การตัดขอบรอยแตกตามรูปที่ 5 ต้องมีลักษณะอย่างไร\n', '\nAnswer : ตัดขอบรอยแตกให้เป็นแนวเส้นตรง\n', '\nPage : 28\n', '\n\nQuestion : หลังจากตัดขอบคอนกรีตแล้ว ขั้นตอนต่อไปคืออะไร\n', '\nAnswer : ใช้เครื่องเป่าลมเป่าทำความสะอาดผิวคอนกรีต\n', '\nPage : 29\n', '\n\nQuestion : อุปกรณ์ใดที่ใช้ทำความสะอาดผิวคอนกรีตหลังจากการตัดขอบ\n', '\nAnswer : เครื่องเป่าลม\n', '\nPage : 29\n', '\n\nQuestion : การทาวัสดุประสานคอนกรีต Sikadur 32 TH ต้องทาบริเวณใด\n', '\nAnswer : ทาลงบนผิวคอนกรีตที่แตก\n', '\nPage : 29\n', '\n\nQuestion : ในขั้นตอนการพอกอีพ็อกซี่มอร์ต้าร์ ต้องใช้อุปกรณ์ใดในการพอก\n', '\nAnswer : เกรียง\n', '\nPage : 30\n', '\n\nQuestion : การพอกอีพ็อกซี่มอร์ต้าร์ต้องคำนึงถึงรูปร่างอย่างไร\n', '\nAnswer : ต้องพอกให้ได้รูปร่างและขนาดใกล้เคียงกับขนาดเดิม ขอบและมุมจะต้องเหมือนกับรูปร่างเดิม\n', '\nPage : 30\n', '\n\nQuestion : หลังจากอีพ็อกซี่มอร์ต้าร์แห้งแล้ว ต้องทำอย่างไรกับผิวที่ซ่อม\n', '\nAnswer : ใช้เครื่องขัดคอนกรีตและกระดาษทรายขัดผิวที่ทำการซ่อมให้เรียบ\n', '\nPage : 30\n', '\n\nQuestion : หลังจากการขัดแต่งผิวคอนกรีตแล้ว ต้องตรวจสอบสิ่งใดบ้าง\n', '\nAnswer : ตรวจสอบขนาด ขอบ และมุม เพื่อให้แน่ใจว่ามีขนาดที่ถูกต้อง\n', '\nPage : 30\n', '\n\nQuestion : เพื่อให้ผิวที่ซ่อมแซมมีสีที่สม่ำเสมอ ต้องดำเนินการอย่างไรในขั้นตอนที่ 3.6\n', '\nAns ...
# ['Question : เอกสาร RP-TN-03 มีชื่อหัวข้อเรื่องว่าอย่างไร\n', '\nAnswer : Spalling Edge Repair (การซ่อมแซมขอบชิ้นงานที่แตกบิ่น)\n', '\nPage : 24\n', '\n\nQuestion : เอกสารนี้ใช้สำหรับโครงการก่อสร้างชื่อว่าอะไร\n', '\nAnswer : Sewerage Tunnel Bung Nong Bon to Chaophraya River\n', '\nPage : 24\n', '\n\nQuestion : การซ่อมแซมชิ้นงานที่แตกบิ่น ต้องอ้างอิงเกณฑ์ขนาดความเสียหายจากเอกสารใด\n', '\nAnswer : TB-RP-01 (Guideline For Repair)\n', '\nPage : 25\n', '\n\nQuestion : มอร์ต้าร์ที่ใช้ในการซ่อมแซมจะต้องมีกำลังอัดขั้นต่ำเท่าใด\n', '\nAnswer : สูงกว่า 400 ksc\n', '\nPage : 25\n', '\n\nQuestion : นอกจากกำลังอัดแล้ว วัสดุซ่อมแซมต้องมีคุณสมบัติอย่างไรเกี่ยวกับการหดตัว\n', '\nAnswer : ต้องมีการหดตัวน้อย\n', '\nPage : 25\n', '\n\nQuestion : อุปกรณ์ที่ใช้ในการซ่อมแซมมีอะไรบ้าง (ระบุมา 6 รายการ)\n', '\nAnswer : \n1. เครื่องเป่าลม\n2. เกรียง\n3. ฟองน้ำหรือลูกกลิ้ง\n4. กระดาษทรายหรือเครื่องขัดผิวคอนกรีต\n5. ภาชนะใส่วัสดุซ่อม\n6. เครื่องตัดและใบตัดคอนกรีต\n', '\nPage : 25\n', '\n\nQuestion : วัสดุเชื่อมประสานคอนกรีตที่เสนอขออนุมัติใช้คือผลิตภัณฑ์ใด\n', '\nAnswer : Sikadur 32 TH\n', '\nPage : 26\n', '\n\nQuestion : อัตราส่วนผสมโดยน้ำหนักของ Sikadur 32 TH คือเท่าใด\n', '\nAnswer : A:B = 2:1 โดยน้ำหนัก\n', '\nPage : 26\n', '\n\nQuestion : อีพ็อกซีมอร์ต้าร์ที่เสนอขออนุมัติใช้มีกี่รายการ อะไรบ้าง\n', '\nAnswer : มี 2 รายการ ได้แก่:\n1. Sikadur 41 CF Normal\n2. Sikadur 31 CF Normal\n', '\nPage : 26\n', '\n\nQuestion : อัตราส่วนผสมโดยน้ำหนักของ Sikadur 41 CF Normal คือเท่าใด\n', '\nAnswer : วัสดุ A : วัสดุ B : วัสดุ C = 2 : 1 : 2.5\n', '\nPage : 26\n', '\n\nQuestion : อัตราส่วนผสมโดยน้ำหนักของ Sikadur 31 CF Normal คือเท่าใด\n', '\nAnswer : วัสดุ A : วัสดุ B = 2 : 1\n', '\nPage : 26\n', '\n\nQuestion : ปูนฉาบซ่อม Sika Skim Coat มีอัตราส่วนผสมปูนต่อน้ำเท่าใด\n', '\nAnswer : ปูน:น้ำ = 1:0.35 โดยน้ำหนัก\n', '\nPage : 27\n', '\n\nQuestion : ปูนฉาบซ่อม Renderoc Skim Coat เป็นผลิตภัณฑ์ของแบรนด์ใด\n', '\nAnswer : FOSROC\n', '\nPage : 27\n', '\n\nQuestion : อัตราส่วนผสมปูนต่อน้ำของ Renderoc Skim Coat คือเท่าใด\n', '\nAnswer : ปูน:น้ำ = 1:0.11 โดยน้ำหนัก\n', '\nPage : 27\n', '\n\nQuestion : ปูนฉาบแต่งตราผึ้ง 124 มีอัตราส่วนผสมปูนต่อน้ำเท่าใด\n', '\nAnswer : ปูน:น้ำ = 1:0.4 โดยน้ำหนัก\n', '\nPage : 27\n', '\n\nQuestion : ปูนฉาบแต่งตราผึ้ง 124L มีอัตราส่วนผสมปูนต่อน้ำเท่าใด\n', '\nAnswer : ปูน:น้ำ = 1:0.4 โดยน้ำหนัก\n', '\nPage : 27\n', '\n\nQuestion : ปูนฉาบซ่อม Conpatch 300 เป็นผลิตภัณฑ์ของแบรนด์ใด\n', '\nAnswer : CORMIX\n', '\nPage : 27\n', '\n\nQuestion : อัตราส่วนผสมปูนต่อน้ำของ Conpatch 300 คือเท่าใด\n', '\nAnswer : ปูน:น้ำ = 1:0.2 โดยน้ำหนัก\n', '\nPage : 27\n', '\n\nQuestion : ขั้นตอนแรกในการเตรียมการซ่อมแซมผิวคอนกรีตคืออะไร\n', '\nAnswer : ใช้เครื่องตัดคอนกรีตตัดขอบคอนกรีตที่แตกให้เป็นแนวชัดเจน\n', '\nPage : 28\n', '\n\nQuestion : การตัดขอบรอยแตกตามรูปที่ 5 ต้องมีลักษณะอย่างไร\n', '\nAnswer : ตัดขอบรอยแตกให้เป็นแนวเส้นตรง\n', '\nPage : 28\n', '\n\nQuestion : หลังจากตัดขอบคอนกรีตแล้ว ขั้นตอนต่อไปคืออะไร\n', '\nAnswer : ใช้เครื่องเป่าลมเป่าทำความสะอาดผิวคอนกรีต\n', '\nPage : 29\n', '\n\nQuestion : อุปกรณ์ใดที่ใช้ทำความสะอาดผิวคอนกรีตหลังจากการตัดขอบ\n', '\nAnswer : เครื่องเป่าลม\n', '\nPage : 29\n', '\n\nQuestion : การทาวัสดุประสานคอนกรีต Sikadur 32 TH ต้องทาบริเวณใด\n', '\nAnswer : ทาลงบนผิวคอนกรีตที่แตก\n', '\nPage : 29\n', '\n\nQuestion : ในขั้นตอนการพอกอีพ็อกซี่มอร์ต้าร์ ต้องใช้อุปกรณ์ใดในการพอก\n', '\nAnswer : เกรียง\n', '\nPage : 30\n', '\n\nQuestion : การพอกอีพ็อกซี่มอร์ต้าร์ต้องคำนึงถึงรูปร่างอย่างไร\n', '\nAnswer : ต้องพอกให้ได้รูปร่างและขนาดใกล้เคียงกับขนาดเดิม ขอบและมุมจะต้องเหมือนกับรูปร่างเดิม\n', '\nPage : 30\n', '\n\nQuestion : หลังจากอีพ็อกซี่มอร์ต้าร์แห้งแล้ว ต้องทำอย่างไรกับผิวที่ซ่อม\n', '\nAnswer : ใช้เครื่องขัดคอนกรีตและกระดาษทรายขัดผิวที่ทำการซ่อมให้เรียบ\n', '\nPage : 30\n', '\n\nQuestion : หลังจากการขัดแต่งผิวคอนกรีตแล้ว ต้องตรวจสอบสิ่งใดบ้าง\n', '\nAnswer : ตรวจสอบขนาด ขอบ และมุม เพื่อให้แน่ใจว่ามีขนาดที่ถูกต้อง\n', '\nPage : 30\n', '\n\nQuestion : เพื่อให้ผิวที่ซ่อมแซมมีสีที่สม่ำเสมอ ต้องดำเนินการอย่างไรในขั้นตอนที่ 3.6\n', '\nAns ...
# 120

# %%
new_qa = []

for i in range(0, len(qa_result_list)-1, 3):
    # print(i)
    new_qa.append({
        'Question': qa_result_list[i].replace('Question :', '').replace('++++++++++++++++++++++', '').replace('\n', ''),
        'Answer': qa_result_list[i+1].replace('Answer :', '').replace('++++++++++++++++++++++', '').replace('\n', ''),
        'Page': qa_result_list[i+2].replace('++++++++++++++++++++++', '').replace('\n', '').replace('Page :', '').replace('Page:', '')
    })

# print(new_qa)

new_qa_df = pd.DataFrame(new_qa)
new_qa_df
# Out:
#                                              Question  \
# 0        เอกสาร RP-TN-03 มีชื่อหัวข้อเรื่องว่าอย่างไร
# 1        เอกสารนี้ใช้สำหรับโครงการก่อสร้างชื่อว่าอะไร
# 2    การซ่อมแซมชิ้นงานที่แตกบิ่น ต้องอ้างอิงเกณฑ์ข...
# 3    มอร์ต้าร์ที่ใช้ในการซ่อมแซมจะต้องมีกำลังอัดขั...
# 4    นอกจากกำลังอัดแล้ว วัสดุซ่อมแซมต้องมีคุณสมบัต...
# 5    อุปกรณ์ที่ใช้ในการซ่อมแซมมีอะไรบ้าง (ระบุมา 6...
# 6    วัสดุเชื่อมประสานคอนกรีตที่เสนอขออนุมัติใช้คื...
# 7    อัตราส่วนผสมโดยน้ำหนักของ Sikadur 32 TH คือเท...
# 8    อีพ็อกซีมอร์ต้าร์ที่เสนอขออนุมัติใช้มีกี่รายก...
# 9    อัตราส่วนผสมโดยน้ำหนักของ Sikadur 41 CF Norma...
# 10   อัตราส่วนผสมโดยน้ำหนักของ Sikadur 31 CF Norma...
# 11   ปูนฉาบซ่อม Sika Skim Coat มีอัตราส่วนผสมปูนต่...
# 12   ปูนฉาบซ่อม Renderoc Skim Coat เป็นผลิตภัณฑ์ขอ...
# 13   อัตราส่วนผสมปูนต่อน้ำของ Renderoc Skim Coat ค...
# 14   ปูนฉาบแต่งตราผึ้ง 124 มีอัตราส่วนผสมปูนต่อน้ำ...
# 15   ปูนฉาบแต่งตราผึ้ง 124L มีอัตราส่วนผสมปูนต่อน้...
# 16   ปูนฉาบซ่อม Conpatch 300 เป็นผลิตภัณฑ์ของแบรนด์ใด
# 17    อัตราส่วนผสมปูนต่อน้ำของ Conpatch 300 คือเท่าใด
# 18   ขั้นตอนแรกในการเตรียมการซ่อมแซมผิวคอนกรีตคืออะไร
# 19     การตัดขอบรอยแตกตามรูปที่ 5 ต้องมีลักษณะอย่างไร
# 20       หลังจากตัดขอบคอนกรีตแล้ว ขั้นตอนต่อไปคืออะไร
# 21   อุปกรณ์ใดที่ใช้ทำความสะอาดผิวคอนกรีตหลังจากกา...
# 22   การทาวัสดุประสานคอนกรีต Sikadur 32 TH ต้องทาบ...
# 23   ในขั้นตอนการพอกอีพ็อกซี่มอร์ต้าร์ ต้องใช้อุปก...
# 24   การพอกอีพ็อกซี่มอร์ต้าร์ต้องคำนึงถึงรูปร่างอย...
# 25   หลังจากอีพ็อกซี่มอร์ต้าร์แห้งแล้ว ต้องทำอย่าง...
# 26   หลังจากการขัดแต่งผิวคอนกรีตแล้ว ต้องตรวจสอบสิ...
# 27   เพื่อให้ผิวที่ซ่อมแซมมีสีที่สม่ำเสมอ ต้องดำเน...
# 28        อุปกรณ์ใดที่ใช้ในการลูบน้ำปูนลงบนผิวคอนกรีต
# 29            การตรวจสอบขั้นสุดท้ายทำหลังจากขั้นตอนใด
# 30   ในการตรวจสอบขั้นสุดท้าย ต้องดูว่ามีความเสียหา...
# 31           รูปที่ 1 ในเอกสารแสดงข้อมูลเกี่ยวกับอะไร
# 32                 รูปที่ 2 ในเอกสารแสดงวัสดุประเภทใด
# 33                 รูปที่ 3 ในเอกสารแสดงวัสดุประเภทใด
# 34                 รูปที่ 4 ในเอกสารแสดงวัสดุประเภทใด
# 35              รูปที่ 5 แสดงการปฏิบัติงานในขั้นตอนใด
# 36              รูปที่ 7 แสดงการปฏิบัติงานในขั้นตอนใด
# 37              รูปที่ 8 แสดงการปฏิบัติงานในขั้นตอนใด
# 38              รูปที่ 9 แสดงการปฏิบัติงานในขั้นตอนใด
# 39             รูปที่ 10 แสดงการปฏิบัติงานในขั้นตอนใด
#
#                                                Answer Page
# 0    Spalling Edge Repair (การซ่อมแซมขอบชิ้นงานที่...   24
# 1    Sewerage Tunnel Bung Nong Bon to Chaophraya R...   24
# 2                     TB-RP-01 (Guideline For Repair)   25
# 3                                     สูงกว่า 400 ksc   25
# 4                                  ต้องมีการหดตัวน้อย   25
# 5    1. เครื่องเป่าลม2. เกรียง3. ฟองน้ำหรือลูกกลิ้...   25
# 6                                       Sikadur 32 TH   26
# 7                                A:B = 2:1 โดยน้ำหนัก   26
# 8    มี 2 รายการ ได้แก่:1. Sikadur 41 CF Normal2. ...   26
# 9           วัสดุ A : วัสดุ B : วัสดุ C = 2 : 1 : 2.5   26
# 10                          วัสดุ A : วัสดุ B = 2 : 1   26
# 11                        ปูน:น้ำ = 1:0.35 โดยน้ำหนัก   27
# 12                                             FOSROC   27
# 13                        ปูน:น้ำ = 1:0.11 โดยน้ำหนัก   27
# 14                         ปูน:น้ำ = 1:0.4 โดยน้ำหนัก   27
# 15                         ปูน:น้ำ = 1:0.4 โดยน้ำหนัก   27
# 16                                             CORMIX   27
# 17                         ปูน:น้ำ = 1:0.2 โดยน้ำหนัก   27
# 18   ใช้เครื่องตัดคอนกรีตตัดขอบคอนกรีตที่แตกให้เป็...   28
# 19                      ตัดขอบรอยแตกให้เป็นแนวเส้นตรง   28
# 20          ใช้เครื่องเป่าลมเป่าทำความสะอาดผิวคอนกรีต   29
# 21                                      เครื่องเป่าลม   29
# 22                             ทาลงบนผิวคอนกรีตที่แตก   29
# 23                                             เกรียง   30
# 24   ต้องพอกให้ได้รูปร่างและขนาดใกล้เคียงกับขนาดเด...   30
# 25   ใช้เครื่องขัดคอนกรีตและกระดาษทรายขัดผิวที่ทำก...   30
# 26   ตรวจสอบขนาด ขอบ และมุม เพื่อให้แน่ใจว่ามีขนาด...   30
# 27   ผสมปูนฉาบซ่อมให้เหลวแล้วใช้ฟองน้ำหรือลูกกลิ้ง...   31
# 28                                 ฟองน้ำหรือลูกกลิ้ง   31
# 29                              หลังจากน้ำปูนแห้งแล้ว   31
# 30                        รอยร้าวหรือรอยแยกของคอนกรีต   31
# 31         แสดงขนาดรอยบิ่นแตก (วัดขนาดส่วนที่แตกบิ่น)   25
# 32   วัสดุเชื่อมประสานคอนกรีตที่ใช้ในการซ่อมแซม (S...   26
# 33   วัสดุที่ใช้ในการซ่อมรอยแตกบิ่น (อีพ็อกซีมอร์ต...   27
# 34      วัสดุฉาบที่ใช้ในการซ่อมแซม (Skim Coat Mortar)   28
# 35   การตัดคอนกรีตบริเวณขอบรอยแตก (ตัดขอบรอยแตกให้...   28
# 36                            การทาน้ำยาประสานคอนกรีต   29
# 37                           การพอกอีพ็อกซี่มอร์ต้าร์   30
# 38        การขัดด้วยเครื่องขัดผิวคอนกรีตและกระดาษทราย   30
# 39                         การลูบผิวคอนกรีตด้วยน้ำปูน   31

# %%
new_qa_df.to_csv(f'{root_path}\\table\\QA_content_4.csv', index=False)

# %% [markdown]
# # 5_Voids_And_Blowholes_Repair

# %%
context = ""
for i in range(len(docs[docs['content'] == '5_Voids_And_Blowholes_Repair'])):
    context += f"Page {docs[docs['content'] == '5_Voids_And_Blowholes_Repair']['page'].iloc[i]}:\n{docs[docs['content'] == '5_Voids_And_Blowholes_Repair']['text'].iloc[i]}\n\n"
    # print(docs[docs['content'] == '2_Repair_With_Cementitious_Mortar']['page'].iloc[i])
# print(context)

# %%
qa_result = generate_qa_from_docs(context, qa_example.iloc[0])

# %%
print(qa_result.split('<split>'))
qa_result_list = []
for qa in qa_result.split('<split>'):
    if qa != '++++++++++++++++++++++' and qa != '':
        qa_result_list.append(qa)
print(qa_result_list)
print(len(qa_result_list))
# Out:
# ['Question : เอกสารหมายเลข RP-TN-04 กล่าวถึงวิธีการซ่อมแซมความเสียหายประเภทใด', '\n++++++++++++++++++++++\nAnswer : การซ่อมแซมรูฟองอากาศ (Voids and Blowholes Repair)', '\n++++++++++++++++++++++\nPage : 32', '\n\nQuestion : ชื่อโครงการที่ระบุในเอกสารนี้คืออะไร', '\n++++++++++++++++++++++\nAnswer : Sewerage Tunnel Bung Nong Bon to Chaophraya River', '\n++++++++++++++++++++++\nPage : 32', '\n\nQuestion : เอกสารฉบับนี้ (RP-TN-04) ใช้สำหรับการซ่อมแซมรูฟองอากาศที่มีขนาดความกว้างและความลึกเท่าใด', '\n++++++++++++++++++++++\nAnswer : ขนาดความกว้างและความลึกมากกว่า 2 mm. แต่ไม่เกิน 10 mm.', '\n++++++++++++++++++++++\nPage : 33', '\n\nQuestion : คุณสมบัติของปูนฉาบซ่อมที่กำหนดให้ใช้ในงานซ่อมแซมรูฟองอากาศคืออะไร', '\n++++++++++++++++++++++\nAnswer : ต้องมีคุณสมบัติการยึดเกาะที่ดี และมีสีที่ใกล้เคียงกับผิวคอนกรีต', '\n++++++++++++++++++++++\nPage : 33', '\n\nQuestion : อุปกรณ์ข้อที่ 1.1 ที่ใช้ในการซ่อมแซมคืออะไร', '\n++++++++++++++++++++++\nAnswer : เครื่องเป่าลม', '\n++++++++++++++++++++++\nPage : 33', '\n\nQuestion : อุปกรณ์ข้อที่ 1.2 ที่ใช้ในการซ่อมแซมคืออะไร', '\n++++++++++++++++++++++\nAnswer : เกรียง', '\n++++++++++++++++++++++\nPage : 33', '\n\nQuestion : อุปกรณ์ข้อที่ 1.3 ที่ระบุไว้สำหรับการซ่อมแซมคืออะไร', '\n++++++++++++++++++++++\nAnswer : ฟองน้ำหรือลูกกลิ้ง', '\n++++++++++++++++++++++\nPage : 33', '\n\nQuestion : อุปกรณ์ข้อที่ 1.4 ที่ใช้ในการขัดผิวคืออะไร', '\n++++++++++++++++++++++\nAnswer : กระดาษทราย', '\n++++++++++++++++++++++\nPage : 33', '\n\nQuestion : อุปกรณ์ข้อที่ 1.5 สำหรับใส่วัสดุซ่อมคืออะไร', '\n++++++++++++++++++++++\nAnswer : ภาชนะสำหรับใส่วัสดุซ่อม', '\n++++++++++++++++++++++\nPage : 33', '\n\nQuestion : รูปที่ 1 ในเอกสารแสดงภาพของสิ่งใด', '\n++++++++++++++++++++++\nAnswer : รูฟองอากาศที่มีขนาดมากกว่า 2 mm.', '\n++++++++++++++++++++++\nPage : 33', '\n\nQuestion : วัสดุ Sika Skim Coat มีอัตราส่วนผสม (ปูน:น้ำ) โดยน้ำหนักเท่าใด', '\n++++++++++++++++++++++\nAnswer : ปูน:น้ำ = 1:0.35 โดยน้ำหนัก', '\n++++++++++++++++++++++\nPage : 34', '\n\nQuestion : วัสดุ Renderoc Skim Coat เป็นผลิตภัณฑ์ของ Brand ใด', '\n++++++++++++++++++++++\nAnswer : FOSROC', '\n++++++++++++++++++++++\nPage : 34', '\n\nQuestion : อัตราส่วนผสมของ Renderoc Skim Coat (ปูน:น้ำ) คือเท่าใด', '\n++++++++++++++++++++++\nAnswer : ปูน:น้ำ = 1:0.11 โดยน้ำหนัก', '\n++++++++++++++++++++++\nPage : 34', '\n\nQuestion : ปูนฉาบแต่งตราผึ้ง 124 มีอัตราส่วนผสม (ปูน:น้ำ) เท่าใด', '\n++++++++++++++++++++++\nAnswer : ปูน:น้ำ = 1:0.4 โดยน้ำหนัก', '\n++++++++++++++++++++++\nPage : 34', '\n\nQuestion : ปูนฉาบแต่งตราผึ้ง 124L มีอัตราส่วนผสม (ปูน:น้ำ) เท่าใด', '\n++++++++++++++++++++++\nAnswer : ปูน:น้ำ = 1:0.4 โดยน้ำหนัก', '\n++++++++++++++++++++++\nPage : 34', '\n\nQuestion : วัสดุ Conpatch 300 เป็นผลิตภัณฑ์ของ Brand ใด', '\n++++++++++++++++++++++\nAnswer : CORMIX', '\n++++++++++++++++++++++\nPage : 34', '\n\nQuestion : อัตราส่วนผสมของ Conpatch 300 (ปูน:น้ำ) คือเท่าใด', '\n++++++++++++++++++++++\nAnswer : ปูน:น้ำ = 1:0.2 โดยน้ำหนัก', '\n++++++++++++++++++++++\nPage : 34', '\n\nQuestion : หน่วยวัดที่ใช้กำหนดอัตราส่วนผสมของปูนและน้ำในตารางวัสดุคืออะไร', '\n++++++++++++++++++++++\nAnswer : โดยน้ำหนัก', '\n++++++++++++++++++++++\nPage : 34', '\n\nQuestion : รายชื่อวัสดุลำดับที่ 3 ในตารางวัสดุที่ใช้ในการซ่อมแซมคืออะไร', '\n++++++++++++++++++++++\nAnswer : ปูนฉาบแต่งตราผึ้ง 124', '\n++++++++++++++++++++++\nPage : 34', '\n\nQuestion : ขั้นตอนแรก (ข้อ 3.1) ในการซ่อมแซมผิวคอนกรีตคืออะไร', '\n++++++++++++++++++++++\nAnswer : ทำความสะอาดผิวคอนกรีตบริเวณที่เกิดรูฟองอากาศ โดยใช้เครื่องเป่าลม', '\n++++++++++++++++++++++\nPage : 35', '\n\nQuestion : ในขั้นตอนที่ 3.2 ต้องใช้อุปกรณ์ใดในการลูบที่ผิวคอนกรีต', '\n++++++++++++++++++++++\nAnswer : ฟองน้ำหรือลูกกลิ้งชุบน้ำ', '\n++++++++++++++++++++++\nPage : 35', '\n\nQuestion : รูปที่ 3 แสดงขั้นตอนการทำงานใด', '\n++++++++++++++++++++++\nAnswer : แสดงขั้นตอนการลูบผิวคอนกรีตด้วยฟองน้ำ', '\n++++++++++++++++++++++\nPage : 35', '\n\nQuestion : ในขั้นตอนที่ 3.3 ต้องฉาบอุดรูฟองอากาศในขณะที่ผิวคอนกรีตอยู่ในสภาพใด', '\n++++++++++++++++++++++\nAnswer : ฉ ...
# ['Question : เอกสารหมายเลข RP-TN-04 กล่าวถึงวิธีการซ่อมแซมความเสียหายประเภทใด', '\n++++++++++++++++++++++\nAnswer : การซ่อมแซมรูฟองอากาศ (Voids and Blowholes Repair)', '\n++++++++++++++++++++++\nPage : 32', '\n\nQuestion : ชื่อโครงการที่ระบุในเอกสารนี้คืออะไร', '\n++++++++++++++++++++++\nAnswer : Sewerage Tunnel Bung Nong Bon to Chaophraya River', '\n++++++++++++++++++++++\nPage : 32', '\n\nQuestion : เอกสารฉบับนี้ (RP-TN-04) ใช้สำหรับการซ่อมแซมรูฟองอากาศที่มีขนาดความกว้างและความลึกเท่าใด', '\n++++++++++++++++++++++\nAnswer : ขนาดความกว้างและความลึกมากกว่า 2 mm. แต่ไม่เกิน 10 mm.', '\n++++++++++++++++++++++\nPage : 33', '\n\nQuestion : คุณสมบัติของปูนฉาบซ่อมที่กำหนดให้ใช้ในงานซ่อมแซมรูฟองอากาศคืออะไร', '\n++++++++++++++++++++++\nAnswer : ต้องมีคุณสมบัติการยึดเกาะที่ดี และมีสีที่ใกล้เคียงกับผิวคอนกรีต', '\n++++++++++++++++++++++\nPage : 33', '\n\nQuestion : อุปกรณ์ข้อที่ 1.1 ที่ใช้ในการซ่อมแซมคืออะไร', '\n++++++++++++++++++++++\nAnswer : เครื่องเป่าลม', '\n++++++++++++++++++++++\nPage : 33', '\n\nQuestion : อุปกรณ์ข้อที่ 1.2 ที่ใช้ในการซ่อมแซมคืออะไร', '\n++++++++++++++++++++++\nAnswer : เกรียง', '\n++++++++++++++++++++++\nPage : 33', '\n\nQuestion : อุปกรณ์ข้อที่ 1.3 ที่ระบุไว้สำหรับการซ่อมแซมคืออะไร', '\n++++++++++++++++++++++\nAnswer : ฟองน้ำหรือลูกกลิ้ง', '\n++++++++++++++++++++++\nPage : 33', '\n\nQuestion : อุปกรณ์ข้อที่ 1.4 ที่ใช้ในการขัดผิวคืออะไร', '\n++++++++++++++++++++++\nAnswer : กระดาษทราย', '\n++++++++++++++++++++++\nPage : 33', '\n\nQuestion : อุปกรณ์ข้อที่ 1.5 สำหรับใส่วัสดุซ่อมคืออะไร', '\n++++++++++++++++++++++\nAnswer : ภาชนะสำหรับใส่วัสดุซ่อม', '\n++++++++++++++++++++++\nPage : 33', '\n\nQuestion : รูปที่ 1 ในเอกสารแสดงภาพของสิ่งใด', '\n++++++++++++++++++++++\nAnswer : รูฟองอากาศที่มีขนาดมากกว่า 2 mm.', '\n++++++++++++++++++++++\nPage : 33', '\n\nQuestion : วัสดุ Sika Skim Coat มีอัตราส่วนผสม (ปูน:น้ำ) โดยน้ำหนักเท่าใด', '\n++++++++++++++++++++++\nAnswer : ปูน:น้ำ = 1:0.35 โดยน้ำหนัก', '\n++++++++++++++++++++++\nPage : 34', '\n\nQuestion : วัสดุ Renderoc Skim Coat เป็นผลิตภัณฑ์ของ Brand ใด', '\n++++++++++++++++++++++\nAnswer : FOSROC', '\n++++++++++++++++++++++\nPage : 34', '\n\nQuestion : อัตราส่วนผสมของ Renderoc Skim Coat (ปูน:น้ำ) คือเท่าใด', '\n++++++++++++++++++++++\nAnswer : ปูน:น้ำ = 1:0.11 โดยน้ำหนัก', '\n++++++++++++++++++++++\nPage : 34', '\n\nQuestion : ปูนฉาบแต่งตราผึ้ง 124 มีอัตราส่วนผสม (ปูน:น้ำ) เท่าใด', '\n++++++++++++++++++++++\nAnswer : ปูน:น้ำ = 1:0.4 โดยน้ำหนัก', '\n++++++++++++++++++++++\nPage : 34', '\n\nQuestion : ปูนฉาบแต่งตราผึ้ง 124L มีอัตราส่วนผสม (ปูน:น้ำ) เท่าใด', '\n++++++++++++++++++++++\nAnswer : ปูน:น้ำ = 1:0.4 โดยน้ำหนัก', '\n++++++++++++++++++++++\nPage : 34', '\n\nQuestion : วัสดุ Conpatch 300 เป็นผลิตภัณฑ์ของ Brand ใด', '\n++++++++++++++++++++++\nAnswer : CORMIX', '\n++++++++++++++++++++++\nPage : 34', '\n\nQuestion : อัตราส่วนผสมของ Conpatch 300 (ปูน:น้ำ) คือเท่าใด', '\n++++++++++++++++++++++\nAnswer : ปูน:น้ำ = 1:0.2 โดยน้ำหนัก', '\n++++++++++++++++++++++\nPage : 34', '\n\nQuestion : หน่วยวัดที่ใช้กำหนดอัตราส่วนผสมของปูนและน้ำในตารางวัสดุคืออะไร', '\n++++++++++++++++++++++\nAnswer : โดยน้ำหนัก', '\n++++++++++++++++++++++\nPage : 34', '\n\nQuestion : รายชื่อวัสดุลำดับที่ 3 ในตารางวัสดุที่ใช้ในการซ่อมแซมคืออะไร', '\n++++++++++++++++++++++\nAnswer : ปูนฉาบแต่งตราผึ้ง 124', '\n++++++++++++++++++++++\nPage : 34', '\n\nQuestion : ขั้นตอนแรก (ข้อ 3.1) ในการซ่อมแซมผิวคอนกรีตคืออะไร', '\n++++++++++++++++++++++\nAnswer : ทำความสะอาดผิวคอนกรีตบริเวณที่เกิดรูฟองอากาศ โดยใช้เครื่องเป่าลม', '\n++++++++++++++++++++++\nPage : 35', '\n\nQuestion : ในขั้นตอนที่ 3.2 ต้องใช้อุปกรณ์ใดในการลูบที่ผิวคอนกรีต', '\n++++++++++++++++++++++\nAnswer : ฟองน้ำหรือลูกกลิ้งชุบน้ำ', '\n++++++++++++++++++++++\nPage : 35', '\n\nQuestion : รูปที่ 3 แสดงขั้นตอนการทำงานใด', '\n++++++++++++++++++++++\nAnswer : แสดงขั้นตอนการลูบผิวคอนกรีตด้วยฟองน้ำ', '\n++++++++++++++++++++++\nPage : 35', '\n\nQuestion : ในขั้นตอนที่ 3.3 ต้องฉาบอุดรูฟองอากาศในขณะที่ผิวคอนกรีตอยู่ในสภาพใด', '\n++++++++++++++++++++++\nAnswer : ฉ ...
# 120

# %%
new_qa = []

for i in range(0, len(qa_result_list)-1, 3):
    # print(i)
    new_qa.append({
        'Question': qa_result_list[i].replace('Question :', '').replace('++++++++++++++++++++++', '').replace('\n', ''),
        'Answer': qa_result_list[i+1].replace('Answer :', '').replace('++++++++++++++++++++++', '').replace('\n', ''),
        'Page': qa_result_list[i+2].replace('++++++++++++++++++++++', '').replace('\n', '').replace('Page :', '').replace('Page:', '')
    })

# print(new_qa)

new_qa_df = pd.DataFrame(new_qa)
new_qa_df
# Out:
#                                              Question  \
# 0    เอกสารหมายเลข RP-TN-04 กล่าวถึงวิธีการซ่อมแซม...
# 1                ชื่อโครงการที่ระบุในเอกสารนี้คืออะไร
# 2    เอกสารฉบับนี้ (RP-TN-04) ใช้สำหรับการซ่อมแซมร...
# 3    คุณสมบัติของปูนฉาบซ่อมที่กำหนดให้ใช้ในงานซ่อม...
# 4         อุปกรณ์ข้อที่ 1.1 ที่ใช้ในการซ่อมแซมคืออะไร
# 5         อุปกรณ์ข้อที่ 1.2 ที่ใช้ในการซ่อมแซมคืออะไร
# 6    อุปกรณ์ข้อที่ 1.3 ที่ระบุไว้สำหรับการซ่อมแซมค...
# 7          อุปกรณ์ข้อที่ 1.4 ที่ใช้ในการขัดผิวคืออะไร
# 8         อุปกรณ์ข้อที่ 1.5 สำหรับใส่วัสดุซ่อมคืออะไร
# 9                   รูปที่ 1 ในเอกสารแสดงภาพของสิ่งใด
# 10   วัสดุ Sika Skim Coat มีอัตราส่วนผสม (ปูน:น้ำ)...
# 11   วัสดุ Renderoc Skim Coat เป็นผลิตภัณฑ์ของ Bra...
# 12   อัตราส่วนผสมของ Renderoc Skim Coat (ปูน:น้ำ) ...
# 13   ปูนฉาบแต่งตราผึ้ง 124 มีอัตราส่วนผสม (ปูน:น้ำ...
# 14   ปูนฉาบแต่งตราผึ้ง 124L มีอัตราส่วนผสม (ปูน:น้...
# 15       วัสดุ Conpatch 300 เป็นผลิตภัณฑ์ของ Brand ใด
# 16   อัตราส่วนผสมของ Conpatch 300 (ปูน:น้ำ) คือเท่าใด
# 17   หน่วยวัดที่ใช้กำหนดอัตราส่วนผสมของปูนและน้ำใน...
# 18   รายชื่อวัสดุลำดับที่ 3 ในตารางวัสดุที่ใช้ในกา...
# 19   ขั้นตอนแรก (ข้อ 3.1) ในการซ่อมแซมผิวคอนกรีตคื...
# 20   ในขั้นตอนที่ 3.2 ต้องใช้อุปกรณ์ใดในการลูบที่ผ...
# 21                     รูปที่ 3 แสดงขั้นตอนการทำงานใด
# 22   ในขั้นตอนที่ 3.3 ต้องฉาบอุดรูฟองอากาศในขณะที่...
# 23   เครื่องมือที่ใช้ในการฉาบอุดรูฟองอากาศในขั้นตอ...
# 24              รูปที่ 4 ในเอกสารแสดงการทำงานลักษณะใด
# 25   ขั้นตอนที่ 3.4 หลังจากปูนฉาบแห้งแล้วต้องทำอย่...
# 26   วัตถุประสงค์ของการขัดด้วยกระดาษทรายในขั้นตอนท...
# 27                     รูปที่ 5 แสดงขั้นตอนการทำงานใด
# 28   ในขั้นตอนที่ 3.5 ต้องเตรียมปูนฉาบซ่อมในลักษณะ...
# 29   อุปกรณ์ที่ใช้ในการลูบปูนฉาบเหลวบนผิวคอนกรีตใน...
# 30   วัตถุประสงค์ของการลูบปูนฉาบเหลวให้ทั่วในขั้นต...
# 31                      รูปที่ 6 แสดงการทำงานลักษณะใด
# 32                 ขั้นตอนที่ 3.6 คือการตรวจสอบสิ่งใด
# 33          การตรวจสอบในขั้นตอนที่ 3.6 จะทำได้เมื่อใด
# 34                          รูปที่ 7 แสดงภาพของสิ่งใด
# 35        เอกสาร RP-TN-04 ฉบับนี้เป็น Issue ที่เท่าใด
# 36   วันที่ (Date) ที่ระบุในเอกสาร RP-TN-04 ฉบับนี...
# 37   จากตารางวัสดุ หน้า 34 แบรนด์ SIKA ใช้ผลิตภัณฑ...
# 38   จากตารางวัสดุ หน้า 34 ปูนตราผึ้งรายการที่ 4 ค...
# 39   ขั้นตอนการเตรียมผิว (ข้อ 3.1 และ 3.2) มีอุปกร...
#
#                                                Answer       Page
# 0    การซ่อมแซมรูฟองอากาศ (Voids and Blowholes Rep...  Page : 32
# 1    Sewerage Tunnel Bung Nong Bon to Chaophraya R...  Page : 32
# 2    ขนาดความกว้างและความลึกมากกว่า 2 mm. แต่ไม่เก...  Page : 33
# 3    ต้องมีคุณสมบัติการยึดเกาะที่ดี และมีสีที่ใกล้...  Page : 33
# 4                                       เครื่องเป่าลม  Page : 33
# 5                                              เกรียง  Page : 33
# 6                                  ฟองน้ำหรือลูกกลิ้ง  Page : 33
# 7                                          กระดาษทราย  Page : 33
# 8                             ภาชนะสำหรับใส่วัสดุซ่อม  Page : 33
# 9                    รูฟองอากาศที่มีขนาดมากกว่า 2 mm.  Page : 33
# 10                        ปูน:น้ำ = 1:0.35 โดยน้ำหนัก  Page : 34
# 11                                             FOSROC  Page : 34
# 12                        ปูน:น้ำ = 1:0.11 โดยน้ำหนัก  Page : 34
# 13                         ปูน:น้ำ = 1:0.4 โดยน้ำหนัก  Page : 34
# 14                         ปูน:น้ำ = 1:0.4 โดยน้ำหนัก  Page : 34
# 15                                             CORMIX  Page : 34
# 16                         ปูน:น้ำ = 1:0.2 โดยน้ำหนัก  Page : 34
# 17                                         โดยน้ำหนัก  Page : 34
# 18                              ปูนฉาบแต่งตราผึ้ง 124  Page : 34
# 19   ทำความสะอาดผิวคอนกรีตบริเวณที่เกิดรูฟองอากาศ ...  Page : 35
# 20                           ฟองน้ำหรือลูกกลิ้งชุบน้ำ  Page : 35
# 21              แสดงขั้นตอนการลูบผิวคอนกรีตด้วยฟองน้ำ  Page : 35
# 22                ฉาบในขณะที่ผิวคอนกรีตยังชุ่มน้ำอยู่  Page : 35
# 23                                   เกรียงหรือฟองน้ำ  Page : 35
# 24                            แสดงการฉาบอุดรูฟองอากาศ  Page : 35
# 25   ใช้กระดาษทรายขัดบริเวณที่ฉาบอุดให้เรียบเสมอกั...  Page : 36
# 26   เพื่อให้บริเวณที่ฉาบอุดเรียบเสมอกับผิวคอนกรีต...  Page : 36
# 27                        แสดงการขัดผิวด้วยกระดาษทราย  Page : 36
# 28                               ผสมปูนฉาบซ่อมให้เหลว  Page : 36
# 29                                 ฟองน้ำหรือลูกกลิ้ง  Page : 36
# 30                               เพื่อให้มีสีสม่ำเสมอ  Page : 36
# 31                 แสดงการลูบผิวคอนกรีตด้วยปูนฉาบเหลว  Page : 36
# 32   ตรวจสอบดูว่ามีรอยร้าวหรือความเสียหายอื่นเกิดข...  Page : 37
# 33                              หลังจากน้ำปูนแห้งแล้ว  Page : 37
# 34                แสดงผิวคอนกรีตที่ผ่านการซ่อมแซมแล้ว  Page : 37
# 35                                            Issue 2  Page : 33
# 36                                          20/6/2017  Page : 33
# 37                                     Sika Skim Coat  Page : 34
# 38                             ปูนฉาบแต่งตราผึ้ง 124L  Page : 34
# 39   2 ชนิด ได้แก่ เครื่องเป่าลม และ ฟองน้ำ (หรือล...  Page : 35

# %%
new_qa_df.to_csv(f'{root_path}\\table\\QA_content_5.csv', index=False)

# %% [markdown]
# # 6_Voids_And_Blowholes_Repair_With_High_Strength_Mortar

# %%
context = ""
for i in range(len(docs[docs['content'] == '6_Voids_And_Blowholes_Repair_With_High_Strength_Mortar'])):
    context += f"Page {docs[docs['content'] == '6_Voids_And_Blowholes_Repair_With_High_Strength_Mortar']['page'].iloc[i]}:\n{docs[docs['content'] == '6_Voids_And_Blowholes_Repair_With_High_Strength_Mortar']['text'].iloc[i]}\n\n"
    # print(docs[docs['content'] == '2_Repair_With_Cementitious_Mortar']['page'].iloc[i])
# print(context)

# %%
qa_result = generate_qa_from_docs(context, qa_example.iloc[0])

# %%
print(qa_result.split('<split>'))
qa_result_list = []
for qa in qa_result.split('<split>'):
    if qa != '++++++++++++++++++++++' and qa != '':
        qa_result_list.append(qa)
print(qa_result_list)
print(len(qa_result_list))
# Out:
# ['Question : เอกสารรหัส RP-TN-05 กล่าวถึงขั้นตอนการซ่อมแซมงานประเภทใด\n', '\nAnswer : การซ่อมแซมรูฟองอากาศ (Voids and Blowholes Repair) ด้วย High Strength Mortar\n', '\nPage : 38\n', '\n\nQuestion : โครงการที่ระบุในเอกสารสำหรับการซ่อมแซมนี้คือโครงการใด\n', '\nAnswer : SEWERAGE TUNNEL BUNG NONG BON TO CHAOPHRAYA RIVER\n', '\nPage : 38\n', '\n\nQuestion : การซ่อมแซมด้วยวิธี RP-TN-05 ใช้สำหรับรูฟองอากาศที่มีขนาดเท่าใด\n', '\nAnswer : รูฟองอากาศที่มีขนาดความกว้างและความลึกมากกว่า 10 mm.\n', '\nPage : 39\n', '\n\nQuestion : คุณสมบัติของวัสดุฉาบซ่อมที่ต้องใช้ในการซ่อมแซมรูฟองอากาศขนาดใหญ่ต้องเป็นอย่างไรเมื่อเทียบกับวัสดุทั่วไป\n', '\nAnswer : ต้องมีกำลังอัดและการยึดเกาะสูงกว่า และมีการขยายตัวต่ำกว่าวัสดุฉาบซ่อมทั่วไป\n', '\nPage : 39\n', '\n\nQuestion : ในรูปที่ 1 ตัวอย่างรูฟองอากาศที่มีขนาดมากกว่า 10 mm. มีความลึกและความยาวเท่าใด\n', '\nAnswer : ลึก 15 mm. และ ยาว 20 mm.\n', '\nPage : 39\n', '\n\nQuestion : อุปกรณ์ข้อที่ 1.1 ที่ใช้ในการซ่อมแซมคืออะไร\n', '\nAnswer : เครื่องเป่าลม\n', '\nPage : 39\n', '\n\nQuestion : อุปกรณ์ข้อที่ 1.2 ที่ใช้ในการซ่อมแซมคืออะไร\n', '\nAnswer : เกรียง\n', '\nPage : 39\n', '\n\nQuestion : อุปกรณ์ข้อที่ 1.3 ที่ระบุไว้สำหรับการซ่อมแซมคืออะไร\n', '\nAnswer : ฟองน้ำหรือลูกกลิ้ง\n', '\nPage : 39\n', '\n\nQuestion : อุปกรณ์ข้อที่ 1.4 ที่ใช้ในการเตรียมผิวหรือขัดแต่งคืออะไร\n', '\nAnswer : กระดาษทราย\n', '\nPage : 39\n', '\n\nQuestion : วันที่ที่ระบุในเอกสาร (Date) ฉบับ Issue 2 คือวันที่เท่าใด\n', '\nAnswer : 20/6/2017\n', '\nPage : 39\n', '\n\nQuestion : วัสดุปูนฉาบซ่อมกำลังอัดสูงที่เสนอขออนุมัติใช้คือยี่ห้อและรุ่นใด\n', '\nAnswer : ปูนฉาบตราผึ้ง 135F\n', '\nPage : 40\n', '\n\nQuestion : อัตราส่วนผสมของปูนฉาบตราผึ้ง 135F ระหว่างปูนต่อน้ำคือเท่าใด\n', '\nAnswer : ปูน : น้ำ = 1 : 0.18 โดยน้ำหนัก\n', '\nPage : 40\n', '\n\nQuestion : การผสมปูนฉาบ 135F ใช้วิธีการตวงสัดส่วนโดยปริมาตรหรือโดยน้ำหนัก\n', '\nAnswer : โดยน้ำหนัก\n', '\nPage : 40\n', '\n\nQuestion : ขั้นตอนแรกในการเตรียมผิวรูฟองอากาศ (ข้อ 3.1) คืออะไร\n', '\nAnswer : ใช้กระดาษทรายขัดขอบรูฟองอากาศเพื่อให้การซ่อมแซมทำได้เต็มพื้นที่\n', '\nPage : 40\n', '\n\nQuestion : วัตถุประสงค์ของการขัดขอบรูฟองอากาศในขั้นตอนที่ 3.1 คืออะไร\n', '\nAnswer : เพื่อให้การซ่อมแซมทำได้เต็มพื้นที่\n', '\nPage : 40\n', '\n\nQuestion : รูปที่ 3 ในเอกสารแสดงขั้นตอนการทำงานใด\n', '\nAnswer : การขัดขอบรูฟองอากาศ\n', '\nPage : 40\n', '\n\nQuestion : ในขั้นตอนที่ 3.2 ใช้อุปกรณ์ใดในการทำความสะอาดรูฟองอากาศ\n', '\nAnswer : ลมเป่า (เครื่องเป่าลม)\n', '\nPage : 41\n', '\n\nQuestion : สภาพผิวคอนกรีตบริเวณที่จะทำการซ่อมจะต้องมีลักษณะอย่างไรก่อนเริ่มฉาบ\n', '\nAnswer : จะต้องไม่มีฝุ่นหรือคราบใดๆ\n', '\nPage : 41\n', '\n\nQuestion : รูปที่ 4 แสดงการทำงานขั้นตอนใด\n', '\nAnswer : การเป่าลมทำความสะอาดรูฟองอากาศ\n', '\nPage : 41\n', '\n\nQuestion : ในขั้นตอนที่ 3.3 สามารถใช้อุปกรณ์ใดบ้างในการอุดปูนฉาบให้เต็มรู\n', '\nAnswer : เกรียงหรือฟองน้ำ\n', '\nPage : 41\n', '\n\nQuestion : รูปที่ 5 แสดงการทำงานลักษณะใด\n', '\nAnswer : การฉาบอุดรูฟองอากาศ\n', '\nPage : 41\n', '\n\nQuestion : ขั้นตอนการขัดผิวปูนฉาบด้วยกระดาษทราย (ข้อ 3.4) จะทำได้เมื่อใด\n', '\nAnswer : หลังจากปูนฉาบแห้งแล้ว\n', '\nPage : 42\n', '\n\nQuestion : เป้าหมายของการขัดผิวปูนฉาบในขั้นตอนที่ 3.4 คืออะไร\n', '\nAnswer : เพื่อให้ผิวเรียบเสมอกับผิวคอนกรีตส่วนอื่น\n', '\nPage : 42\n', '\n\nQuestion : รูปที่ 6 แสดงการทำงานขั้นตอนใด\n', '\nAnswer : การขัดผิวปูนฉาบด้วยกระดาษทราย\n', '\nPage : 42\n', '\n\nQuestion : หลังจากขัดด้วยกระดาษทรายจนเรียบแล้ว ต้องทำขั้นตอนใดต่อในข้อ 3.5\n', '\nAnswer : ผสมปูนฉาบให้เหลวแล้วใช้ฟองน้ำลูบที่ผิวคอนกรีตบริเวณที่ทำการซ่อมแซม\n', '\nPage : 42\n', '\n\nQuestion : วัตถุประสงค์ของการใช้ปูนฉาบเหลวลูบที่ผิวคอนกรีตในขั้นตอนที่ 3.5 คืออะไร\n', '\nAnswer : เพื่อให้ผิวคอนกรีตมีสีสม่ำเสมอ\n', '\nPage : 42\n', '\n\nQuestion : อุปกรณ์ใดที่ใช้ในการลูบปูนฉาบเหลวในขั้นตอนที่ 3.5\n', '\nAnswer : ฟองน้ำ\n', '\nPage : 42\n', '\n\nQuestion : รูปที่ 7 แสดงขั้นตอนการทำงานใด\n', '\nAnswer : การลูบผิวคอนกรีตด้วยปูนฉาบเหลว\n', '\nPage : 42\n', '\n\nQuestion : การตรวจสอบความเรียบร้อยครั้งสุดท้าย (ข้อ 3.6) ทำเมื่อใด\n', '\nAnswer : ห ...
# ['Question : เอกสารรหัส RP-TN-05 กล่าวถึงขั้นตอนการซ่อมแซมงานประเภทใด\n', '\nAnswer : การซ่อมแซมรูฟองอากาศ (Voids and Blowholes Repair) ด้วย High Strength Mortar\n', '\nPage : 38\n', '\n\nQuestion : โครงการที่ระบุในเอกสารสำหรับการซ่อมแซมนี้คือโครงการใด\n', '\nAnswer : SEWERAGE TUNNEL BUNG NONG BON TO CHAOPHRAYA RIVER\n', '\nPage : 38\n', '\n\nQuestion : การซ่อมแซมด้วยวิธี RP-TN-05 ใช้สำหรับรูฟองอากาศที่มีขนาดเท่าใด\n', '\nAnswer : รูฟองอากาศที่มีขนาดความกว้างและความลึกมากกว่า 10 mm.\n', '\nPage : 39\n', '\n\nQuestion : คุณสมบัติของวัสดุฉาบซ่อมที่ต้องใช้ในการซ่อมแซมรูฟองอากาศขนาดใหญ่ต้องเป็นอย่างไรเมื่อเทียบกับวัสดุทั่วไป\n', '\nAnswer : ต้องมีกำลังอัดและการยึดเกาะสูงกว่า และมีการขยายตัวต่ำกว่าวัสดุฉาบซ่อมทั่วไป\n', '\nPage : 39\n', '\n\nQuestion : ในรูปที่ 1 ตัวอย่างรูฟองอากาศที่มีขนาดมากกว่า 10 mm. มีความลึกและความยาวเท่าใด\n', '\nAnswer : ลึก 15 mm. และ ยาว 20 mm.\n', '\nPage : 39\n', '\n\nQuestion : อุปกรณ์ข้อที่ 1.1 ที่ใช้ในการซ่อมแซมคืออะไร\n', '\nAnswer : เครื่องเป่าลม\n', '\nPage : 39\n', '\n\nQuestion : อุปกรณ์ข้อที่ 1.2 ที่ใช้ในการซ่อมแซมคืออะไร\n', '\nAnswer : เกรียง\n', '\nPage : 39\n', '\n\nQuestion : อุปกรณ์ข้อที่ 1.3 ที่ระบุไว้สำหรับการซ่อมแซมคืออะไร\n', '\nAnswer : ฟองน้ำหรือลูกกลิ้ง\n', '\nPage : 39\n', '\n\nQuestion : อุปกรณ์ข้อที่ 1.4 ที่ใช้ในการเตรียมผิวหรือขัดแต่งคืออะไร\n', '\nAnswer : กระดาษทราย\n', '\nPage : 39\n', '\n\nQuestion : วันที่ที่ระบุในเอกสาร (Date) ฉบับ Issue 2 คือวันที่เท่าใด\n', '\nAnswer : 20/6/2017\n', '\nPage : 39\n', '\n\nQuestion : วัสดุปูนฉาบซ่อมกำลังอัดสูงที่เสนอขออนุมัติใช้คือยี่ห้อและรุ่นใด\n', '\nAnswer : ปูนฉาบตราผึ้ง 135F\n', '\nPage : 40\n', '\n\nQuestion : อัตราส่วนผสมของปูนฉาบตราผึ้ง 135F ระหว่างปูนต่อน้ำคือเท่าใด\n', '\nAnswer : ปูน : น้ำ = 1 : 0.18 โดยน้ำหนัก\n', '\nPage : 40\n', '\n\nQuestion : การผสมปูนฉาบ 135F ใช้วิธีการตวงสัดส่วนโดยปริมาตรหรือโดยน้ำหนัก\n', '\nAnswer : โดยน้ำหนัก\n', '\nPage : 40\n', '\n\nQuestion : ขั้นตอนแรกในการเตรียมผิวรูฟองอากาศ (ข้อ 3.1) คืออะไร\n', '\nAnswer : ใช้กระดาษทรายขัดขอบรูฟองอากาศเพื่อให้การซ่อมแซมทำได้เต็มพื้นที่\n', '\nPage : 40\n', '\n\nQuestion : วัตถุประสงค์ของการขัดขอบรูฟองอากาศในขั้นตอนที่ 3.1 คืออะไร\n', '\nAnswer : เพื่อให้การซ่อมแซมทำได้เต็มพื้นที่\n', '\nPage : 40\n', '\n\nQuestion : รูปที่ 3 ในเอกสารแสดงขั้นตอนการทำงานใด\n', '\nAnswer : การขัดขอบรูฟองอากาศ\n', '\nPage : 40\n', '\n\nQuestion : ในขั้นตอนที่ 3.2 ใช้อุปกรณ์ใดในการทำความสะอาดรูฟองอากาศ\n', '\nAnswer : ลมเป่า (เครื่องเป่าลม)\n', '\nPage : 41\n', '\n\nQuestion : สภาพผิวคอนกรีตบริเวณที่จะทำการซ่อมจะต้องมีลักษณะอย่างไรก่อนเริ่มฉาบ\n', '\nAnswer : จะต้องไม่มีฝุ่นหรือคราบใดๆ\n', '\nPage : 41\n', '\n\nQuestion : รูปที่ 4 แสดงการทำงานขั้นตอนใด\n', '\nAnswer : การเป่าลมทำความสะอาดรูฟองอากาศ\n', '\nPage : 41\n', '\n\nQuestion : ในขั้นตอนที่ 3.3 สามารถใช้อุปกรณ์ใดบ้างในการอุดปูนฉาบให้เต็มรู\n', '\nAnswer : เกรียงหรือฟองน้ำ\n', '\nPage : 41\n', '\n\nQuestion : รูปที่ 5 แสดงการทำงานลักษณะใด\n', '\nAnswer : การฉาบอุดรูฟองอากาศ\n', '\nPage : 41\n', '\n\nQuestion : ขั้นตอนการขัดผิวปูนฉาบด้วยกระดาษทราย (ข้อ 3.4) จะทำได้เมื่อใด\n', '\nAnswer : หลังจากปูนฉาบแห้งแล้ว\n', '\nPage : 42\n', '\n\nQuestion : เป้าหมายของการขัดผิวปูนฉาบในขั้นตอนที่ 3.4 คืออะไร\n', '\nAnswer : เพื่อให้ผิวเรียบเสมอกับผิวคอนกรีตส่วนอื่น\n', '\nPage : 42\n', '\n\nQuestion : รูปที่ 6 แสดงการทำงานขั้นตอนใด\n', '\nAnswer : การขัดผิวปูนฉาบด้วยกระดาษทราย\n', '\nPage : 42\n', '\n\nQuestion : หลังจากขัดด้วยกระดาษทรายจนเรียบแล้ว ต้องทำขั้นตอนใดต่อในข้อ 3.5\n', '\nAnswer : ผสมปูนฉาบให้เหลวแล้วใช้ฟองน้ำลูบที่ผิวคอนกรีตบริเวณที่ทำการซ่อมแซม\n', '\nPage : 42\n', '\n\nQuestion : วัตถุประสงค์ของการใช้ปูนฉาบเหลวลูบที่ผิวคอนกรีตในขั้นตอนที่ 3.5 คืออะไร\n', '\nAnswer : เพื่อให้ผิวคอนกรีตมีสีสม่ำเสมอ\n', '\nPage : 42\n', '\n\nQuestion : อุปกรณ์ใดที่ใช้ในการลูบปูนฉาบเหลวในขั้นตอนที่ 3.5\n', '\nAnswer : ฟองน้ำ\n', '\nPage : 42\n', '\n\nQuestion : รูปที่ 7 แสดงขั้นตอนการทำงานใด\n', '\nAnswer : การลูบผิวคอนกรีตด้วยปูนฉาบเหลว\n', '\nPage : 42\n', '\n\nQuestion : การตรวจสอบความเรียบร้อยครั้งสุดท้าย (ข้อ 3.6) ทำเมื่อใด\n', '\nAnswer : ห ...
# 120

# %%
new_qa = []

for i in range(0, len(qa_result_list)-1, 3):
    # print(i)
    new_qa.append({
        'Question': qa_result_list[i].replace('Question :', '').replace('++++++++++++++++++++++', '').replace('\n', ''),
        'Answer': qa_result_list[i+1].replace('Answer :', '').replace('++++++++++++++++++++++', '').replace('\n', ''),
        'Page': qa_result_list[i+2].replace('++++++++++++++++++++++', '').replace('\n', '').replace('Page :', '').replace('Page:', '')
    })

# print(new_qa)

new_qa_df = pd.DataFrame(new_qa)
new_qa_df
# Out:
#                                              Question  \
# 0    เอกสารรหัส RP-TN-05 กล่าวถึงขั้นตอนการซ่อมแซม...
# 1    โครงการที่ระบุในเอกสารสำหรับการซ่อมแซมนี้คือโ...
# 2    การซ่อมแซมด้วยวิธี RP-TN-05 ใช้สำหรับรูฟองอาก...
# 3    คุณสมบัติของวัสดุฉาบซ่อมที่ต้องใช้ในการซ่อมแซ...
# 4    ในรูปที่ 1 ตัวอย่างรูฟองอากาศที่มีขนาดมากกว่า...
# 5         อุปกรณ์ข้อที่ 1.1 ที่ใช้ในการซ่อมแซมคืออะไร
# 6         อุปกรณ์ข้อที่ 1.2 ที่ใช้ในการซ่อมแซมคืออะไร
# 7    อุปกรณ์ข้อที่ 1.3 ที่ระบุไว้สำหรับการซ่อมแซมค...
# 8    อุปกรณ์ข้อที่ 1.4 ที่ใช้ในการเตรียมผิวหรือขัด...
# 9    วันที่ที่ระบุในเอกสาร (Date) ฉบับ Issue 2 คือ...
# 10   วัสดุปูนฉาบซ่อมกำลังอัดสูงที่เสนอขออนุมัติใช้...
# 11   อัตราส่วนผสมของปูนฉาบตราผึ้ง 135F ระหว่างปูนต...
# 12   การผสมปูนฉาบ 135F ใช้วิธีการตวงสัดส่วนโดยปริม...
# 13   ขั้นตอนแรกในการเตรียมผิวรูฟองอากาศ (ข้อ 3.1) ...
# 14   วัตถุประสงค์ของการขัดขอบรูฟองอากาศในขั้นตอนที...
# 15             รูปที่ 3 ในเอกสารแสดงขั้นตอนการทำงานใด
# 16   ในขั้นตอนที่ 3.2 ใช้อุปกรณ์ใดในการทำความสะอาด...
# 17   สภาพผิวคอนกรีตบริเวณที่จะทำการซ่อมจะต้องมีลัก...
# 18                     รูปที่ 4 แสดงการทำงานขั้นตอนใด
# 19   ในขั้นตอนที่ 3.3 สามารถใช้อุปกรณ์ใดบ้างในการอ...
# 20                      รูปที่ 5 แสดงการทำงานลักษณะใด
# 21   ขั้นตอนการขัดผิวปูนฉาบด้วยกระดาษทราย (ข้อ 3.4...
# 22   เป้าหมายของการขัดผิวปูนฉาบในขั้นตอนที่ 3.4 คื...
# 23                     รูปที่ 6 แสดงการทำงานขั้นตอนใด
# 24   หลังจากขัดด้วยกระดาษทรายจนเรียบแล้ว ต้องทำขั้...
# 25   วัตถุประสงค์ของการใช้ปูนฉาบเหลวลูบที่ผิวคอนกร...
# 26   อุปกรณ์ใดที่ใช้ในการลูบปูนฉาบเหลวในขั้นตอนที่...
# 27                     รูปที่ 7 แสดงขั้นตอนการทำงานใด
# 28   การตรวจสอบความเรียบร้อยครั้งสุดท้าย (ข้อ 3.6)...
# 29   ในขั้นตอนที่ 3.6 สิ่งที่ต้องตรวจสอบบริเวณที่ท...
# 30   หากพบ "รอยร้าว" ในขั้นตอนสุดท้าย ถือว่าเป็นสิ...
# 31   หากพบ "การแยกตัว" (Separation) ในขั้นตอนสุดท้...
# 32                               รูปที่ 8 แสดงภาพอะไร
# 33   ชื่อบริษัทผู้รับเหมาที่ปรากฏในส่วนหัวของเอกสา...
# 34          เอกสาร RP-TN-05 มีจำนวนหน้าทั้งหมดกี่หน้า
# 35   ภาชนะสำหรับใส่วัสดุซ่อม จัดเป็นอุปกรณ์ที่จำเป...
# 36   ในการเตรียมผิว (ข้อ 3.1) หากไม่ขัดขอบรูฟองอาก...
# 37   ในขั้นตอนที่ 3.3 การผสมปูนฉาบ 135F ต้องผสมกับ...
# 38   ขั้นตอนการปรับสีผิวคอนกรีต (ข้อ 3.5) ให้ทำก่อ...
# 39                     รูปที่ 2 ในหน้า 40 แสดงภาพอะไร
#
#                                                Answer Page
# 0    การซ่อมแซมรูฟองอากาศ (Voids and Blowholes Rep...   38
# 1    SEWERAGE TUNNEL BUNG NONG BON TO CHAOPHRAYA R...   38
# 2    รูฟองอากาศที่มีขนาดความกว้างและความลึกมากกว่า...   39
# 3    ต้องมีกำลังอัดและการยึดเกาะสูงกว่า และมีการขย...   39
# 4                           ลึก 15 mm. และ ยาว 20 mm.   39
# 5                                       เครื่องเป่าลม   39
# 6                                              เกรียง   39
# 7                                  ฟองน้ำหรือลูกกลิ้ง   39
# 8                                          กระดาษทราย   39
# 9                                           20/6/2017   39
# 10                                 ปูนฉาบตราผึ้ง 135F   40
# 11                    ปูน : น้ำ = 1 : 0.18 โดยน้ำหนัก   40
# 12                                         โดยน้ำหนัก   40
# 13   ใช้กระดาษทรายขัดขอบรูฟองอากาศเพื่อให้การซ่อมแ...   40
# 14                 เพื่อให้การซ่อมแซมทำได้เต็มพื้นที่   40
# 15                                การขัดขอบรูฟองอากาศ   40
# 16                             ลมเป่า (เครื่องเป่าลม)   41
# 17                         จะต้องไม่มีฝุ่นหรือคราบใดๆ   41
# 18                     การเป่าลมทำความสะอาดรูฟองอากาศ   41
# 19                                   เกรียงหรือฟองน้ำ   41
# 20                                การฉาบอุดรูฟองอากาศ   41
# 21                              หลังจากปูนฉาบแห้งแล้ว   42
# 22          เพื่อให้ผิวเรียบเสมอกับผิวคอนกรีตส่วนอื่น   42
# 23                      การขัดผิวปูนฉาบด้วยกระดาษทราย   42
# 24   ผสมปูนฉาบให้เหลวแล้วใช้ฟองน้ำลูบที่ผิวคอนกรีต...   42
# 25                     เพื่อให้ผิวคอนกรีตมีสีสม่ำเสมอ   42
# 26                                             ฟองน้ำ   42
# 27                     การลูบผิวคอนกรีตด้วยปูนฉาบเหลว   42
# 28                              หลังจากน้ำปูนแห้งแล้ว   43
# 29          ตรวจสอบว่ามีรอยร้าวหรือมีการแยกตัวหรือไม่   43
# 30     ใช่ (ตามข้อ 3.6 ให้ตรวจสอบว่ามีรอยร้าวหรือไม่)   43
# 31   ใช่ (ตามข้อ 3.6 ให้ตรวจสอบว่ามีการแยกตัวหรือไม่)   43
# 32              สภาพผิวคอนกรีตที่ซ่อมแซมเรียบร้อยแล้ว   43
# 33   บริษัท ซิโน-ไทย เอ็นจีเนียริ่ง แอนด์ คอนสตรัค...   38
# 34                    5 หน้า (ระบุ 1 of 5 ถึง 5 of 5)   39
# 35                          ใช่ เป็นอุปกรณ์ที่ต้องใช้   39
# 36   การซ่อมแซมอาจทำได้ไม่เต็มพื้นที่ (เนื่องจากเอ...   40
# 37                       น้ำ (ตามอัตราส่วน ปูน : น้ำ)   40
# 38                หลังจากขัดด้วยกระดาษทรายจนเรียบแล้ว   42
# 39    วัสดุฉาบที่ใช้ในการซ่อมแซม (ถุงปูนตราผึ้ง 135F)   40

# %%
new_qa_df.to_csv(f'{root_path}\\table\\QA_content_6.csv', index=False)

# %% [markdown]
# # 7_Materials_Data_Sheet

# %%
context = ""
for i in range(len(docs[docs['content'] == '7_Materials_Data_Sheet'])):
    context += f"Page {docs[docs['content'] == '7_Materials_Data_Sheet']['page'].iloc[i]}:\n{docs[docs['content'] == '7_Materials_Data_Sheet']['text'].iloc[i]}\n\n"
    # print(docs[docs['content'] == '2_Repair_With_Cementitious_Mortar']['page'].iloc[i])
# print(context)

# %%
qa_result = generate_qa_from_docs(context, qa_example.iloc[0])

# %%
print(qa_result.split('<split>'))
qa_result_list = []
for qa in qa_result.split('<split>'):
    if qa != '++++++++++++++++++++++' and qa != '':
        qa_result_list.append(qa)
print(qa_result_list)
print(len(qa_result_list))
# Out:
# ['Question : What is the mixing water requirement for Renderoc Skimcoat Base Coat and Finish Coat?', '\n++++++++++++++++++++++\nAnswer : The mixing water requirements are:\n- Renderoc Skimcoat Base Coat: 7 - 7.5 litres/bag\n- Renderoc Skimcoat Finish Coat: 7.5 - 8 litres/bag', '\n++++++++++++++++++++++\nPage : 100', '\n\nQuestion : What is the yield per 25 kg bag for Renderoc Skimcoat Base Coat and Finish Coat?', '\n++++++++++++++++++++++\nAnswer : The yield per 25 kg bag is:\n- Renderoc Skimcoat Base Coat: 19.0 litres/bag\n- Renderoc Skimcoat Finish Coat: 22.0 litres/bag', '\n++++++++++++++++++++++\nPage : 100', '\n\nQuestion : What is the recommended application thickness for Renderoc Skimcoat Base Coat and Finish Coat?', '\n++++++++++++++++++++++\nAnswer : The recommended thickness is:\n- Renderoc Skimcoat Base Coat: 0.5 - 5.0 mm\n- Renderoc Skimcoat Finish Coat: 0.1 - 0.5 mm', '\n++++++++++++++++++++++\nPage : 100', '\n\nQuestion : ปูนฉาบแต่งบางพิเศษตราผึ้ง เบอร์ 124 มีอัตราส่วนผสมน้ำเท่าไหร่', '\n++++++++++++++++++++++\nAnswer : อัตราส่วนผสมคือ 1 ถุง (20 กก.) ผสมน้ำ 7.5-8.5 ลิตร โดยผสมให้เป็นเนื้อเดียวกัน', '\n++++++++++++++++++++++\nPage : 102', '\n\nQuestion : ความหนาในการฉาบที่แนะนำสำหรับปูนฉาบแต่งบางพิเศษตราผึ้ง เบอร์ 124 คือเท่าไหร่', '\n++++++++++++++++++++++\nAnswer : สามารถฉาบหรือรีดให้มีความหนา 1-2 มม. ถ้าต้องการความหนาเกิน 2 มม. ควรฉาบหรือรีดทีละชั้นๆ ละไม่เกิน 2 มม.', '\n++++++++++++++++++++++\nPage : 102', '\n\nQuestion : ข้อแนะนำเรื่องระยะเวลาการใช้งานหลังจากผสมน้ำแล้วของปูนฉาบแต่งบางพิเศษตราผึ้ง เบอร์ 124 คืออะไร', '\n++++++++++++++++++++++\nAnswer : ควรใช้ให้หมดภายใน 1 ชั่วโมง หลังจากผสมน้ำแล้ว และไม่ควรเติมน้ำอีกในระหว่างการใช้งาน', '\n++++++++++++++++++++++\nPage : 102', '\n\nQuestion : What is the Compressive Strength specification at 28 days for Bee Brand Skim Coat Mortar No. 124 and 124W?', '\n++++++++++++++++++++++\nAnswer : The Compressive Strength specification at 28 days for Bee Brand No. 124 and 124W is 20.0 MPa.', '\n++++++++++++++++++++++\nPage : 109', '\n\nQuestion : ปูนฉาบซ่อมกำลังอัดสูงตราผึ้ง เบอร์ 135 และ 135 F แตกต่างกันอย่างไรในแง่ของส่วนผสม', '\n++++++++++++++++++++++\nAnswer : ปูนฉาบซ่อมกำลังอัดสูง เบอร์ 135 ปราศจากสารพิษ ไม่มีคลอไรด์ที่เป็นอันตรายต่อเหล็กเสริม เฉพาะเบอร์ 135 F จะมีส่วนผสมของ Cellulose Fiber', '\n++++++++++++++++++++++\nPage : 114', '\n\nQuestion : ข้อมูลเทคนิคเรื่องกำลังอัด (Compressive Strength) ของปูนฉาบซ่อมกำลังอัดสูงตราผึ้ง เบอร์ 135 ที่อายุ 1, 7 และ 28 วัน คือเท่าไหร่', '\n++++++++++++++++++++++\nAnswer : กำลังอัดของปูนฉาบซ่อมกำลังอัดสูงตราผึ้ง เบอร์ 135 มีดังนี้:\n1. 1 วัน: 25 MPa\n2. 7 วัน: 40 MPa\n3. 28 วัน: 60 MPa', '\n++++++++++++++++++++++\nPage : 114', '\n\nQuestion : ระยะเวลาการใช้งาน (Pot Life) ของปูนฉาบซ่อมกำลังอัดสูงตราผึ้ง เบอร์ 135 หลังจากผสมน้ำแล้วคือเท่าไหร่', '\n++++++++++++++++++++++\nAnswer : ควรใช้ให้หมดภายใน 45 นาที หลังจากผสมน้ำแล้ว', '\n++++++++++++++++++++++\nPage : 114', '\n\nQuestion : อัตราส่วนการผสมน้ำสำหรับปูนฉาบซ่อมกำลังอัดสูงตราผึ้ง เบอร์ 135 คือเท่าไหร่', '\n++++++++++++++++++++++\nAnswer : อัตราส่วนการผสมคือน้ำ : ปูน # 135 เท่ากับ 17 - 19 % โดยน้ำหนัก', '\n++++++++++++++++++++++\nPage : 114', '\n\nQuestion : ปริมาณน้ำที่ใช้ผสม Sika Skim Coat สำหรับสีเทาและสีขาวแตกต่างกันอย่างไร', '\n++++++++++++++++++++++\nAnswer : ปริมาณน้ำที่ใช้ผสมต่อ Sika Skim Coat 1 ถุง (20 กก.) มีดังนี้:\n- สำหรับสีเทา: ใช้น้ำ 7.0-7.4 ลิตร (35%-37%)\n- สำหรับสีขาว: ใช้น้ำ 7.4-7.8 ลิตร (37%-39%)', '\n++++++++++++++++++++++\nPage : 46', '\n\nQuestion : ระยะเวลาการทำงาน (Pot life) ของ Sika Skim Coat ที่อุณหภูมิ 30°C คือเท่าไหร่', '\n++++++++++++++++++++++\nAnswer : ระยะเวลาการทำงานประมาณ 45 นาที ที่อุณหภูมิ 30°C', '\n++++++++++++++++++++++\nPage : 46', '\n\nQuestion : What is the mixing ratio for Sikadur-31 CF Normal?', '\n++++++++++++++++++++++\nAnswer : The mixing ratio is Part A : Part B = 2 : 1 by weight or volume.', '\n++++++++++++++++++++++\nPage : 50', '\n\nQuestion : What is the sag flow limit for Sikadur-31 CF Normal on vertical surfaces?', '\n+++++++++++ ...
# ['Question : What is the mixing water requirement for Renderoc Skimcoat Base Coat and Finish Coat?', '\n++++++++++++++++++++++\nAnswer : The mixing water requirements are:\n- Renderoc Skimcoat Base Coat: 7 - 7.5 litres/bag\n- Renderoc Skimcoat Finish Coat: 7.5 - 8 litres/bag', '\n++++++++++++++++++++++\nPage : 100', '\n\nQuestion : What is the yield per 25 kg bag for Renderoc Skimcoat Base Coat and Finish Coat?', '\n++++++++++++++++++++++\nAnswer : The yield per 25 kg bag is:\n- Renderoc Skimcoat Base Coat: 19.0 litres/bag\n- Renderoc Skimcoat Finish Coat: 22.0 litres/bag', '\n++++++++++++++++++++++\nPage : 100', '\n\nQuestion : What is the recommended application thickness for Renderoc Skimcoat Base Coat and Finish Coat?', '\n++++++++++++++++++++++\nAnswer : The recommended thickness is:\n- Renderoc Skimcoat Base Coat: 0.5 - 5.0 mm\n- Renderoc Skimcoat Finish Coat: 0.1 - 0.5 mm', '\n++++++++++++++++++++++\nPage : 100', '\n\nQuestion : ปูนฉาบแต่งบางพิเศษตราผึ้ง เบอร์ 124 มีอัตราส่วนผสมน้ำเท่าไหร่', '\n++++++++++++++++++++++\nAnswer : อัตราส่วนผสมคือ 1 ถุง (20 กก.) ผสมน้ำ 7.5-8.5 ลิตร โดยผสมให้เป็นเนื้อเดียวกัน', '\n++++++++++++++++++++++\nPage : 102', '\n\nQuestion : ความหนาในการฉาบที่แนะนำสำหรับปูนฉาบแต่งบางพิเศษตราผึ้ง เบอร์ 124 คือเท่าไหร่', '\n++++++++++++++++++++++\nAnswer : สามารถฉาบหรือรีดให้มีความหนา 1-2 มม. ถ้าต้องการความหนาเกิน 2 มม. ควรฉาบหรือรีดทีละชั้นๆ ละไม่เกิน 2 มม.', '\n++++++++++++++++++++++\nPage : 102', '\n\nQuestion : ข้อแนะนำเรื่องระยะเวลาการใช้งานหลังจากผสมน้ำแล้วของปูนฉาบแต่งบางพิเศษตราผึ้ง เบอร์ 124 คืออะไร', '\n++++++++++++++++++++++\nAnswer : ควรใช้ให้หมดภายใน 1 ชั่วโมง หลังจากผสมน้ำแล้ว และไม่ควรเติมน้ำอีกในระหว่างการใช้งาน', '\n++++++++++++++++++++++\nPage : 102', '\n\nQuestion : What is the Compressive Strength specification at 28 days for Bee Brand Skim Coat Mortar No. 124 and 124W?', '\n++++++++++++++++++++++\nAnswer : The Compressive Strength specification at 28 days for Bee Brand No. 124 and 124W is 20.0 MPa.', '\n++++++++++++++++++++++\nPage : 109', '\n\nQuestion : ปูนฉาบซ่อมกำลังอัดสูงตราผึ้ง เบอร์ 135 และ 135 F แตกต่างกันอย่างไรในแง่ของส่วนผสม', '\n++++++++++++++++++++++\nAnswer : ปูนฉาบซ่อมกำลังอัดสูง เบอร์ 135 ปราศจากสารพิษ ไม่มีคลอไรด์ที่เป็นอันตรายต่อเหล็กเสริม เฉพาะเบอร์ 135 F จะมีส่วนผสมของ Cellulose Fiber', '\n++++++++++++++++++++++\nPage : 114', '\n\nQuestion : ข้อมูลเทคนิคเรื่องกำลังอัด (Compressive Strength) ของปูนฉาบซ่อมกำลังอัดสูงตราผึ้ง เบอร์ 135 ที่อายุ 1, 7 และ 28 วัน คือเท่าไหร่', '\n++++++++++++++++++++++\nAnswer : กำลังอัดของปูนฉาบซ่อมกำลังอัดสูงตราผึ้ง เบอร์ 135 มีดังนี้:\n1. 1 วัน: 25 MPa\n2. 7 วัน: 40 MPa\n3. 28 วัน: 60 MPa', '\n++++++++++++++++++++++\nPage : 114', '\n\nQuestion : ระยะเวลาการใช้งาน (Pot Life) ของปูนฉาบซ่อมกำลังอัดสูงตราผึ้ง เบอร์ 135 หลังจากผสมน้ำแล้วคือเท่าไหร่', '\n++++++++++++++++++++++\nAnswer : ควรใช้ให้หมดภายใน 45 นาที หลังจากผสมน้ำแล้ว', '\n++++++++++++++++++++++\nPage : 114', '\n\nQuestion : อัตราส่วนการผสมน้ำสำหรับปูนฉาบซ่อมกำลังอัดสูงตราผึ้ง เบอร์ 135 คือเท่าไหร่', '\n++++++++++++++++++++++\nAnswer : อัตราส่วนการผสมคือน้ำ : ปูน # 135 เท่ากับ 17 - 19 % โดยน้ำหนัก', '\n++++++++++++++++++++++\nPage : 114', '\n\nQuestion : ปริมาณน้ำที่ใช้ผสม Sika Skim Coat สำหรับสีเทาและสีขาวแตกต่างกันอย่างไร', '\n++++++++++++++++++++++\nAnswer : ปริมาณน้ำที่ใช้ผสมต่อ Sika Skim Coat 1 ถุง (20 กก.) มีดังนี้:\n- สำหรับสีเทา: ใช้น้ำ 7.0-7.4 ลิตร (35%-37%)\n- สำหรับสีขาว: ใช้น้ำ 7.4-7.8 ลิตร (37%-39%)', '\n++++++++++++++++++++++\nPage : 46', '\n\nQuestion : ระยะเวลาการทำงาน (Pot life) ของ Sika Skim Coat ที่อุณหภูมิ 30°C คือเท่าไหร่', '\n++++++++++++++++++++++\nAnswer : ระยะเวลาการทำงานประมาณ 45 นาที ที่อุณหภูมิ 30°C', '\n++++++++++++++++++++++\nPage : 46', '\n\nQuestion : What is the mixing ratio for Sikadur-31 CF Normal?', '\n++++++++++++++++++++++\nAnswer : The mixing ratio is Part A : Part B = 2 : 1 by weight or volume.', '\n++++++++++++++++++++++\nPage : 50', '\n\nQuestion : What is the sag flow limit for Sikadur-31 CF Normal on vertical surfaces?', '\n+++++++++++ ...
# 120

# %%
new_qa = []

for i in range(0, len(qa_result_list)-1, 3):
    # print(i)
    new_qa.append({
        'Question': qa_result_list[i].replace('Question :', '').replace('++++++++++++++++++++++', '').replace('\n', ''),
        'Answer': qa_result_list[i+1].replace('Answer :', '').replace('++++++++++++++++++++++', '').replace('\n', ''),
        'Page': qa_result_list[i+2].replace('++++++++++++++++++++++', '').replace('\n', '')
    })

# print(new_qa)

new_qa_df = pd.DataFrame(new_qa)
new_qa_df
# Out:
#                                              Question  \
# 0    What is the mixing water requirement for Rend...
# 1    What is the yield per 25 kg bag for Renderoc ...
# 2    What is the recommended application thickness...
# 3    ปูนฉาบแต่งบางพิเศษตราผึ้ง เบอร์ 124 มีอัตราส่...
# 4    ความหนาในการฉาบที่แนะนำสำหรับปูนฉาบแต่งบางพิเ...
# 5    ข้อแนะนำเรื่องระยะเวลาการใช้งานหลังจากผสมน้ำแ...
# 6    What is the Compressive Strength specificatio...
# 7    ปูนฉาบซ่อมกำลังอัดสูงตราผึ้ง เบอร์ 135 และ 13...
# 8    ข้อมูลเทคนิคเรื่องกำลังอัด (Compressive Stren...
# 9    ระยะเวลาการใช้งาน (Pot Life) ของปูนฉาบซ่อมกำล...
# 10   อัตราส่วนการผสมน้ำสำหรับปูนฉาบซ่อมกำลังอัดสูง...
# 11   ปริมาณน้ำที่ใช้ผสม Sika Skim Coat สำหรับสีเทา...
# 12   ระยะเวลาการทำงาน (Pot life) ของ Sika Skim Coa...
# 13   What is the mixing ratio for Sikadur-31 CF No...
# 14   What is the sag flow limit for Sikadur-31 CF ...
# 15   What is the Compressive Strength of Sikadur-3...
# 16   What is the bond strength of Sikadur-31 CF No...
# 17   What is the mixing ratio by weight for Sikadu...
# 18   What is the maximum layer thickness for Sikad...
# 19   What is the Compressive Strength of Sikadur-4...
# 20         What is the mixing ratio for Sikadur-32TH?
# 21      What is the Pot Life of Sikadur-32TH at 30°C?
# 22   What is the Bond Strength to Concrete for Sik...
# 23   ความข้นเหลว (Viscosity) ของ Sikadur-52TH ที่อ...
# 24   ความกว้างสูงสุดของรอยแตกร้าวที่ควรทำการอัดฉีด...
# 25   ค่ารับแรงดึง (Tensile Strength) ของ Sikadur-5...
# 26   What is the recommended application layer thi...
# 27   What are the preparation instructions regardi...
# 28   Based on the Department of Science Service re...
# 29   What is the mixing ratio by weight for Condur...
# 30   What is the Tensile Strength property listed ...
# 31   What is the recommended crack width range for...
# 32   According to the AIT test report, what was th...
# 33   What is the Bond Strength of Renderoc Skimcoa...
# 34   What is the Wet Density of Renderoc Skimcoat ...
# 35   What is the recommended curing time before pa...
# 36   What is the Pot Life of Sikadur-41 CF Normal ...
# 37   What is the shelf life of Sikadur-31 CF Norma...
# 38   แรงยึดเกาะ (Bond Strength) ของปูนฉาบซ่อมกำลัง...
# 39   What are the storage limitations for Renderoc...
#
#                                                Answer        Page
# 0    The mixing water requirements are:- Renderoc ...  Page : 100
# 1    The yield per 25 kg bag is:- Renderoc Skimcoa...  Page : 100
# 2    The recommended thickness is:- Renderoc Skimc...  Page : 100
# 3    อัตราส่วนผสมคือ 1 ถุง (20 กก.) ผสมน้ำ 7.5-8.5...  Page : 102
# 4    สามารถฉาบหรือรีดให้มีความหนา 1-2 มม. ถ้าต้องก...  Page : 102
# 5    ควรใช้ให้หมดภายใน 1 ชั่วโมง หลังจากผสมน้ำแล้ว...  Page : 102
# 6    The Compressive Strength specification at 28 ...  Page : 109
# 7    ปูนฉาบซ่อมกำลังอัดสูง เบอร์ 135 ปราศจากสารพิษ...  Page : 114
# 8    กำลังอัดของปูนฉาบซ่อมกำลังอัดสูงตราผึ้ง เบอร์...  Page : 114
# 9         ควรใช้ให้หมดภายใน 45 นาที หลังจากผสมน้ำแล้ว  Page : 114
# 10   อัตราส่วนการผสมคือน้ำ : ปูน # 135 เท่ากับ 17 ...  Page : 114
# 11   ปริมาณน้ำที่ใช้ผสมต่อ Sika Skim Coat 1 ถุง (2...   Page : 46
# 12    ระยะเวลาการทำงานประมาณ 45 นาที ที่อุณหภูมิ 30°C   Page : 46
# 13   The mixing ratio is Part A : Part B = 2 : 1 b...   Page : 50
# 14   On vertical surfaces, it is non-sag up to 15 ...   Page : 48
# 15   The Compressive Strength is 45 - 55 N/mm² aft...   Page : 49
# 16   The bond strength is > 4 N/mm² (100% concrete...   Page : 49
# 17   The mixing ratio is Part A : B : C = 2 : 1 : ...   Page : 55
# 18              The maximum layer thickness is 60 mm.   Page : 53
# 19   The Compressive Strength is 77 - 87 N/mm² aft...   Page : 54
# 20   The mixing ratio is Comp. A : B = 2 : 1 parts...   Page : 59
# 21                The Pot Life at 30°C is 20 minutes.   Page : 59
# 22   The Bond Strength to Concrete is 2.5 - 3 N/mm...   Page : 59
# 23   ความข้นเหลวของ Sikadur-52TH ที่อุณหภูมิ 30°C ...   Page : 61
# 24   ความกว้างสูงสุดของรอยแตกร้าวที่ควรทำการอัดฉีด...   Page : 60
# 25   ค่ารับแรงดึง (Tensile Strength) คือ 20-25 นิว...   Page : 61
# 26   Conpatch 300 should be worked in thin layers ...   Page : 62
# 27   Pre-wet saturate the concrete surface to rece...   Page : 62
# 28   The Compressive Strength of Conpatch 300 at 2...   Page : 67
# 29       The mixing ratio is A : B = 4 : 1 by weight.   Page : 70
# 30                The Tensile Strength is > 25 N/mm².   Page : 70
# 31             The crack should be between 0 - 15 mm.   Page : 70
# 32   The average Bond Strength by Slant Shear Test...   Page : 77
# 33   The Bond Strength is 0.5 N/mm² (Grade 30 conc...   Page : 98
# 34   The Wet Density of Renderoc Skimcoat Base Coa...   Page : 98
# 35   The curing time before painting is:- Base coa...   Page : 98
# 36   The Pot Life of Sikadur-41 CF Normal at +30°C...   Page : 56
# 37   The shelf life is 24 months from date of prod...   Page : 48
# 38               แรงยึดเกาะที่อายุ 28 วัน คือ 5.5 MPa  Page : 114
# 39   If stored at high temperature and/or high hum...   Page : 99

# %%
new_qa_df.to_csv(f'{root_path}\\table\\QA_content_7.csv', index=False)

# %% [markdown]
# # 8_Risk_Assessment_In_Repair_Working

# %%
context = ""
for i in range(len(docs[docs['content'] == '8_Risk_Assessment_In_Repair_Working'])):
    context += f"Page {docs[docs['content'] == '8_Risk_Assessment_In_Repair_Working']['page'].iloc[i]}:\n{docs[docs['content'] == '8_Risk_Assessment_In_Repair_Working']['text'].iloc[i]}\n\n"
    # print(docs[docs['content'] == '2_Repair_With_Cementitious_Mortar']['page'].iloc[i])
# print(context)

# %%
qa_result = generate_qa_from_docs(context, qa_example.iloc[0])

# %%
print(qa_result.split('<split>'))
qa_result_list = []
for qa in qa_result.split('<split>'):
    if qa != '++++++++++++++++++++++' and qa != '':
        qa_result_list.append(qa)
print(qa_result_list)
print(len(qa_result_list))
# Out:
# ['Question : เอกสารฉบับนี้มีรหัสเอกสาร (Document ID) ว่าอะไร\n', '\n\nAnswer : RA-RP-01\n', '\n\nPage : 120\n', '\n\nQuestion : ชื่อโครงการที่ระบุในหน้าปกของเอกสารคือโครงการอะไร\n', '\n\nAnswer : โครงการก่อสร้างอุโมงค์ระบายน้ำจากบึงหนองบอนลงสู่แม่น้ำเจ้าพระยา (Sewerage Tunnel Bung Nong Bon to Chaophraya River)\n', '\n\nPage : 120\n', '\n\nQuestion : บริษัทใดเป็นผู้จัดทำเอกสารการประเมินความเสี่ยงฉบับนี้\n', '\n\nAnswer : บริษัท ซิโน-ไทย เอ็นจีเนียริ่ง แอนด์ คอนสตรัคชั่น จำกัด (มหาชน) (Sino-Thai Engineering & Construction Public Company Limited)\n', '\n\nPage : 120\n', '\n\nQuestion : ในตารางที่ 1 อันตรายลำดับที่ 1 (Item 1) เกิดจากการใช้อุปกรณ์ชนิดใด\n', '\n\nAnswer : อันตรายจากการใช้เครื่องเจียรคอนกรีต\n', '\n\nPage : 121\n', '\n\nQuestion : เหตุการณ์อันตรายที่อาจเกิดขึ้น (Hazard Event/Potential) จากการใช้เครื่องเจียรคอนกรีตมีอะไรบ้าง\n', '\n\nAnswer :\n1. ไฟฟ้าดูด\n2. โดนใบเจียรบาด\n', '\n\nPage : 121\n', '\n\nQuestion : ระดับความเสี่ยงเริ่มต้น (Initial Risk Rating) ของการใช้เครื่องเจียรคอนกรีตมีค่า HCR และ PR เท่าใด\n', '\n\nAnswer : HCR = 4, PR = 3\n', '\n\nPage : 121\n', '\n\nQuestion : ค่า Risk Factor (RF) เริ่มต้นสำหรับการใช้เครื่องเจียรคอนกรีตคือก่อนการลดความเสี่ยงเท่าใด\n', '\n\nAnswer : 12\n', '\n\nPage : 121\n', '\n\nQuestion : วิธีการลดความเสี่ยง (Method of Minimization) สำหรับการใช้เครื่องเจียรคอนกรีตมีอะไรบ้าง\n', '\n\nAnswer :\n1. อบรมวิธีการป้องกันความเสี่ยงในการใช้เครื่องเจียรคอนกรีต\n2. ใช้เครื่องมือที่ผ่านการตรวจสภาพแล้วเท่านั้น\n3. ติดตั้งเซฟการ์ดที่เครื่องเจียรคอนกรีต\n4. ผู้ปฏิบัติงานต้องสวมใส่อุปกรณ์ PPE ที่กำหนดให้ครบ\n5. จัดพื้นที่การทำงานให้เหมาะสม\n', '\n\nPage : 121\n', '\n\nQuestion : ค่า Residual Risk Factor ของการใช้เครื่องเจียรคอนกรีตหลังจากมีมาตรการควบคุมแล้วคือเท่าใด\n', '\n\nAnswer : 6\n', '\n\nPage : 121\n', '\n\nQuestion : ระดับความเสี่ยง (Risk Priority) ของการใช้เครื่องเจียรคอนกรีตภายหลังการควบคุมอยู่ในระดับใด\n', '\n\nAnswer : Medium (ปานกลาง)\n', '\n\nPage : 121\n', '\n\nQuestion : อันตรายลำดับที่ 2 (Item 2) ในตารางประเมินความเสี่ยงคืออะไร\n', '\n\nAnswer : อันตรายจากการสัมผัสสารเคมี\n', '\n\nPage : 121\n', '\n\nQuestion : เหตุการณ์อันตรายที่อาจเกิดขึ้นจากการสัมผัสสารเคมีมีอะไรบ้าง\n', '\n\nAnswer :\n1. ผิวหนังไหม้\n2. ระคายเคืองผิวหนัง\n3. ผิวหนังอักเสบ\n4. เนื้อเยื่อตาไหม้\n5. ระคายเคืองดวงตา\n', '\n\nPage : 121\n', '\n\nQuestion : ค่า Risk Factor (RF) เริ่มต้นสำหรับอันตรายจากการสัมผัสสารเคมีคือเท่าใด\n', '\n\nAnswer : 9\n', '\n\nPage : 121\n', '\n\nQuestion : วิธีการลดความเสี่ยงสำหรับอันตรายจากการสัมผัสสารเคมีมีข้อปฏิบัติอย่างไรบ้าง\n', '\n\nAnswer :\n1. อบรมวิธีการปฐมพยาบาลผู้ป่วยที่สัมผัสสารเคมีเบื้องต้น\n2. จัดเตรียมอุปกรณ์ในการปฐมพยาบาล\n3. สวมใส่เครื่องป้องกันทุกครั้งเพื่อหลีกเลี่ยงการสัมผัสสารเคมีโดยตรง\n4. จัดอุปกรณ์สำหรับใช้กับสารเคมีให้เหมาะสม\n5. ตรวจสุขภาพผู้ปฏิบัติงาน เพื่อป้องกันผลกระทบในระยะยาว\n', '\n\nPage : 121\n', '\n\nQuestion : อันตรายลำดับที่ 3 (Item 3) คืออันตรายจากสาเหตุใด\n', '\n\nAnswer : อันตรายจากการสูดดมสารเคมี\n', '\n\nPage : 121\n', '\n\nQuestion : ผลกระทบต่อสุขภาพที่อาจเกิดขึ้นจากการสูดดมสารเคมีมีอะไรบ้าง\n', '\n\nAnswer :\n1. ระคายเคืองระบบทางเดินหายใจ\n2. วิงเวียนศีรษะ\n3. หมดสติ\n', '\n\nPage : 121\n', '\n\nQuestion : มาตรการลดความเสี่ยงที่เกี่ยวข้องกับหน้ากากป้องกันสำหรับอันตรายจากการสูดดมสารเคมีคืออะไร\n', '\n\nAnswer : หน้ากากป้องกันที่เหมาะสมกับลักษณะสารเคมี\n', '\n\nPage : 121\n', '\n\nQuestion : มาตรการลดความเสี่ยงเพิ่มเติมในกรณีวัสดุรั่วไหลสำหรับการสูดดมสารเคมีคืออะไร\n', '\n\nAnswer : อบรมวิธีการจัดการเมื่อวัสดุรั่วไหลหรือฟุ้งกระจาย\n', '\n\nPage : 121\n', '\n\nQuestion : เกณฑ์คะแนน Risk Factor สำหรับระดับความเสี่ยง "Low Risk" (ความเสี่ยงต่ำ) คือช่วงใด\n', '\n\nAnswer : 1 - 4\n', '\n\nPage : 121\n', '\n\nQuestion : เกณฑ์คะแนน Risk Factor สำหรับระดับความเสี่ยง "Medium Risk" (เสี่ยงปานกลาง) คือช่วงใด\n', '\n\nAnswer : 5 - 7\n', '\n\nPage : 121\n', '\n\nQuestion : เกณฑ์คะแนน Risk Factor สำหรับระดับความเสี่ยง "High Risk" (มีความเสี่ยงสูง) คือช่วงใด\n', '\n\nAnswer : 8 - 16\n', '\n\nPage : 121\n', '\n\nQuestion : อันตรายลำดับที่ 4 (Item 4) ในหน้า 122 ...
# ['Question : เอกสารฉบับนี้มีรหัสเอกสาร (Document ID) ว่าอะไร\n', '\n\nAnswer : RA-RP-01\n', '\n\nPage : 120\n', '\n\nQuestion : ชื่อโครงการที่ระบุในหน้าปกของเอกสารคือโครงการอะไร\n', '\n\nAnswer : โครงการก่อสร้างอุโมงค์ระบายน้ำจากบึงหนองบอนลงสู่แม่น้ำเจ้าพระยา (Sewerage Tunnel Bung Nong Bon to Chaophraya River)\n', '\n\nPage : 120\n', '\n\nQuestion : บริษัทใดเป็นผู้จัดทำเอกสารการประเมินความเสี่ยงฉบับนี้\n', '\n\nAnswer : บริษัท ซิโน-ไทย เอ็นจีเนียริ่ง แอนด์ คอนสตรัคชั่น จำกัด (มหาชน) (Sino-Thai Engineering & Construction Public Company Limited)\n', '\n\nPage : 120\n', '\n\nQuestion : ในตารางที่ 1 อันตรายลำดับที่ 1 (Item 1) เกิดจากการใช้อุปกรณ์ชนิดใด\n', '\n\nAnswer : อันตรายจากการใช้เครื่องเจียรคอนกรีต\n', '\n\nPage : 121\n', '\n\nQuestion : เหตุการณ์อันตรายที่อาจเกิดขึ้น (Hazard Event/Potential) จากการใช้เครื่องเจียรคอนกรีตมีอะไรบ้าง\n', '\n\nAnswer :\n1. ไฟฟ้าดูด\n2. โดนใบเจียรบาด\n', '\n\nPage : 121\n', '\n\nQuestion : ระดับความเสี่ยงเริ่มต้น (Initial Risk Rating) ของการใช้เครื่องเจียรคอนกรีตมีค่า HCR และ PR เท่าใด\n', '\n\nAnswer : HCR = 4, PR = 3\n', '\n\nPage : 121\n', '\n\nQuestion : ค่า Risk Factor (RF) เริ่มต้นสำหรับการใช้เครื่องเจียรคอนกรีตคือก่อนการลดความเสี่ยงเท่าใด\n', '\n\nAnswer : 12\n', '\n\nPage : 121\n', '\n\nQuestion : วิธีการลดความเสี่ยง (Method of Minimization) สำหรับการใช้เครื่องเจียรคอนกรีตมีอะไรบ้าง\n', '\n\nAnswer :\n1. อบรมวิธีการป้องกันความเสี่ยงในการใช้เครื่องเจียรคอนกรีต\n2. ใช้เครื่องมือที่ผ่านการตรวจสภาพแล้วเท่านั้น\n3. ติดตั้งเซฟการ์ดที่เครื่องเจียรคอนกรีต\n4. ผู้ปฏิบัติงานต้องสวมใส่อุปกรณ์ PPE ที่กำหนดให้ครบ\n5. จัดพื้นที่การทำงานให้เหมาะสม\n', '\n\nPage : 121\n', '\n\nQuestion : ค่า Residual Risk Factor ของการใช้เครื่องเจียรคอนกรีตหลังจากมีมาตรการควบคุมแล้วคือเท่าใด\n', '\n\nAnswer : 6\n', '\n\nPage : 121\n', '\n\nQuestion : ระดับความเสี่ยง (Risk Priority) ของการใช้เครื่องเจียรคอนกรีตภายหลังการควบคุมอยู่ในระดับใด\n', '\n\nAnswer : Medium (ปานกลาง)\n', '\n\nPage : 121\n', '\n\nQuestion : อันตรายลำดับที่ 2 (Item 2) ในตารางประเมินความเสี่ยงคืออะไร\n', '\n\nAnswer : อันตรายจากการสัมผัสสารเคมี\n', '\n\nPage : 121\n', '\n\nQuestion : เหตุการณ์อันตรายที่อาจเกิดขึ้นจากการสัมผัสสารเคมีมีอะไรบ้าง\n', '\n\nAnswer :\n1. ผิวหนังไหม้\n2. ระคายเคืองผิวหนัง\n3. ผิวหนังอักเสบ\n4. เนื้อเยื่อตาไหม้\n5. ระคายเคืองดวงตา\n', '\n\nPage : 121\n', '\n\nQuestion : ค่า Risk Factor (RF) เริ่มต้นสำหรับอันตรายจากการสัมผัสสารเคมีคือเท่าใด\n', '\n\nAnswer : 9\n', '\n\nPage : 121\n', '\n\nQuestion : วิธีการลดความเสี่ยงสำหรับอันตรายจากการสัมผัสสารเคมีมีข้อปฏิบัติอย่างไรบ้าง\n', '\n\nAnswer :\n1. อบรมวิธีการปฐมพยาบาลผู้ป่วยที่สัมผัสสารเคมีเบื้องต้น\n2. จัดเตรียมอุปกรณ์ในการปฐมพยาบาล\n3. สวมใส่เครื่องป้องกันทุกครั้งเพื่อหลีกเลี่ยงการสัมผัสสารเคมีโดยตรง\n4. จัดอุปกรณ์สำหรับใช้กับสารเคมีให้เหมาะสม\n5. ตรวจสุขภาพผู้ปฏิบัติงาน เพื่อป้องกันผลกระทบในระยะยาว\n', '\n\nPage : 121\n', '\n\nQuestion : อันตรายลำดับที่ 3 (Item 3) คืออันตรายจากสาเหตุใด\n', '\n\nAnswer : อันตรายจากการสูดดมสารเคมี\n', '\n\nPage : 121\n', '\n\nQuestion : ผลกระทบต่อสุขภาพที่อาจเกิดขึ้นจากการสูดดมสารเคมีมีอะไรบ้าง\n', '\n\nAnswer :\n1. ระคายเคืองระบบทางเดินหายใจ\n2. วิงเวียนศีรษะ\n3. หมดสติ\n', '\n\nPage : 121\n', '\n\nQuestion : มาตรการลดความเสี่ยงที่เกี่ยวข้องกับหน้ากากป้องกันสำหรับอันตรายจากการสูดดมสารเคมีคืออะไร\n', '\n\nAnswer : หน้ากากป้องกันที่เหมาะสมกับลักษณะสารเคมี\n', '\n\nPage : 121\n', '\n\nQuestion : มาตรการลดความเสี่ยงเพิ่มเติมในกรณีวัสดุรั่วไหลสำหรับการสูดดมสารเคมีคืออะไร\n', '\n\nAnswer : อบรมวิธีการจัดการเมื่อวัสดุรั่วไหลหรือฟุ้งกระจาย\n', '\n\nPage : 121\n', '\n\nQuestion : เกณฑ์คะแนน Risk Factor สำหรับระดับความเสี่ยง "Low Risk" (ความเสี่ยงต่ำ) คือช่วงใด\n', '\n\nAnswer : 1 - 4\n', '\n\nPage : 121\n', '\n\nQuestion : เกณฑ์คะแนน Risk Factor สำหรับระดับความเสี่ยง "Medium Risk" (เสี่ยงปานกลาง) คือช่วงใด\n', '\n\nAnswer : 5 - 7\n', '\n\nPage : 121\n', '\n\nQuestion : เกณฑ์คะแนน Risk Factor สำหรับระดับความเสี่ยง "High Risk" (มีความเสี่ยงสูง) คือช่วงใด\n', '\n\nAnswer : 8 - 16\n', '\n\nPage : 121\n', '\n\nQuestion : อันตรายลำดับที่ 4 (Item 4) ในหน้า 122 ...
# 120

# %%
new_qa = []

for i in range(0, len(qa_result_list)-1, 3):
    # print(i)
    new_qa.append({
        'Question': qa_result_list[i].replace('Question :', '').replace('++++++++++++++++++++++', '').replace('\n', ''),
        'Answer': qa_result_list[i+1].replace('Answer :', '').replace('++++++++++++++++++++++', '').replace('\n', ''),
        'Page': qa_result_list[i+2].replace('++++++++++++++++++++++', '').replace('\n', '').replace('Page :', '').replace('Page:', '')
    })

# print(new_qa)

new_qa_df = pd.DataFrame(new_qa)
new_qa_df
# Out:
#                                              Question  \
# 0     เอกสารฉบับนี้มีรหัสเอกสาร (Document ID) ว่าอะไร
# 1    ชื่อโครงการที่ระบุในหน้าปกของเอกสารคือโครงการ...
# 2    บริษัทใดเป็นผู้จัดทำเอกสารการประเมินความเสี่ย...
# 3    ในตารางที่ 1 อันตรายลำดับที่ 1 (Item 1) เกิดจ...
# 4    เหตุการณ์อันตรายที่อาจเกิดขึ้น (Hazard Event/...
# 5    ระดับความเสี่ยงเริ่มต้น (Initial Risk Rating)...
# 6    ค่า Risk Factor (RF) เริ่มต้นสำหรับการใช้เครื...
# 7    วิธีการลดความเสี่ยง (Method of Minimization) ...
# 8    ค่า Residual Risk Factor ของการใช้เครื่องเจีย...
# 9    ระดับความเสี่ยง (Risk Priority) ของการใช้เครื...
# 10   อันตรายลำดับที่ 2 (Item 2) ในตารางประเมินความ...
# 11   เหตุการณ์อันตรายที่อาจเกิดขึ้นจากการสัมผัสสาร...
# 12   ค่า Risk Factor (RF) เริ่มต้นสำหรับอันตรายจาก...
# 13   วิธีการลดความเสี่ยงสำหรับอันตรายจากการสัมผัสส...
# 14   อันตรายลำดับที่ 3 (Item 3) คืออันตรายจากสาเหตุใด
# 15   ผลกระทบต่อสุขภาพที่อาจเกิดขึ้นจากการสูดดมสารเ...
# 16   มาตรการลดความเสี่ยงที่เกี่ยวข้องกับหน้ากากป้อ...
# 17   มาตรการลดความเสี่ยงเพิ่มเติมในกรณีวัสดุรั่วไห...
# 18   เกณฑ์คะแนน Risk Factor สำหรับระดับความเสี่ยง ...
# 19   เกณฑ์คะแนน Risk Factor สำหรับระดับความเสี่ยง ...
# 20   เกณฑ์คะแนน Risk Factor สำหรับระดับความเสี่ยง ...
# 21      อันตรายลำดับที่ 4 (Item 4) ในหน้า 122 คืออะไร
# 22   เหตุการณ์อันตรายที่อาจเกิดขึ้นจากการกลืนสารเค...
# 23   ระดับความเสี่ยงเริ่มต้น (Initial Risk Rating)...
# 24   ข้อห้ามสำคัญในการปฏิบัติงานเพื่อลดความเสี่ยงจ...
# 25   มาตรการด้านสุขอนามัยเพื่อลดความเสี่ยงจากการกล...
# 26   ค่า Residual Risk Factor สำหรับอันตรายจากการก...
# 27   สูตรการคำนวณค่า Risk Factor (RF) ตามเอกสารคือ...
# 28                              คำย่อ HCR หมายถึงอะไร
# 29                               คำย่อ PR หมายถึงอะไร
# 30    คำนิยามของระดับความรุนแรง (HCR) ระดับ 4 คืออะไร
# 31    คำนิยามของระดับความรุนแรง (HCR) ระดับ 3 คืออะไร
# 32    คำนิยามของระดับความรุนแรง (HCR) ระดับ 2 คืออะไร
# 33   คำนิยามของระดับความเป็นไปได้ (PR) ระดับ 4 คือ...
# 34   คำนิยามของระดับความเป็นไปได้ (PR) ระดับ 3 คือ...
# 35   คำนิยามของระดับความเป็นไปได้ (PR) ระดับ 1 คือ...
# 36   ขั้นตอนแรก (Step 1) ในหัวข้อ METHODOLOGY ของก...
# 37          ขั้นตอนที่ 3 ในหัวข้อ METHODOLOGY คืออะไร
# 38   ตามตาราง Risk Factor Matrix หาก HCR = 4 และ P...
# 39   เป้าหมายของการควบคุมความเสี่ยง (Controls shou...
#
#                                                Answer  Page
# 0                                            RA-RP-01   120
# 1    โครงการก่อสร้างอุโมงค์ระบายน้ำจากบึงหนองบอนลง...   120
# 2    บริษัท ซิโน-ไทย เอ็นจีเนียริ่ง แอนด์ คอนสตรัค...   120
# 3                 อันตรายจากการใช้เครื่องเจียรคอนกรีต   121
# 4                         1. ไฟฟ้าดูด2. โดนใบเจียรบาด   121
# 5                                     HCR = 4, PR = 3   121
# 6                                                  12   121
# 7   1. อบรมวิธีการป้องกันความเสี่ยงในการใช้เครื่อง...   121
# 8                                                   6   121
# 9                                    Medium (ปานกลาง)   121
# 10                         อันตรายจากการสัมผัสสารเคมี   121
# 11  1. ผิวหนังไหม้2. ระคายเคืองผิวหนัง3. ผิวหนังอั...   121
# 12                                                  9   121
# 13  1. อบรมวิธีการปฐมพยาบาลผู้ป่วยที่สัมผัสสารเคมี...   121
# 14                          อันตรายจากการสูดดมสารเคมี   121
# 15  1. ระคายเคืองระบบทางเดินหายใจ2. วิงเวียนศีรษะ3...   121
# 16           หน้ากากป้องกันที่เหมาะสมกับลักษณะสารเคมี   121
# 17   อบรมวิธีการจัดการเมื่อวัสดุรั่วไหลหรือฟุ้งกระจาย   121
# 18                                              1 - 4   121
# 19                                              5 - 7   121
# 20                                             8 - 16   121
# 21                           อันตรายจากการกลืนสารเคมี   122
# 22  1. เนื้อเยื่อในช่องปากถูกทำลาย2. ระบบทางเดินอา...   122
# 23                                  HCR 4, PR 1, RF 4   122
# 24     ห้ามนำอาหารมารับประทานในพื้นที่ทำงานโดยเด็ดขาด   122
# 25        ทำความสะอาดร่างกายทุกครั้งที่พักหรือเลิกงาน   122
# 26                                                  3   122
# 27                                      RF = HCR * PR   123
# 28   Hazard Class Rating (ระดับความรุนแรงของความเส...   123
# 29   Probability Rating (ระดับความเป็นไปได้ของความ...   123
# 30                    มีความรุนแรงมากถึงขั้นเสียชีวิต   123
# 31   มีความรุนแรงที่อาจทำให้บาดเจ็บสาหัสหรือเสียชีวิต   123
# 32      มีความรุนแรงในระดับที่ก่อให้เกิดการบาดเจ็บได้   123
# 33               มีความเสี่ยงที่จะเกิดขึ้นได้ตลอดเวลา   123
# 34   มีความเสี่ยงที่จะเกิดขึ้นหากภาวะแวดล้อมเอื้ออ...   123
# 35                           มีโอกาสน้อยที่จะเกิดขึ้น   123
# 36                           ระบุพื้นที่เสี่ยงอันตราย   123
# 37   คำนวณความเสี่ยงและมีการจัดอันดับความเสี่ยงเบื...   123
# 38                                                 16   123
# 39   A LOW RISK PRIORITY (ความเสี่ยงจะต่ำหากมีการค...   123

# %%
new_qa_df.to_csv(f'{root_path}\\table\\QA_content_8.csv', index=False)

# %% [markdown]
# # 9_Materials_Safety_Data

# %%
context = ""
for i in range(len(docs[docs['content'] == '9_Materials_Safety_Data'])):
    context += f"Page {docs[docs['content'] == '9_Materials_Safety_Data']['page'].iloc[i]}:\n{docs[docs['content'] == '9_Materials_Safety_Data']['text'].iloc[i]}\n\n"
    # print(docs[docs['content'] == '2_Repair_With_Cementitious_Mortar']['page'].iloc[i])
# print(context)

# %%
qa_result = generate_qa_from_docs(context, qa_example.iloc[0])

# %%
print(qa_result.split('<split>'))
qa_result_list = []
for qa in qa_result.split('<split>'):
    if qa != '++++++++++++++++++++++' and qa != '':
        qa_result_list.append(qa)
print(qa_result_list)
print(len(qa_result_list))
# Out:
# ['Question : การปฐมพยาบาลเบื้องต้นเมื่อดวงตาสัมผัสกับ Sika Skim Coat คืออะไร\n', '\nAnswer : ถอดคอนแทคเลนส์ ใช้น้ำสะอาดล้างดวงตาอย่างต่อเนื่อง ไม่น้อยกว่า 10 นาที แล้วพาไปพบแพทย์\n', '\nPage : 125\n', '\n\nQuestion : หากกลืน Sika Skim Coat เข้าไปและผู้ป่วยมีสติ ควรปฐมพยาบาลอย่างไร\n', '\nAnswer : ให้บ้วนปาก แล้วดื่มน้ำเพียงเล็กน้อย ห้ามทำให้อาเจียนโดยเด็ดขาด แล้วพาไปพบแพทย์ทันที\n', '\nPage : 125\n', '\n\nQuestion : อันตรายจากการสูดดม Sika Skim Coat มีผลกระทบอย่างไร\n', '\nAnswer : อาจทำให้เกิดการระคายเคืองอย่างมากต่อระบบทางเดินหายใจ\n', '\nPage : 125\n', '\n\nQuestion : อันตรายต่อผิวหนังจาก Sikadur 32 TH (PART A) มีความรุนแรงระดับใด\n', '\nAnswer : ทำให้ผิวหนังเกิดการระคายเคืองอย่างมาก\n', '\nPage : 125\n', '\n\nQuestion : การปฐมพยาบาลเมื่อกลืน Sikadur 32 TH (PART A) ควรทำอย่างไร\n', '\nAnswer : บ้วนปากแล้วดื่มน้ำสะอาด พยายามทำให้ผู้ป่วยอาเจียนออกมา แล้วพาไปพบแพทย์\n', '\nPage : 125\n', '\n\nQuestion : มาตรการป้องกันเมื่อใช้งาน Sikadur 32 TH (PART A) มีอะไรบ้าง\n', '\nAnswer : สวมแว่นตาป้องกันอันตรายที่ได้มาตรฐาน สวมเสื้อแขนยาวและถุงมือที่ป้องกันสารเคมีได้ ห้ามกลืนโดยเด็ดขาด ใช้หน้ากากป้องกันที่เหมาะสม และล้างมือให้สะอาดหลังปฏิบัติงาน\n', '\nPage : 126\n', '\n\nQuestion : อันตรายต่อดวงตาจาก Sikadur 32 TH (PART B) มีความรุนแรงระดับใด\n', '\nAnswer : ทำลายเนื้อเยื่อตาอย่างรุนแรงอาจทำให้ตาบอดได้\n', '\nPage : 126\n', '\n\nQuestion : การปฐมพยาบาลเมื่อผิวหนังสัมผัสกับ Sikadur 32 TH (PART B) ทำอย่างไร\n', '\nAnswer : ถอดเสื้อผ้าที่ปนเปื้อนออก แล้วล้างตัวด้วยสบู่และน้ำทันที หากโดนกัดกร่อนจนเป็นแผลแล้วไม่ทำการรักษา จะทำให้แผลสมานตัวช้า\n', '\nPage : 126\n', '\n\nQuestion : หากกลืน Sikadur 32 TH (PART B) ควรทำให้อาเจียนหรือไม่\n', '\nAnswer : ห้ามทำให้อาเจียนโดยเด็ดขาด ให้บ้วนปากแล้วดื่มน้ำสะอาดตามเป็นปริมาณมาก แล้วพาไปพบแพทย์โดยทันที\n', '\nPage : 126\n', '\n\nQuestion : อันตรายต่อดวงตาจาก Sikadur 41 CF Normal (PART A) คืออะไร\n', '\nAnswer : ทำให้เกิดการระคายเคืองและอาจทำลายดวงตาอย่างรุนแรง\n', '\nPage : 126\n', '\n\nQuestion : การปฐมพยาบาลผู้ป่วยที่สูดดม Sikadur 41 CF Normal (PART A) เป็นปริมาณมากทำอย่างไร\n', '\nAnswer : เคลื่อนย้ายผู้ป่วยไปยังพื้นที่ที่มีอากาศถ่ายเท และพาไปพบแพทย์\n', '\nPage : 127\n', '\n\nQuestion : การปฐมพยาบาลเมื่อกลืนสาร Sikadur 41 CF Normal (PART A) คืออะไร\n', '\nAnswer : บ้วนปากแล้วดื่มน้ำสะอาด พยายามทำให้ผู้ป่วยอาเจียนออกมา แล้วพาไปพบแพทย์\n', '\nPage : 127\n', '\n\nQuestion : ความรุนแรงของอันตรายต่อดวงตาจาก Sikadur 41 CF Normal (PART B) คืออะไร\n', '\nAnswer : ทำลายเนื้อเยื่อตาอย่างรุนแรงอาจทำให้ตาบอดได้\n', '\nPage : 127\n', '\n\nQuestion : ข้อห้ามสำคัญในการปฐมพยาบาลเมื่อกลืน Sikadur 41 CF Normal (PART B) คืออะไร\n', '\nAnswer : ห้ามทำให้อาเจียนโดยเด็ดขาด\n', '\nPage : 127\n', '\n\nQuestion : หากแผลที่เกิดจาก Sikadur 41 CF Normal (PART B) ไม่ได้รับการรักษาจะมีผลอย่างไร\n', '\nAnswer : จะทำให้แผลสมานตัวช้า\n', '\nPage : 127\n', '\n\nQuestion : อันตรายจากการสูดดม Sikadur 41 CF Normal (PART C) คืออะไร\n', '\nAnswer : อาจทำให้เกิดอาการวิงเวียนศีรษะ\n', '\nPage : 128\n', '\n\nQuestion : การปฐมพยาบาลเมื่อผิวหนังสัมผัส Sikadur 41 CF Normal (PART C) ทำอย่างไร\n', '\nAnswer : ถอดเสื้อผ้าที่ปนเปื้อน แล้วล้างตัวด้วยสบู่และน้ำสะอาดปริมาณมาก หากเกิดอาการแพ้ให้ไปพบแพทย์\n', '\nPage : 128\n', '\n\nQuestion : มาตรการป้องกันเมื่อใช้งาน Sikadur 41 CF Normal (PART C) มีอะไรบ้าง\n', '\nAnswer : สวมแว่นตาป้องกัน สวมเสื้อแขนยาว ถุงมือที่ป้องกันสารเคมีได้ ห้ามกลืน ใช้หน้ากากป้องกันที่เหมาะสม และล้างมือให้สะอาดหลังปฏิบัติงานเสร็จ\n', '\nPage : 128\n', '\n\nQuestion : ความรุนแรงของอันตรายต่อดวงตาจาก Sikadur 31 CF Normal (PART A) คืออะไร\n', '\nAnswer : อาจทำลายดวงตาอย่างรุนแรง\n', '\nPage : 128\n', '\n\nQuestion : ขั้นตอนการปฐมพยาบาลเมื่อกลืน Sikadur 31 CF Normal (PART A) คืออะไร\n', '\nAnswer : บ้วนปากแล้วดื่มน้ำสะอาด พยายามทำให้ผู้ป่วยอาเจียนออกมา แล้วพาไปพบแพทย์\n', '\nPage : 128\n', '\n\nQuestion : อันตรายต่อผิวหนังจาก Sikadur 31 CF Normal (PART A) คืออะไร\n', '\nAnswer : ทำให้เกิดการระคายเคืองที่ผิวหนัง\n', '\nPage : 128\n', '\n\nQuestion : อันตรายต่อดวงตาจาก Sikadur 31 CF Normal (PART B) มีความรุนแรงระดับใด\n', '\nAnswer ...
# ['Question : การปฐมพยาบาลเบื้องต้นเมื่อดวงตาสัมผัสกับ Sika Skim Coat คืออะไร\n', '\nAnswer : ถอดคอนแทคเลนส์ ใช้น้ำสะอาดล้างดวงตาอย่างต่อเนื่อง ไม่น้อยกว่า 10 นาที แล้วพาไปพบแพทย์\n', '\nPage : 125\n', '\n\nQuestion : หากกลืน Sika Skim Coat เข้าไปและผู้ป่วยมีสติ ควรปฐมพยาบาลอย่างไร\n', '\nAnswer : ให้บ้วนปาก แล้วดื่มน้ำเพียงเล็กน้อย ห้ามทำให้อาเจียนโดยเด็ดขาด แล้วพาไปพบแพทย์ทันที\n', '\nPage : 125\n', '\n\nQuestion : อันตรายจากการสูดดม Sika Skim Coat มีผลกระทบอย่างไร\n', '\nAnswer : อาจทำให้เกิดการระคายเคืองอย่างมากต่อระบบทางเดินหายใจ\n', '\nPage : 125\n', '\n\nQuestion : อันตรายต่อผิวหนังจาก Sikadur 32 TH (PART A) มีความรุนแรงระดับใด\n', '\nAnswer : ทำให้ผิวหนังเกิดการระคายเคืองอย่างมาก\n', '\nPage : 125\n', '\n\nQuestion : การปฐมพยาบาลเมื่อกลืน Sikadur 32 TH (PART A) ควรทำอย่างไร\n', '\nAnswer : บ้วนปากแล้วดื่มน้ำสะอาด พยายามทำให้ผู้ป่วยอาเจียนออกมา แล้วพาไปพบแพทย์\n', '\nPage : 125\n', '\n\nQuestion : มาตรการป้องกันเมื่อใช้งาน Sikadur 32 TH (PART A) มีอะไรบ้าง\n', '\nAnswer : สวมแว่นตาป้องกันอันตรายที่ได้มาตรฐาน สวมเสื้อแขนยาวและถุงมือที่ป้องกันสารเคมีได้ ห้ามกลืนโดยเด็ดขาด ใช้หน้ากากป้องกันที่เหมาะสม และล้างมือให้สะอาดหลังปฏิบัติงาน\n', '\nPage : 126\n', '\n\nQuestion : อันตรายต่อดวงตาจาก Sikadur 32 TH (PART B) มีความรุนแรงระดับใด\n', '\nAnswer : ทำลายเนื้อเยื่อตาอย่างรุนแรงอาจทำให้ตาบอดได้\n', '\nPage : 126\n', '\n\nQuestion : การปฐมพยาบาลเมื่อผิวหนังสัมผัสกับ Sikadur 32 TH (PART B) ทำอย่างไร\n', '\nAnswer : ถอดเสื้อผ้าที่ปนเปื้อนออก แล้วล้างตัวด้วยสบู่และน้ำทันที หากโดนกัดกร่อนจนเป็นแผลแล้วไม่ทำการรักษา จะทำให้แผลสมานตัวช้า\n', '\nPage : 126\n', '\n\nQuestion : หากกลืน Sikadur 32 TH (PART B) ควรทำให้อาเจียนหรือไม่\n', '\nAnswer : ห้ามทำให้อาเจียนโดยเด็ดขาด ให้บ้วนปากแล้วดื่มน้ำสะอาดตามเป็นปริมาณมาก แล้วพาไปพบแพทย์โดยทันที\n', '\nPage : 126\n', '\n\nQuestion : อันตรายต่อดวงตาจาก Sikadur 41 CF Normal (PART A) คืออะไร\n', '\nAnswer : ทำให้เกิดการระคายเคืองและอาจทำลายดวงตาอย่างรุนแรง\n', '\nPage : 126\n', '\n\nQuestion : การปฐมพยาบาลผู้ป่วยที่สูดดม Sikadur 41 CF Normal (PART A) เป็นปริมาณมากทำอย่างไร\n', '\nAnswer : เคลื่อนย้ายผู้ป่วยไปยังพื้นที่ที่มีอากาศถ่ายเท และพาไปพบแพทย์\n', '\nPage : 127\n', '\n\nQuestion : การปฐมพยาบาลเมื่อกลืนสาร Sikadur 41 CF Normal (PART A) คืออะไร\n', '\nAnswer : บ้วนปากแล้วดื่มน้ำสะอาด พยายามทำให้ผู้ป่วยอาเจียนออกมา แล้วพาไปพบแพทย์\n', '\nPage : 127\n', '\n\nQuestion : ความรุนแรงของอันตรายต่อดวงตาจาก Sikadur 41 CF Normal (PART B) คืออะไร\n', '\nAnswer : ทำลายเนื้อเยื่อตาอย่างรุนแรงอาจทำให้ตาบอดได้\n', '\nPage : 127\n', '\n\nQuestion : ข้อห้ามสำคัญในการปฐมพยาบาลเมื่อกลืน Sikadur 41 CF Normal (PART B) คืออะไร\n', '\nAnswer : ห้ามทำให้อาเจียนโดยเด็ดขาด\n', '\nPage : 127\n', '\n\nQuestion : หากแผลที่เกิดจาก Sikadur 41 CF Normal (PART B) ไม่ได้รับการรักษาจะมีผลอย่างไร\n', '\nAnswer : จะทำให้แผลสมานตัวช้า\n', '\nPage : 127\n', '\n\nQuestion : อันตรายจากการสูดดม Sikadur 41 CF Normal (PART C) คืออะไร\n', '\nAnswer : อาจทำให้เกิดอาการวิงเวียนศีรษะ\n', '\nPage : 128\n', '\n\nQuestion : การปฐมพยาบาลเมื่อผิวหนังสัมผัส Sikadur 41 CF Normal (PART C) ทำอย่างไร\n', '\nAnswer : ถอดเสื้อผ้าที่ปนเปื้อน แล้วล้างตัวด้วยสบู่และน้ำสะอาดปริมาณมาก หากเกิดอาการแพ้ให้ไปพบแพทย์\n', '\nPage : 128\n', '\n\nQuestion : มาตรการป้องกันเมื่อใช้งาน Sikadur 41 CF Normal (PART C) มีอะไรบ้าง\n', '\nAnswer : สวมแว่นตาป้องกัน สวมเสื้อแขนยาว ถุงมือที่ป้องกันสารเคมีได้ ห้ามกลืน ใช้หน้ากากป้องกันที่เหมาะสม และล้างมือให้สะอาดหลังปฏิบัติงานเสร็จ\n', '\nPage : 128\n', '\n\nQuestion : ความรุนแรงของอันตรายต่อดวงตาจาก Sikadur 31 CF Normal (PART A) คืออะไร\n', '\nAnswer : อาจทำลายดวงตาอย่างรุนแรง\n', '\nPage : 128\n', '\n\nQuestion : ขั้นตอนการปฐมพยาบาลเมื่อกลืน Sikadur 31 CF Normal (PART A) คืออะไร\n', '\nAnswer : บ้วนปากแล้วดื่มน้ำสะอาด พยายามทำให้ผู้ป่วยอาเจียนออกมา แล้วพาไปพบแพทย์\n', '\nPage : 128\n', '\n\nQuestion : อันตรายต่อผิวหนังจาก Sikadur 31 CF Normal (PART A) คืออะไร\n', '\nAnswer : ทำให้เกิดการระคายเคืองที่ผิวหนัง\n', '\nPage : 128\n', '\n\nQuestion : อันตรายต่อดวงตาจาก Sikadur 31 CF Normal (PART B) มีความรุนแรงระดับใด\n', '\nAnswer ...
# 120

# %%
new_qa = []

for i in range(0, len(qa_result_list)-1, 3):
    # print(i)
    new_qa.append({
        'Question': qa_result_list[i].replace('Question :', '').replace('++++++++++++++++++++++', '').replace('\n', ''),
        'Answer': qa_result_list[i+1].replace('Answer :', '').replace('++++++++++++++++++++++', '').replace('\n', ''),
        'Page': qa_result_list[i+2].replace('++++++++++++++++++++++', '').replace('\n', '').replace('Page :', '').replace('Page:', '')
    })

# print(new_qa)

new_qa_df = pd.DataFrame(new_qa)
new_qa_df
# Out:
#                                              Question  \
# 0    การปฐมพยาบาลเบื้องต้นเมื่อดวงตาสัมผัสกับ Sika...
# 1    หากกลืน Sika Skim Coat เข้าไปและผู้ป่วยมีสติ ...
# 2    อันตรายจากการสูดดม Sika Skim Coat มีผลกระทบอย...
# 3    อันตรายต่อผิวหนังจาก Sikadur 32 TH (PART A) ม...
# 4    การปฐมพยาบาลเมื่อกลืน Sikadur 32 TH (PART A) ...
# 5    มาตรการป้องกันเมื่อใช้งาน Sikadur 32 TH (PART...
# 6    อันตรายต่อดวงตาจาก Sikadur 32 TH (PART B) มีค...
# 7    การปฐมพยาบาลเมื่อผิวหนังสัมผัสกับ Sikadur 32 ...
# 8    หากกลืน Sikadur 32 TH (PART B) ควรทำให้อาเจีย...
# 9    อันตรายต่อดวงตาจาก Sikadur 41 CF Normal (PART...
# 10   การปฐมพยาบาลผู้ป่วยที่สูดดม Sikadur 41 CF Nor...
# 11   การปฐมพยาบาลเมื่อกลืนสาร Sikadur 41 CF Normal...
# 12   ความรุนแรงของอันตรายต่อดวงตาจาก Sikadur 41 CF...
# 13   ข้อห้ามสำคัญในการปฐมพยาบาลเมื่อกลืน Sikadur 4...
# 14   หากแผลที่เกิดจาก Sikadur 41 CF Normal (PART B...
# 15   อันตรายจากการสูดดม Sikadur 41 CF Normal (PART...
# 16   การปฐมพยาบาลเมื่อผิวหนังสัมผัส Sikadur 41 CF ...
# 17   มาตรการป้องกันเมื่อใช้งาน Sikadur 41 CF Norma...
# 18   ความรุนแรงของอันตรายต่อดวงตาจาก Sikadur 31 CF...
# 19   ขั้นตอนการปฐมพยาบาลเมื่อกลืน Sikadur 31 CF No...
# 20   อันตรายต่อผิวหนังจาก Sikadur 31 CF Normal (PA...
# 21   อันตรายต่อดวงตาจาก Sikadur 31 CF Normal (PART...
# 22   การปฐมพยาบาลเบื้องต้นเมื่อกลืน Sikadur 31 CF ...
# 23   การปฐมพยาบาลเมื่อผิวหนังสัมผัสกับ Sikadur 31 ...
# 24   อันตรายต่อดวงตาจาก Sikadur 52 TH (PART A) คือ...
# 25   อาการที่อาจเกิดขึ้นจากการสูดดม Sikadur 52 TH ...
# 26   การปฐมพยาบาลเมื่อกลืน Sikadur 52 TH (PART A) ...
# 27   อันตรายจากการกลืน Sikadur 52 TH (PART B) มีคว...
# 28   อันตรายต่อผิวหนังจาก Sikadur 52 TH (PART B) ค...
# 29   การปฐมพยาบาลเมื่อกลืน Sikadur 52 TH (PART B) ...
# 30   ข้อห้ามในการล้างตาเมื่อสัมผัสกับ Conpatch 300...
# 31          อันตรายต่อผิวหนังจาก Conpatch 300 คืออะไร
# 32       การปฐมพยาบาลเมื่อกลืน Conpatch 300 ทำอย่างไร
# 33   ข้อควรระวังในการปฐมพยาบาลเมื่อดวงตาสัมผัสกับ ...
# 34       อันตรายจากการกลืน Condur SC (PART A) คืออะไร
# 35   อันตรายต่อดวงตาจาก Condur SC (PART B) มีความร...
# 36   การปฐมพยาบาลเมื่อกลืน Condur SC (PART B) คืออะไร
# 37     อันตรายต่อผิวหนังจาก Renderoc Skimcoat คืออะไร
# 38   ความรุนแรงของอันตรายต่อดวงตาจาก Bee Brand Ski...
# 39   การปฐมพยาบาลเมื่อผิวหนังสัมผัสกับ Bee Brand S...
#
#                                                Answer  Page
# 0    ถอดคอนแทคเลนส์ ใช้น้ำสะอาดล้างดวงตาอย่างต่อเน...   125
# 1    ให้บ้วนปาก แล้วดื่มน้ำเพียงเล็กน้อย ห้ามทำให้...   125
# 2    อาจทำให้เกิดการระคายเคืองอย่างมากต่อระบบทางเด...   125
# 3               ทำให้ผิวหนังเกิดการระคายเคืองอย่างมาก   125
# 4    บ้วนปากแล้วดื่มน้ำสะอาด พยายามทำให้ผู้ป่วยอาเ...   125
# 5    สวมแว่นตาป้องกันอันตรายที่ได้มาตรฐาน สวมเสื้อ...   126
# 6        ทำลายเนื้อเยื่อตาอย่างรุนแรงอาจทำให้ตาบอดได้   126
# 7    ถอดเสื้อผ้าที่ปนเปื้อนออก แล้วล้างตัวด้วยสบู่...   126
# 8    ห้ามทำให้อาเจียนโดยเด็ดขาด ให้บ้วนปากแล้วดื่ม...   126
# 9    ทำให้เกิดการระคายเคืองและอาจทำลายดวงตาอย่างรุ...   126
# 10   เคลื่อนย้ายผู้ป่วยไปยังพื้นที่ที่มีอากาศถ่ายเ...   127
# 11   บ้วนปากแล้วดื่มน้ำสะอาด พยายามทำให้ผู้ป่วยอาเ...   127
# 12       ทำลายเนื้อเยื่อตาอย่างรุนแรงอาจทำให้ตาบอดได้   127
# 13                         ห้ามทำให้อาเจียนโดยเด็ดขาด   127
# 14                               จะทำให้แผลสมานตัวช้า   127
# 15                     อาจทำให้เกิดอาการวิงเวียนศีรษะ   128
# 16   ถอดเสื้อผ้าที่ปนเปื้อน แล้วล้างตัวด้วยสบู่และ...   128
# 17   สวมแว่นตาป้องกัน สวมเสื้อแขนยาว ถุงมือที่ป้อง...   128
# 18                           อาจทำลายดวงตาอย่างรุนแรง   128
# 19   บ้วนปากแล้วดื่มน้ำสะอาด พยายามทำให้ผู้ป่วยอาเ...   128
# 20                   ทำให้เกิดการระคายเคืองที่ผิวหนัง   128
# 21       ทำลายเนื้อเยื่อตาอย่างรุนแรงอาจทำให้ตาบอดได้   129
# 22   บ้วนปากแล้วดื่มน้ำสะอาดตามเป็นปริมาณมาก ห้ามท...   129
# 23   ถอดเสื้อผ้าที่ปนเปื้อนออก แล้วล้างตัวด้วยสบู่...   129
# 24                    ทำให้ดวงตาระคายเคืองอย่างรุนแรง   129
# 25                     อาจทำให้เกิดอาการวิงเวียนศีรษะ   129
# 26   บ้วนปากแล้วดื่มน้ำสะอาดตาม พยายามทำให้อาเจียน...   129
# 27                            อาจเป็นอันตรายถึงตายได้   130
# 28                        ทำให้ผิวหนังไหม้อย่างรุนแรง   130
# 29   บ้วนปากแล้วดื่มน้ำสะอาดตามเป็นปริมาณมาก ห้ามท...   130
# 30   ห้ามใช้สารเคมีที่เป็นตัวทำละลาย หรือ ทินเนอร์...   130
# 31   ทำให้เกิดการระคายเคืองผิวหนัง และมีอาการระคาย...   130
# 32   บ้วนปากแล้วดื่มน้ำสะอาดตามเป็นปริมาณมาก ห้ามท...   131
# 33   ห้ามใช้สารเคมีที่เป็นตัวทำละลาย หรือ ทินเนอร์...   131
# 34   ทำให้เกิดอาการระคายเคืองต่อระบบทางเดินและย่อย...   131
# 35   ทำให้เกิดการระคายเคืองและไหม้อย่างรุนแรงต่อดวงตา   132
# 36   บ้วนปากแล้วดื่มน้ำสะอาดตามเป็นปริมาณมาก ห้ามท...   132
# 37     อาจเกิดอาการแพ้ที่ผิวหนัง และมีอาการระคายเคือง   132
# 38          ทำให้เกิดการระคายเคืองที่ดวงตาอย่างรุนแรง   133
# 39   ถอดเสื้อผ้าที่ปนเปื้อนออก ล้างตัวด้วยสบู่และน...   133

# %%
new_qa_df.to_csv(f'{root_path}\\table\\QA_content_9.csv', index=False)

# %% [markdown]
# # 10_Preventative_Measures_And_Revise_Environment_Impact

# %%
context = ""
for i in range(len(docs[docs['content'] == '10_Preventative_Measures_And_Revise_Environment_Impact'])):
    context += f"Page {docs[docs['content'] == '10_Preventative_Measures_And_Revise_Environment_Impact']['page'].iloc[i]}:\n{docs[docs['content'] == '10_Preventative_Measures_And_Revise_Environment_Impact']['text'].iloc[i]}\n\n"
    # print(docs[docs['content'] == '2_Repair_With_Cementitious_Mortar']['page'].iloc[i])
# print(context)

# %%
qa_result = generate_qa_from_docs(context, qa_example.iloc[0])

# %%
print(qa_result.split('<split>'))
qa_result_list = []
for qa in qa_result.split('<split>'):
    if qa != '++++++++++++++++++++++' and qa != '':
        qa_result_list.append(qa)
print(qa_result_list)
print(len(qa_result_list))
# Out:
# ['Question : เอกสาร EV-TN-01 เป็นเอกสารเกี่ยวกับเรื่องอะไรและสำหรับโครงการใด\n', '\nAnswer : เอกสารฉบับนี้เกี่ยวกับมาตรการป้องกันผลกระทบต่อสิ่งแวดล้อม (Preventative measures and revise environmental impact) สำหรับโครงการอุโมงค์ระบายน้ำบึงหนองบอนลงสู่แม่น้ำเจ้าพระยา (Sewerage Tunnel Bung Nong Bon to Chaophraya River)\n', '\nPage : 135\n', '\n\nQuestion : มาตรการป้องกันผลกระทบต่อสิ่งแวดล้อมของงานซ่อมแซมชิ้นส่วนอุโมงค์แบ่งออกเป็นกี่หมวด อะไรบ้าง\n', '\nAnswer : แบ่งออกเป็น 2 หมวด ได้แก่\n1. มาตรการป้องกันผลกระทบต่อสิ่งแวดล้อมสำหรับวัสดุซ่อมแบบผง\n2. มาตรการป้องกันผลกระทบต่อสิ่งแวดล้อมสำหรับวัสดุซ่อมแบบของเหลว\n', '\nPage : 135\n', '\n\nQuestion : วัสดุซ่อมแบบผงที่ระบุในเอกสารมีรายชื่ออะไรบ้าง\n', '\nAnswer : รายชื่อวัสดุซ่อมแบบผง ได้แก่:\n1. Sika Skim Coat\n2. Conpatch 300\n3. Renderoc Skimcoat\n4. ปูนฉาบแต่งตราผึ้ง 124\n5. ปูนฉาบแต่งตราผึ้ง 124L\n6. ปูนฉาบแต่งตราผึ้ง 135F\n', '\nPage : 135\n', '\n\nQuestion : หากวัสดุซ่อมแบบผงปนเปื้อนในท่อระบายน้ำเสีย มีวิธีการแก้ไขอย่างไร\n', '\nAnswer : วิธีการแก้ไขคือ ให้ปิดทางระบายท่อน้ำทิ้ง แล้วกำจัดน้ำที่ปนเปื้อนในท่อระบายออก ห้ามทิ้งน้ำที่ปนเปื้อนลงพื้นดินโดยเด็ดขาด หากปนเปื้อนในปริมาณมากจนไม่สามารถกำจัดทิ้งได้ จะต้องติดต่อหน่วยงานที่สามารถกำจัดสารเคมีได้ทันที\n', '\nPage : 135\n', '\n\nQuestion : มาตรการป้องกันเพื่อไม่ให้วัสดุซ่อมแบบผงปนเปื้อนในท่อระบายน้ำเสียมีอะไรบ้าง\n', '\nAnswer : มาตรการป้องกันมีดังนี้:\n1. แบ่งพื้นที่สำหรับงานซ่อมแซม\n2. ห้ามใช้วัสดุซ่อมนอกพื้นที่ที่จัดเตรียมไว้โดยเด็ดขาด\n3. หากบรรจุภัณฑ์ฉีกขาด ให้เปลี่ยนบรรจุภัณฑ์ใหม่ หรือภาชนะที่สามารถปิดมิดชิดได้\n4. ห้ามนำบรรจุภัณฑ์เก่ามาใช้โดยเด็ดขาด\n', '\nPage : 135\n', '\n\nQuestion : หากวัสดุซ่อมแบบผงปนเปื้อนในแหล่งน้ำ ต้องดำเนินการแก้ไขอย่างไร\n', '\nAnswer : ต้องแจ้งหน่วยงานของรัฐที่ดูแลเรื่องสิ่งแวดล้อมทันที เนื่องจากวัสดุซ่อมดังกล่าวก่อให้เกิดผลกระทบต่อสิ่งมีชีวิตโดยตรง\n', '\nPage : 135\n', '\n\nQuestion : การจัดพื้นที่สำหรับงานซ่อมแซมวัสดุแบบผงเพื่อป้องกันการปนเปื้อนในแหล่งน้ำ มีข้อกำหนดอย่างไร\n', '\nAnswer : ต้องจัดพื้นที่สำหรับงานซ่อมแซมให้อยู่ห่างจากแหล่งน้ำธรรมชาติ และจัดให้มีบ่อพักน้ำและบ่อบำบัดก่อนปล่อยน้ำออกจากโรงงาน\n', '\nPage : 135\n', '\n\nQuestion : หากวัสดุซ่อมแบบผงรั่วไหลลงดินในปริมาณไม่มาก มีวิธีการแก้ไขอย่างไร\n', '\nAnswer : ให้กวาดวัสดุซ่อมใส่ถุงดำแล้วทิ้งในพื้นที่สำหรับทิ้งสารเคมี\n', '\nPage : 136\n', '\n\nQuestion : กรณีบรรจุภัณฑ์วัสดุซ่อมแบบผงฉีกขาดจนรั่วไหลจำนวนมาก มีขั้นตอนการจัดการอย่างไร\n', '\nAnswer : ขั้นตอนการจัดการมีดังนี้:\n1. เปลี่ยนบรรจุภัณฑ์หรือภาชนะที่สามารถปิดได้มิดชิด\n2. ขนย้ายออกจากจุดที่รั่วไหล\n3. กวาดวัสดุที่รั่วไหลกองรวมกัน\n4. ใช้ผ้าหรือกระสอบคลุมกองวัสดุเพื่อป้องกันการฟุ้งกระจาย\n5. ตักวัสดุซ่อมใส่ถุงดำทิ้งในพื้นที่สำหรับทิ้งสารเคมี\n', '\nPage : 136\n', '\n\nQuestion : พื้นที่สำหรับงานซ่อมแซมวัสดุแบบผงต้องมีลักษณะอย่างไรเพื่อป้องกันผลกระทบต่อคุณภาพดิน\n', '\nAnswer : พื้นที่สำหรับงานซ่อมแซมต้องเป็นพื้นคอนกรีต เพื่อป้องกันไม่ให้วัสดุซ่อมปนเปื้อนในดิน\n', '\nPage : 136\n', '\n\nQuestion : อุปกรณ์ที่ใช้ดับเพลิงสำหรับกรณีเกิดเพลิงไหม้วัสดุซ่อมแบบผงมีอะไรบ้าง\n', '\nAnswer : อุปกรณ์ที่ใช้ดับเพลิง ได้แก่:\n1. โฟมดับเพลิงชนิดทนแอลกอฮอล์\n2. ถังดับเพลิงชนิด CO2\n3. ถังดับเพลิงแบบผง\n', '\nPage : 136\n', '\n\nQuestion : หากเกิดเพลิงไหม้จากวัสดุซ่อมแบบผง ผู้ได้รับมอบหมายต้องดำเนินการกับวัสดุที่ยังไม่ติดไฟอย่างไร\n', '\nAnswer : ให้เคลื่อนย้ายวัสดุซ่อมที่ยังไม่ติดไฟหรือยังสามารถเคลื่อนย้ายได้ออกจากพื้นที่ เพื่อป้องกันการลุกลามของเพลิง\n', '\nPage : 136\n', '\n\nQuestion : ข้อห้ามในการใช้น้ำดับเพลิงกรณีเกิดเหตุกับวัสดุซ่อมคืออะไร\n', '\nAnswer : ห้ามใช้เครื่องฉีดน้ำแรงดันสูงโดยเด็ดขาด (ให้ใช้น้ำฉีดเพื่อลดอุณหภูมิก่อนเมื่ออุปกรณ์ดับเพลิงอยู่ห่างจากพื้นที่)\n', '\nPage : 136\n', '\n\nQuestion : หากเพลิงลุกไหม้วัสดุซ่อมแบบผงจำนวนมาก ผู้ผจญเพลิงต้องสวมใส่อุปกรณ์ป้องกันอะไร\n', '\nAnswer : ต้องสวมใส่หน้ากาก N95 เพื่อป้องกันการสูดดมสารเคมี\n', '\nPage : 136\n', '\n\nQuestion : วัสดุซ่อมแบบของเหลวที่ระบุในเอกสารมีรายชื่ออะไรบ้าง\n', '\nAnswer : รายชื่อวัสดุซ่อมแบบของเหลว ได้แก่:\n1. Sikadur 32TH\n2. Sikadur 52 TH\n3. Sikadur 31 CF Normal\n4. Sikadur 41 CF Normal\n5. Condur SC\n', '\nPag ...
# ['Question : เอกสาร EV-TN-01 เป็นเอกสารเกี่ยวกับเรื่องอะไรและสำหรับโครงการใด\n', '\nAnswer : เอกสารฉบับนี้เกี่ยวกับมาตรการป้องกันผลกระทบต่อสิ่งแวดล้อม (Preventative measures and revise environmental impact) สำหรับโครงการอุโมงค์ระบายน้ำบึงหนองบอนลงสู่แม่น้ำเจ้าพระยา (Sewerage Tunnel Bung Nong Bon to Chaophraya River)\n', '\nPage : 135\n', '\n\nQuestion : มาตรการป้องกันผลกระทบต่อสิ่งแวดล้อมของงานซ่อมแซมชิ้นส่วนอุโมงค์แบ่งออกเป็นกี่หมวด อะไรบ้าง\n', '\nAnswer : แบ่งออกเป็น 2 หมวด ได้แก่\n1. มาตรการป้องกันผลกระทบต่อสิ่งแวดล้อมสำหรับวัสดุซ่อมแบบผง\n2. มาตรการป้องกันผลกระทบต่อสิ่งแวดล้อมสำหรับวัสดุซ่อมแบบของเหลว\n', '\nPage : 135\n', '\n\nQuestion : วัสดุซ่อมแบบผงที่ระบุในเอกสารมีรายชื่ออะไรบ้าง\n', '\nAnswer : รายชื่อวัสดุซ่อมแบบผง ได้แก่:\n1. Sika Skim Coat\n2. Conpatch 300\n3. Renderoc Skimcoat\n4. ปูนฉาบแต่งตราผึ้ง 124\n5. ปูนฉาบแต่งตราผึ้ง 124L\n6. ปูนฉาบแต่งตราผึ้ง 135F\n', '\nPage : 135\n', '\n\nQuestion : หากวัสดุซ่อมแบบผงปนเปื้อนในท่อระบายน้ำเสีย มีวิธีการแก้ไขอย่างไร\n', '\nAnswer : วิธีการแก้ไขคือ ให้ปิดทางระบายท่อน้ำทิ้ง แล้วกำจัดน้ำที่ปนเปื้อนในท่อระบายออก ห้ามทิ้งน้ำที่ปนเปื้อนลงพื้นดินโดยเด็ดขาด หากปนเปื้อนในปริมาณมากจนไม่สามารถกำจัดทิ้งได้ จะต้องติดต่อหน่วยงานที่สามารถกำจัดสารเคมีได้ทันที\n', '\nPage : 135\n', '\n\nQuestion : มาตรการป้องกันเพื่อไม่ให้วัสดุซ่อมแบบผงปนเปื้อนในท่อระบายน้ำเสียมีอะไรบ้าง\n', '\nAnswer : มาตรการป้องกันมีดังนี้:\n1. แบ่งพื้นที่สำหรับงานซ่อมแซม\n2. ห้ามใช้วัสดุซ่อมนอกพื้นที่ที่จัดเตรียมไว้โดยเด็ดขาด\n3. หากบรรจุภัณฑ์ฉีกขาด ให้เปลี่ยนบรรจุภัณฑ์ใหม่ หรือภาชนะที่สามารถปิดมิดชิดได้\n4. ห้ามนำบรรจุภัณฑ์เก่ามาใช้โดยเด็ดขาด\n', '\nPage : 135\n', '\n\nQuestion : หากวัสดุซ่อมแบบผงปนเปื้อนในแหล่งน้ำ ต้องดำเนินการแก้ไขอย่างไร\n', '\nAnswer : ต้องแจ้งหน่วยงานของรัฐที่ดูแลเรื่องสิ่งแวดล้อมทันที เนื่องจากวัสดุซ่อมดังกล่าวก่อให้เกิดผลกระทบต่อสิ่งมีชีวิตโดยตรง\n', '\nPage : 135\n', '\n\nQuestion : การจัดพื้นที่สำหรับงานซ่อมแซมวัสดุแบบผงเพื่อป้องกันการปนเปื้อนในแหล่งน้ำ มีข้อกำหนดอย่างไร\n', '\nAnswer : ต้องจัดพื้นที่สำหรับงานซ่อมแซมให้อยู่ห่างจากแหล่งน้ำธรรมชาติ และจัดให้มีบ่อพักน้ำและบ่อบำบัดก่อนปล่อยน้ำออกจากโรงงาน\n', '\nPage : 135\n', '\n\nQuestion : หากวัสดุซ่อมแบบผงรั่วไหลลงดินในปริมาณไม่มาก มีวิธีการแก้ไขอย่างไร\n', '\nAnswer : ให้กวาดวัสดุซ่อมใส่ถุงดำแล้วทิ้งในพื้นที่สำหรับทิ้งสารเคมี\n', '\nPage : 136\n', '\n\nQuestion : กรณีบรรจุภัณฑ์วัสดุซ่อมแบบผงฉีกขาดจนรั่วไหลจำนวนมาก มีขั้นตอนการจัดการอย่างไร\n', '\nAnswer : ขั้นตอนการจัดการมีดังนี้:\n1. เปลี่ยนบรรจุภัณฑ์หรือภาชนะที่สามารถปิดได้มิดชิด\n2. ขนย้ายออกจากจุดที่รั่วไหล\n3. กวาดวัสดุที่รั่วไหลกองรวมกัน\n4. ใช้ผ้าหรือกระสอบคลุมกองวัสดุเพื่อป้องกันการฟุ้งกระจาย\n5. ตักวัสดุซ่อมใส่ถุงดำทิ้งในพื้นที่สำหรับทิ้งสารเคมี\n', '\nPage : 136\n', '\n\nQuestion : พื้นที่สำหรับงานซ่อมแซมวัสดุแบบผงต้องมีลักษณะอย่างไรเพื่อป้องกันผลกระทบต่อคุณภาพดิน\n', '\nAnswer : พื้นที่สำหรับงานซ่อมแซมต้องเป็นพื้นคอนกรีต เพื่อป้องกันไม่ให้วัสดุซ่อมปนเปื้อนในดิน\n', '\nPage : 136\n', '\n\nQuestion : อุปกรณ์ที่ใช้ดับเพลิงสำหรับกรณีเกิดเพลิงไหม้วัสดุซ่อมแบบผงมีอะไรบ้าง\n', '\nAnswer : อุปกรณ์ที่ใช้ดับเพลิง ได้แก่:\n1. โฟมดับเพลิงชนิดทนแอลกอฮอล์\n2. ถังดับเพลิงชนิด CO2\n3. ถังดับเพลิงแบบผง\n', '\nPage : 136\n', '\n\nQuestion : หากเกิดเพลิงไหม้จากวัสดุซ่อมแบบผง ผู้ได้รับมอบหมายต้องดำเนินการกับวัสดุที่ยังไม่ติดไฟอย่างไร\n', '\nAnswer : ให้เคลื่อนย้ายวัสดุซ่อมที่ยังไม่ติดไฟหรือยังสามารถเคลื่อนย้ายได้ออกจากพื้นที่ เพื่อป้องกันการลุกลามของเพลิง\n', '\nPage : 136\n', '\n\nQuestion : ข้อห้ามในการใช้น้ำดับเพลิงกรณีเกิดเหตุกับวัสดุซ่อมคืออะไร\n', '\nAnswer : ห้ามใช้เครื่องฉีดน้ำแรงดันสูงโดยเด็ดขาด (ให้ใช้น้ำฉีดเพื่อลดอุณหภูมิก่อนเมื่ออุปกรณ์ดับเพลิงอยู่ห่างจากพื้นที่)\n', '\nPage : 136\n', '\n\nQuestion : หากเพลิงลุกไหม้วัสดุซ่อมแบบผงจำนวนมาก ผู้ผจญเพลิงต้องสวมใส่อุปกรณ์ป้องกันอะไร\n', '\nAnswer : ต้องสวมใส่หน้ากาก N95 เพื่อป้องกันการสูดดมสารเคมี\n', '\nPage : 136\n', '\n\nQuestion : วัสดุซ่อมแบบของเหลวที่ระบุในเอกสารมีรายชื่ออะไรบ้าง\n', '\nAnswer : รายชื่อวัสดุซ่อมแบบของเหลว ได้แก่:\n1. Sikadur 32TH\n2. Sikadur 52 TH\n3. Sikadur 31 CF Normal\n4. Sikadur 41 CF Normal\n5. Condur SC\n', '\nPag ...
# 120

# %%
new_qa = []

for i in range(0, len(qa_result_list)-1, 3):
    # print(i)
    new_qa.append({
        'Question': qa_result_list[i].replace('Question :', '').replace('++++++++++++++++++++++', '').replace('\n', ''),
        'Answer': qa_result_list[i+1].replace('Answer :', '').replace('++++++++++++++++++++++', '').replace('\n', ''),
        'Page': qa_result_list[i+2].replace('++++++++++++++++++++++', '').replace('\n', '').replace('Page :', '').replace('Page:', '')
    })

# print(new_qa)

new_qa_df = pd.DataFrame(new_qa)
new_qa_df
# Out:
#                                              Question  \
# 0    เอกสาร EV-TN-01 เป็นเอกสารเกี่ยวกับเรื่องอะไร...
# 1    มาตรการป้องกันผลกระทบต่อสิ่งแวดล้อมของงานซ่อม...
# 2      วัสดุซ่อมแบบผงที่ระบุในเอกสารมีรายชื่ออะไรบ้าง
# 3    หากวัสดุซ่อมแบบผงปนเปื้อนในท่อระบายน้ำเสีย มี...
# 4    มาตรการป้องกันเพื่อไม่ให้วัสดุซ่อมแบบผงปนเปื้...
# 5    หากวัสดุซ่อมแบบผงปนเปื้อนในแหล่งน้ำ ต้องดำเนิ...
# 6    การจัดพื้นที่สำหรับงานซ่อมแซมวัสดุแบบผงเพื่อป...
# 7    หากวัสดุซ่อมแบบผงรั่วไหลลงดินในปริมาณไม่มาก ม...
# 8    กรณีบรรจุภัณฑ์วัสดุซ่อมแบบผงฉีกขาดจนรั่วไหลจำ...
# 9    พื้นที่สำหรับงานซ่อมแซมวัสดุแบบผงต้องมีลักษณะ...
# 10   อุปกรณ์ที่ใช้ดับเพลิงสำหรับกรณีเกิดเพลิงไหม้ว...
# 11   หากเกิดเพลิงไหม้จากวัสดุซ่อมแบบผง ผู้ได้รับมอ...
# 12   ข้อห้ามในการใช้น้ำดับเพลิงกรณีเกิดเหตุกับวัสด...
# 13   หากเพลิงลุกไหม้วัสดุซ่อมแบบผงจำนวนมาก ผู้ผจญเ...
# 14   วัสดุซ่อมแบบของเหลวที่ระบุในเอกสารมีรายชื่ออะ...
# 15   หากพบวัสดุซ่อมแบบของเหลวปนเปื้อนปริมาณมากในท่...
# 16   มาตรการป้องกันเพิ่มเติมสำหรับการใช้วัสดุซ่อมแ...
# 17   หากวัสดุซ่อมแบบของเหลวปนเปื้อนในแหล่งน้ำ ต้อง...
# 18   การจัดการน้ำทิ้งจากพื้นที่ซ่อมแซมวัสดุแบบของเ...
# 19   หากวัสดุซ่อมแบบของเหลวรั่วไหลสัมผัสกับพื้นดิน...
# 20   หลังจากใช้ทรายหรือขี้เลื่อยดูดซับวัสดุซ่อมแบบ...
# 21   เพื่อป้องกันไม่ให้วัสดุซ่อมแบบของเหลวปนเปื้อน...
# 22   อุปกรณ์ดับเพลิงที่ระบุไว้สำหรับกรณีเกิดเพลิงไ...
# 23   หากถังดับเพลิงอยู่ห่างจากพื้นที่เกิดเหตุเพลิง...
# 24   การป้องกันการสูดดมสารเคมีกรณีเพลิงลุกไหม้วัสด...
# 25   ในกรณีเกิดเพลิงไหม้จากวัสดุซ่อม มาตรการแรกที่...
# 26   ข้อห้ามเกี่ยวกับบรรจุภัณฑ์เก่าสำหรับวัสดุซ่อม...
# 27   หากเกิดการปนเปื้อนของวัสดุซ่อมแบบผงในท่อระบาย...
# 28   ผลิตภัณฑ์ปูนฉาบแต่งตราผึ้งรุ่นใดบ้างที่ระบุใน...
# 29   เหตุผลที่ต้องแจ้งหน่วยงานรัฐทันทีหากวัสดุซ่อม...
# 30   ผลิตภัณฑ์ Sikadur รุ่นใดบ้างที่ระบุในรายการวั...
# 31   หากวัสดุซ่อมแบบผงรั่วไหลจำนวนมาก ทำไมต้องใช้ผ...
# 32   ภาชนะที่ใช้เปลี่ยนแทนบรรจุภัณฑ์ที่ฉีกขาดของวั...
# 33   วันที่ออกเอกสาร (Issue Date) ของเอกสารฉบับนี้...
# 34   ข้อควรระวังในการใช้น้ำดับเพลิงกรณีวัสดุซ่อมแบ...
# 35   วิธีการกำจัดวัสดุดูดซับ (ทราย/ขี้เลื่อย) ที่ป...
# 36   การใช้วัสดุซ่อมแบบผงนอกพื้นที่ที่จัดเตรียมไว้...
# 37   หากพบการปนเปื้อนปริมาณมากในท่อระบายน้ำเสียจาก...
# 38   ใครมีหน้าที่เป็นผู้ผจญเพลิงเคลื่อนย้ายวัสดุซ่...
# 39   วัสดุซ่อม Condur SC จัดอยู่ในประเภทวัสดุซ่อมแ...
#
#                                                Answer  Page
# 0    เอกสารฉบับนี้เกี่ยวกับมาตรการป้องกันผลกระทบต่...   135
# 1    แบ่งออกเป็น 2 หมวด ได้แก่1. มาตรการป้องกันผลก...   135
# 2    รายชื่อวัสดุซ่อมแบบผง ได้แก่:1. Sika Skim Coa...   135
# 3    วิธีการแก้ไขคือ ให้ปิดทางระบายท่อน้ำทิ้ง แล้ว...   135
# 4    มาตรการป้องกันมีดังนี้:1. แบ่งพื้นที่สำหรับงา...   135
# 5    ต้องแจ้งหน่วยงานของรัฐที่ดูแลเรื่องสิ่งแวดล้อ...   135
# 6    ต้องจัดพื้นที่สำหรับงานซ่อมแซมให้อยู่ห่างจากแ...   135
# 7    ให้กวาดวัสดุซ่อมใส่ถุงดำแล้วทิ้งในพื้นที่สำหร...   136
# 8    ขั้นตอนการจัดการมีดังนี้:1. เปลี่ยนบรรจุภัณฑ์...   136
# 9    พื้นที่สำหรับงานซ่อมแซมต้องเป็นพื้นคอนกรีต เพ...   136
# 10   อุปกรณ์ที่ใช้ดับเพลิง ได้แก่:1. โฟมดับเพลิงชน...   136
# 11   ให้เคลื่อนย้ายวัสดุซ่อมที่ยังไม่ติดไฟหรือยังส...   136
# 12   ห้ามใช้เครื่องฉีดน้ำแรงดันสูงโดยเด็ดขาด (ให้ใ...   136
# 13   ต้องสวมใส่หน้ากาก N95 เพื่อป้องกันการสูดดมสาร...   136
# 14   รายชื่อวัสดุซ่อมแบบของเหลว ได้แก่:1. Sikadur ...   137
# 15   ให้ปิดทางระบายท่อน้ำทิ้งแล้วแจ้งหน่วยงานที่เก...   137
# 16      ให้กำหนดตัวผู้ที่สามารถใช้วัสดุซ่อมแบบเหลวได้   137
# 17   แจ้งหน่วยงานของรัฐที่ดูแลเรื่องสิ่งแวดล้อมโดย...   137
# 18   ต้องจัดให้มีบ่อพักน้ำและบ่อบำบัดก่อนปล่อยน้ำอ...   137
# 19   ให้ใช้ทรายหรือขี้เลื่อย กองทับวัสดุที่รั่วไหล...   138
# 20   ให้กวาดวัสดุดูดซับใส่ถุงดำแล้วทิ้งในพื้นที่สำ...   138
# 21         พื้นที่สำหรับงานซ่อมแซมต้องเป็นพื้นคอนกรีต   138
# 22   1. โฟมดับเพลิงชนิดทนแอลกอฮอล์2. ถังดับเพลิงชน...   138
# 23   ให้ใช้น้ำฉีดเพื่อลดอุณหภูมิก่อน แต่ห้ามใช้เคร...   138
# 24                                        หน้ากาก N95   138
# 25       ให้อพยพผู้ที่ไม่เกี่ยวข้องออกจากพื้นที่ทันที   136
# 26                ห้ามนำบรรจุภัณฑ์เก่ามาใช้โดยเด็ดขาด   135
# 27          ห้ามทิ้งน้ำที่ปนเปื้อนลงพื้นดินโดยเด็ดขาด   135
# 28               ปูนฉาบแต่งตราผึ้ง 124, 124L และ 135F   135
# 29   เนื่องจากวัสดุซ่อมดังกล่าวก่อให้เกิดผลกระทบต่...   137
# 30   Sikadur 32TH, Sikadur 52 TH, Sikadur 31 CF No...   137
# 31                          เพื่อป้องกันการฟุ้งกระจาย   136
# 32                 ต้องเป็นภาชนะที่สามารถปิดมิดชิดได้   137
# 33                                          14/2/2017   135
# 34            ห้ามใช้เครื่องฉีดน้ำแรงดันสูงโดยเด็ดขาด   138
# 35     กวาดใส่ถุงดำแล้วทิ้งในพื้นที่สำหรับทิ้งสารเคมี   138
# 36   ไม่สามารถทำได้ ห้ามใช้วัสดุซ่อมนอกพื้นที่ที่จ...   135
# 37                           ให้ปิดทางระบายท่อน้ำทิ้ง   137
# 38                                ผู้ที่ได้รับมอบหมาย   138
# 39                                วัสดุซ่อมแบบของเหลว   137

# %%
new_qa_df.to_csv(f'{root_path}\\table\\QA_content_10.csv', index=False)

# %% [markdown]
# # QA Analysis

# %%
qa1 = pd.read_csv(f'{root_path}\\table\\QA_content_1.csv')
qa2 = pd.read_csv(f'{root_path}\\table\\QA_content_2.csv')
qa3 = pd.read_csv(f'{root_path}\\table\\QA_content_3.csv')
qa4 = pd.read_csv(f'{root_path}\\table\\QA_content_4.csv')
qa5 = pd.read_csv(f'{root_path}\\table\\QA_content_5.csv')
qa6 = pd.read_csv(f'{root_path}\\table\\QA_content_6.csv')
qa7 = pd.read_csv(f'{root_path}\\table\\QA_content_7.csv')
qa8 = pd.read_csv(f'{root_path}\\table\\QA_content_8.csv')
qa9 = pd.read_csv(f'{root_path}\\table\\QA_content_9.csv')
qa10 = pd.read_csv(f'{root_path}\\table\\QA_content_10.csv')

# %%
# # remove string 'Page' from 'Page' column
# # qa1['Page'] = qa1['Page'].str.replace('Page', '').replace('Page :', '').replace('Page:', '').str.strip()
# qa2['Page'] = qa2['Page'].str.replace('Page', '').replace('Page :', '').replace('Page:', '').replace(': ', '').str.strip()
# qa3['Page'] = qa3['Page'].str.replace('Page', '').replace('Page :', '').replace('Page:', '').replace(': ', '').str.strip()
# # qa4['Page'] = qa4['Page'].str.replace('Page', '').replace('Page :', '').replace('Page:', '').str.strip()
# qa5['Page'] = qa5['Page'].str.replace('Page', '').replace('Page :', '').replace('Page:', '').replace(': ', '').str.strip()
# qa6['Page'] = qa6['Page'].str.replace('Page', '').replace('Page :', '').replace('Page:', '').replace(': ', '').str.strip()
# # qa7['Page'] = qa7['Page'].str.replace('Page', '').replace('Page :', '').replace('Page:', '').str.strip()
# # qa8['Page'] = qa8['Page'].str.replace('Page', '').replace('Page :', '').replace('Page:', '').str.strip()
# # qa9['Page'] = qa9['Page'].str.replace('Page', '').replace('Page :', '').replace('Page:', '').str.strip()
# qa10['Page'] = qa10['Page'].str.replace('Page', '').replace('Page : ', '').replace('Page:', '').replace(': ', '').str.strip()

# %%
# transform page to int
qas = [qa5, qa7]
for qa in qas:
    for i in range(len(qa)):
        try:
            if qa['Page'][i] == 10000:
                qa['Page'][i] = 0
            qa['Page'][i] = int(qa['Page'][i])
        except ValueError:
            qa['Page'][i] = 10000
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3696\4067923874.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   qa['Page'][i] = int(qa['Page'][i])
# C:\Users\User\AppData\Local\Temp\ipykernel_3696\4067923874.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   qa['Page'][i] = 0

# %%
qa1.head()
# Out:
#                                             Question  \
# 0        เอกสารฉบับนี้จัดทำขึ้นเพื่อวัตถุประสงค์อะไร
# 1   ข้อบกพร่องของชิ้นส่วนอุโมงค์ที่สามารถซ่อมแซมไ...
# 2   เกณฑ์ความเสียหายจากการผลิตที่ยอมรับได้ โดยไม่...
# 3   เกณฑ์ความเสียหายจากการขนส่งและการขนย้ายที่ยอม...
# 4   ความเสียหายที่เกิดขึ้นกับชิ้นงานแบ่งออกเป็น 4...
#
#                                               Answer  Page
# 0   เอกสารฉบับนี้จัดทำขึ้นเพื่อเป็นแนวทาง (Guidel...     2
# 1   ความเสียหายหรือข้อบกพร่องต้องไม่มีผลกระทบต่อโ...     2
# 2   ความเสียหายจากการผลิตต้องไม่เกิน 5% ของจำนวน ...     2
# 3   ความเสียหายจากการขนส่งและการขนย้ายต้องไม่เกิน...     2
# 4   ความเสียหายแบ่งเป็น:1. รอยร้าว (Crack)2. แตกบ...     2

# %%
qa2.head()
# Out:
#                                             Question  \
# 0   วิธีการ Repair With Cementitious Mortar ใช้ใน...
# 1   วิธีการ Repair With Cementitious Mortar ใช้ซ่...
# 2          การวัดความกว้างของรอยร้าวต้องใช้อุปกรณ์ใด
# 3   ผงซีเมนต์ที่ใช้ในการซ่อมแซมต้องมีคุณสมบัติอย่...
# 4        อุปกรณ์ข้อที่ 1.1 ที่ใช้ในการซ่อมแซมคืออะไร
#
#                                               Answer  Page
# 0   ใช้ซ่อมแซมรอยร้าวทั่วไปที่มีความกว้างมากกว่า ...    10
# 1   รอยร้าวแบบ Shrinkage Crack ที่มีความกว้าง 0.3...    10
# 2                         แผ่น Crack Width Indicator    10
# 3   มีคุณสมบัติในการต้านทานการสึกหรอ สามารถยึดเกา...    10
# 4                                      เครื่องเป่าลม    11

# %%
qa3.head()
# Out:
#                                             Question  \
# 0   เอกสารวิธีการ Repair With Epoxy Resin (RP-TN-...
# 1   คุณสมบัติของวัสดุอีพ็อกซี่เรซิ่นที่ใช้ในการซ่...
# 2   อุปกรณ์ที่ใช้ในการวัดความกว้างของรอยร้าวเรียก...
# 3   โครงการที่ระบุในเอกสารวิธีการซ่อมแซมนี้คือโคร...
# 4   อุปกรณ์ที่ใช้ในการซ่อมแซมตามเอกสาร RP-TN-02 ม...
#
#                                               Answer  Page
# 0   ใช้ซ่อมแซมรอยร้าวทั่วไปที่มีความกว้างตั้งแต่ ...    16
# 1   คุณสมบัติของวัสดุอีพ็อกซี่เรซิ่นมีดังนี้:1. เ...    16
# 2                              Crack Width Indicator    16
# 3   PROJECT: SEWERAGE TUNNEL BUNG NONG BON TO CHA...    16
# 4   อุปกรณ์ที่ใช้ในการซ่อมแซมประกอบด้วย:1. เครื่อ...    17

# %%
# for i in range(len(qa3)):
#     if qa3['Page'][i].startswith(':'):
#         qa3['Page'][i] = int(qa3['Page'][i][2:])

# %%
qa4.head()
# Out:
#                                             Question  \
# 0       เอกสาร RP-TN-03 มีชื่อหัวข้อเรื่องว่าอย่างไร
# 1       เอกสารนี้ใช้สำหรับโครงการก่อสร้างชื่อว่าอะไร
# 2   การซ่อมแซมชิ้นงานที่แตกบิ่น ต้องอ้างอิงเกณฑ์ข...
# 3   มอร์ต้าร์ที่ใช้ในการซ่อมแซมจะต้องมีกำลังอัดขั...
# 4   นอกจากกำลังอัดแล้ว วัสดุซ่อมแซมต้องมีคุณสมบัต...
#
#                                               Answer  Page
# 0   Spalling Edge Repair (การซ่อมแซมขอบชิ้นงานที่...    24
# 1   Sewerage Tunnel Bung Nong Bon to Chaophraya R...    24
# 2                    TB-RP-01 (Guideline For Repair)    25
# 3                                    สูงกว่า 400 ksc    25
# 4                                 ต้องมีการหดตัวน้อย    25

# %%
qa5
# Out:
#                                              Question  \
# 0    อัตราส่วนผสมน้ำ (Mixing water) สำหรับ Rendero...
# 1    ความหนา (Thickness) และพื้นที่การใช้งาน (Cove...
# 2    ขั้นตอนการเตรียมพื้นผิว (Surface Preparation)...
# 3    อัตราส่วนผสมน้ำต่อปูน Bee Brand No. 124 (20 ก...
# 4    ข้อจำกัดความหนาในการฉาบปูน Bee Brand No. 124 ...
# 5    ข้อห้ามในการใช้งานปูน Bee Brand No. 124 หลังจ...
# 6    กำลังอัด (Compressive Strength) ที่อายุ 28 วั...
# 7    ส่วนประกอบหลักของ Bee Brand High Strength Rep...
# 8    ขั้นตอนการเตรียมพื้นผิวสำหรับการซ่อมแซมด้วย B...
# 9    ข้อกำหนดการบ่ม (Curing) สำหรับ Bee Brand High...
# 10   ความหนาในการใช้งาน (Application Thickness) สำ...
# 11   อัตราส่วนผสม (Mix Ratio) ของ Bee Brand No. 13...
# 12   ค่ากำลังอัด (Compressive strength) ของ Bee Br...
# 13   อัตราส่วนผสมน้ำสำหรับ Sika Skim Coat สีเทา แล...
# 14   ระยะเวลาการทำงาน (Pot Life) ของ Sika Skim Coa...
# 15   ความหนาในการฉาบ Sika Skim Coat ต่อการใช้งานคื...
# 16   Sikadur-31 CF Normal เหมาะสำหรับการใช้งานประเ...
# 17   อัตราส่วนผสม (Mixing Ratio) ของ Sikadur-31 CF...
# 18   ความหนาสูงสุด (Max Layer Thickness) ในการใช้ง...
# 19   การเตรียมพื้นผิวเหล็ก (Steel Substrate Prepar...
# 20   ระยะเวลา Potlife ของ Sikadur-31 CF Normal (ขน...
# 21   Sikadur-41 CF Normal ประกอบด้วยส่วนผสมกี่ส่วน...
# 22   ช่วงอุณหภูมิที่เหมาะสมในการใช้งาน Sikadur-41 ...
# 23   ค่าแรงยึดเกาะ (Bond Strength) ของ Sikadur-32T...
# 24   ระยะเวลา Open Time ของ Sikadur-32TH ที่อุณหภู...
# 25   ความกว้างสูงสุดของรอยแตกร้าวที่เหมาะสมสำหรับก...
# 26   อายุต่ำสุดของคอนกรีตใหม่ที่จะสามารถใช้ผลิตภัณ...
# 27   อัตราส่วนผสม (Mixing Ratio) ของ Sikadur-52TH ...
# 28   การเตรียมพื้นผิวก่อนลง Conpatch 300 ต้องทำอย่...
# 29   การใช้งาน Conpatch 300 ในแต่ละชั้นควรมีความหน...
# 30                     Condur SC ใช้สำหรับงานประเภทใด
# 31   อัตราส่วนผสม (Mix Ratio) ของ Condur SC โดยน้ำ...
# 32   ข้อจำกัดเรื่องความกว้างของรอยร้าว (Crack Widt...
# 33   ขั้นตอนการอัดฉีด Condur SC สำหรับรอยร้าวแนวดิ...
# 34   ค่า Tensile Strength และ Flexural Strength ขอ...
# 35   ระยะเวลาการบ่มตัวของ Condur SC ก่อนที่จะทำการ...
# 36           ระยะเวลา Potlife ของ Condur SC คือเท่าใด
# 37   การ Overcoating สำหรับ Renderoc Skimcoat สามา...
# 38      Renderoc Skimcoat (Finish Coat) ควรใช้เมื่อใด
# 39   หากอุณหภูมิแวดล้อมสูงกว่า 35°C ควรทำอย่างไรเม...
#
#                                                Answer Page
# 0    อัตราส่วนผสมน้ำสำหรับ Renderoc Skimcoat มีดัง...  100
# 1    สำหรับ Renderoc Skimcoat Base Coat:- ความหนา:...  100
# 2    ขั้นตอนการเตรียมพื้นผิวมีดังนี้:1. ทำความสะอา...  102
# 3    อัตราส่วนผสมคือ น้ำ 7.5-8.5 ลิตร ต่อปูน 1 ถุง...  102
# 4    ควรฉาบหรือรีดที่ความหนา 1-2 มม. หากต้องการควา...  102
# 5    ข้อห้ามในการใช้งานมีดังนี้:1. ควรใช้ให้หมดภาย...  102
# 6    กำลังอัดที่อายุ 28 วัน ของ Bee Brand No. 124 ...  109
# 7    ประกอบด้วย ปูนซีเมนต์ปอร์ตแลนด์, ทรายคัดขนาด ...  115
# 8    ขั้นตอนการเตรียมพื้นผิวมีดังนี้:1. สกัดผิวหน้...    0
# 9    ควรบ่มอย่างน้อย 1-3 วัน โดยเมื่อคอนกรีตเริ่มแ...    0
# 10  - แนวดิ่ง (Vert.): 4 - 30/40 มม.- เหนือศีรษะ (...  115
# 11   อัตราส่วนผสมน้ำ : ผงปูน คือ 17 - 19 % โดยน้ำหนัก  114
# 12  - 1 วัน: 25 MPa (3,500 psi)- 28 วัน: 60 MPa (7...  115
# 13  - สำหรับสีเทา: ใช้น้ำ 7.0 - 7.4 ลิตร (35% - 37...   46
# 14                    ประมาณ 45 นาที ที่อุณหภูมิ 30°C   46
# 15   ความหนาในการฉาบประมาณ 0.5 - 2.0 มม. โดยอาจฉาบ...   46
# 16   เหมาะสำหรับใช้เป็นกาวติดโครงสร้าง (Structural...   47
# 17   ส่วนผสม A : ส่วนผสม B = 2 : 1 โดยน้ำหนักหรือป...   50
# 18   ความหนาสูงสุด 30 มม. (สำหรับการใช้งานบนพื้นผิ...   48
# 19   พื้นผิวเหล็กต้องได้รับการทำความสะอาดและเตรียม...   50
# 20                                     ประมาณ 35 นาที   51
# 21   เป็นมอร์ตาร์ชนิด 3 ส่วนผสม (3-part) อัตราส่วน...    0
# 22                            ระหว่าง +10°C ถึง +30°C   52
# 23  - ต่อคอนกรีต: 2.5 - 3 N/mm² (Concrete failure)...   59
# 24             - ที่ 30°C: 60 นาที- ที่ 40°C: 40 นาที   59
# 25              ความกว้างสูงสุดของรอยแตกร้าวคือ 5 มม.   60
# 26                                      3 - 6 สัปดาห์   60
# 27           ส่วนผสม A : ส่วนผสม B = 2 : 1 โดยน้ำหนัก   61
# 28   ต้องพรมน้ำให้ทั่วพื้นผิวคอนกรีตที่จะซ่อมแซมจน...   62
# 29   ควรทำงานเป็นชั้นบางๆ โดยมีความหนาน้อยกว่า 2 ม...   62
# 30   ใช้สำหรับอัดฉีด (Inject) เข้าไปในรอยแตกร้าวแล...   70
# 31  - โดยน้ำหนัก A : B = 4 : 1- โดยปริมาตร A : B =...   69
# 32   ความกว้างรอยร้าวต่ำสุดประมาณ 0.5 มม. และความก...   72
# 33   เริ่มปั๊มอีพ็อกซี่เข้าสู่จุดติดตั้ง (Entry po...   72
# 34  - Tensile Strength: > 25 N/mm²- Flexural Stren...   70
# 35       หลังจาก Condur SC แข็งตัวเป็นเวลา 24 ชั่วโมง   72
# 36                                       50 - 70 นาที   70
# 37   สามารถทำได้หลังจากประมาณ 48 ชั่วโมง ขึ้นอยู่ก...   99
# 38   ควรใช้เมื่อต้องการพื้นผิวที่เรียบเนียนมาก (Ve...   99
# 39   ควรเก็บวัสดุไว้ในที่ร่ม (Shade) และใช้น้ำเย็น...   99

# %%
qa6.head()
# Out:
#                                             Question  \
# 0   เอกสารรหัส RP-TN-05 กล่าวถึงขั้นตอนการซ่อมแซม...
# 1   โครงการที่ระบุในเอกสารสำหรับการซ่อมแซมนี้คือโ...
# 2   การซ่อมแซมด้วยวิธี RP-TN-05 ใช้สำหรับรูฟองอาก...
# 3   คุณสมบัติของวัสดุฉาบซ่อมที่ต้องใช้ในการซ่อมแซ...
# 4   ในรูปที่ 1 ตัวอย่างรูฟองอากาศที่มีขนาดมากกว่า...
#
#                                               Answer  Page
# 0   การซ่อมแซมรูฟองอากาศ (Voids and Blowholes Rep...    38
# 1   SEWERAGE TUNNEL BUNG NONG BON TO CHAOPHRAYA R...    38
# 2   รูฟองอากาศที่มีขนาดความกว้างและความลึกมากกว่า...    39
# 3   ต้องมีกำลังอัดและการยึดเกาะสูงกว่า และมีการขย...    39
# 4                          ลึก 15 mm. และ ยาว 20 mm.    39

# %%
qa7
# Out:
#                                              Question  \
# 0    อัตราส่วนผสมน้ำ (Mixing water) สำหรับ Rendero...
# 1    ความหนา (Thickness) และพื้นที่การใช้งาน (Cove...
# 2    ขั้นตอนการเตรียมพื้นผิว (Surface Preparation)...
# 3    อัตราส่วนผสมน้ำต่อปูน Bee Brand No. 124 (20 ก...
# 4    ข้อจำกัดความหนาในการฉาบปูน Bee Brand No. 124 ...
# 5    ข้อห้ามในการใช้งานปูน Bee Brand No. 124 หลังจ...
# 6    กำลังอัด (Compressive Strength) ที่อายุ 28 วั...
# 7    ส่วนประกอบหลักของ Bee Brand High Strength Rep...
# 8    ขั้นตอนการเตรียมพื้นผิวสำหรับการซ่อมแซมด้วย B...
# 9    ข้อกำหนดการบ่ม (Curing) สำหรับ Bee Brand High...
# 10   ความหนาในการใช้งาน (Application Thickness) สำ...
# 11   อัตราส่วนผสม (Mix Ratio) ของ Bee Brand No. 13...
# 12   ค่ากำลังอัด (Compressive strength) ของ Bee Br...
# 13   อัตราส่วนผสมน้ำสำหรับ Sika Skim Coat สีเทา แล...
# 14   ระยะเวลาการทำงาน (Pot Life) ของ Sika Skim Coa...
# 15   ความหนาในการฉาบ Sika Skim Coat ต่อการใช้งานคื...
# 16   Sikadur-31 CF Normal เหมาะสำหรับการใช้งานประเ...
# 17   อัตราส่วนผสม (Mixing Ratio) ของ Sikadur-31 CF...
# 18   ความหนาสูงสุด (Max Layer Thickness) ในการใช้ง...
# 19   การเตรียมพื้นผิวเหล็ก (Steel Substrate Prepar...
# 20   ระยะเวลา Potlife ของ Sikadur-31 CF Normal (ขน...
# 21   Sikadur-41 CF Normal ประกอบด้วยส่วนผสมกี่ส่วน...
# 22   ช่วงอุณหภูมิที่เหมาะสมในการใช้งาน Sikadur-41 ...
# 23   ค่าแรงยึดเกาะ (Bond Strength) ของ Sikadur-32T...
# 24   ระยะเวลา Open Time ของ Sikadur-32TH ที่อุณหภู...
# 25   ความกว้างสูงสุดของรอยแตกร้าวที่เหมาะสมสำหรับก...
# 26   อายุต่ำสุดของคอนกรีตใหม่ที่จะสามารถใช้ผลิตภัณ...
# 27   อัตราส่วนผสม (Mixing Ratio) ของ Sikadur-52TH ...
# 28   การเตรียมพื้นผิวก่อนลง Conpatch 300 ต้องทำอย่...
# 29   การใช้งาน Conpatch 300 ในแต่ละชั้นควรมีความหน...
# 30                     Condur SC ใช้สำหรับงานประเภทใด
# 31   อัตราส่วนผสม (Mix Ratio) ของ Condur SC โดยน้ำ...
# 32   ข้อจำกัดเรื่องความกว้างของรอยร้าว (Crack Widt...
# 33   ขั้นตอนการอัดฉีด Condur SC สำหรับรอยร้าวแนวดิ...
# 34   ค่า Tensile Strength และ Flexural Strength ขอ...
# 35   ระยะเวลาการบ่มตัวของ Condur SC ก่อนที่จะทำการ...
# 36           ระยะเวลา Potlife ของ Condur SC คือเท่าใด
# 37   การ Overcoating สำหรับ Renderoc Skimcoat สามา...
# 38      Renderoc Skimcoat (Finish Coat) ควรใช้เมื่อใด
# 39   หากอุณหภูมิแวดล้อมสูงกว่า 35°C ควรทำอย่างไรเม...
#
#                                                Answer   Page
# 0    อัตราส่วนผสมน้ำสำหรับ Renderoc Skimcoat มีดัง...    100
# 1    สำหรับ Renderoc Skimcoat Base Coat:- ความหนา:...    100
# 2    ขั้นตอนการเตรียมพื้นผิวมีดังนี้:1. ทำความสะอา...    102
# 3    อัตราส่วนผสมคือ น้ำ 7.5-8.5 ลิตร ต่อปูน 1 ถุง...    102
# 4    ควรฉาบหรือรีดที่ความหนา 1-2 มม. หากต้องการควา...    102
# 5    ข้อห้ามในการใช้งานมีดังนี้:1. ควรใช้ให้หมดภาย...    102
# 6    กำลังอัดที่อายุ 28 วัน ของ Bee Brand No. 124 ...    109
# 7    ประกอบด้วย ปูนซีเมนต์ปอร์ตแลนด์, ทรายคัดขนาด ...    115
# 8    ขั้นตอนการเตรียมพื้นผิวมีดังนี้:1. สกัดผิวหน้...  10000
# 9    ควรบ่มอย่างน้อย 1-3 วัน โดยเมื่อคอนกรีตเริ่มแ...  10000
# 10  - แนวดิ่ง (Vert.): 4 - 30/40 มม.- เหนือศีรษะ (...    115
# 11   อัตราส่วนผสมน้ำ : ผงปูน คือ 17 - 19 % โดยน้ำหนัก    114
# 12  - 1 วัน: 25 MPa (3,500 psi)- 28 วัน: 60 MPa (7...    115
# 13  - สำหรับสีเทา: ใช้น้ำ 7.0 - 7.4 ลิตร (35% - 37...     46
# 14                    ประมาณ 45 นาที ที่อุณหภูมิ 30°C     46
# 15   ความหนาในการฉาบประมาณ 0.5 - 2.0 มม. โดยอาจฉาบ...     46
# 16   เหมาะสำหรับใช้เป็นกาวติดโครงสร้าง (Structural...     47
# 17   ส่วนผสม A : ส่วนผสม B = 2 : 1 โดยน้ำหนักหรือป...     50
# 18   ความหนาสูงสุด 30 มม. (สำหรับการใช้งานบนพื้นผิ...     48
# 19   พื้นผิวเหล็กต้องได้รับการทำความสะอาดและเตรียม...     50
# 20                                     ประมาณ 35 นาที     51
# 21   เป็นมอร์ตาร์ชนิด 3 ส่วนผสม (3-part) อัตราส่วน...  10000
# 22                            ระหว่าง +10°C ถึง +30°C     52
# 23  - ต่อคอนกรีต: 2.5 - 3 N/mm² (Concrete failure)...     59
# 24             - ที่ 30°C: 60 นาที- ที่ 40°C: 40 นาที     59
# 25              ความกว้างสูงสุดของรอยแตกร้าวคือ 5 มม.     60
# 26                                      3 - 6 สัปดาห์     60
# 27           ส่วนผสม A : ส่วนผสม B = 2 : 1 โดยน้ำหนัก     61
# 28   ต้องพรมน้ำให้ทั่วพื้นผิวคอนกรีตที่จะซ่อมแซมจน...     62
# 29   ควรทำงานเป็นชั้นบางๆ โดยมีความหนาน้อยกว่า 2 ม...     62
# 30   ใช้สำหรับอัดฉีด (Inject) เข้าไปในรอยแตกร้าวแล...     70
# 31  - โดยน้ำหนัก A : B = 4 : 1- โดยปริมาตร A : B =...     69
# 32   ความกว้างรอยร้าวต่ำสุดประมาณ 0.5 มม. และความก...     72
# 33   เริ่มปั๊มอีพ็อกซี่เข้าสู่จุดติดตั้ง (Entry po...     72
# 34  - Tensile Strength: > 25 N/mm²- Flexural Stren...     70
# 35       หลังจาก Condur SC แข็งตัวเป็นเวลา 24 ชั่วโมง     72
# 36                                       50 - 70 นาที     70
# 37   สามารถทำได้หลังจากประมาณ 48 ชั่วโมง ขึ้นอยู่ก...     99
# 38   ควรใช้เมื่อต้องการพื้นผิวที่เรียบเนียนมาก (Ve...     99
# 39   ควรเก็บวัสดุไว้ในที่ร่ม (Shade) และใช้น้ำเย็น...     99

# %%
qa9.head()
# Out:
#                                             Question  \
# 0   การปฐมพยาบาลเบื้องต้นเมื่อดวงตาสัมผัสกับ Sika...
# 1   หากกลืน Sika Skim Coat เข้าไปและผู้ป่วยมีสติ ...
# 2   อันตรายจากการสูดดม Sika Skim Coat มีผลกระทบอย...
# 3   อันตรายต่อผิวหนังจาก Sikadur 32 TH (PART A) ม...
# 4   การปฐมพยาบาลเมื่อกลืน Sikadur 32 TH (PART A) ...
#
#                                               Answer  Page
# 0   ถอดคอนแทคเลนส์ ใช้น้ำสะอาดล้างดวงตาอย่างต่อเน...   125
# 1   ให้บ้วนปาก แล้วดื่มน้ำเพียงเล็กน้อย ห้ามทำให้...   125
# 2   อาจทำให้เกิดการระคายเคืองอย่างมากต่อระบบทางเด...   125
# 3              ทำให้ผิวหนังเกิดการระคายเคืองอย่างมาก   125
# 4   บ้วนปากแล้วดื่มน้ำสะอาด พยายามทำให้ผู้ป่วยอาเ...   125

# %%
qa10.head()
# Out:
#                                             Question  \
# 0   เอกสาร EV-TN-01 เป็นเอกสารเกี่ยวกับเรื่องอะไร...
# 1   มาตรการป้องกันผลกระทบต่อสิ่งแวดล้อมของงานซ่อม...
# 2     วัสดุซ่อมแบบผงที่ระบุในเอกสารมีรายชื่ออะไรบ้าง
# 3   หากวัสดุซ่อมแบบผงปนเปื้อนในท่อระบายน้ำเสีย มี...
# 4   มาตรการป้องกันเพื่อไม่ให้วัสดุซ่อมแบบผงปนเปื้...
#
#                                               Answer  Page
# 0   เอกสารฉบับนี้เกี่ยวกับมาตรการป้องกันผลกระทบต่...   135
# 1   แบ่งออกเป็น 2 หมวด ได้แก่1. มาตรการป้องกันผลก...   135
# 2   รายชื่อวัสดุซ่อมแบบผง ได้แก่:1. Sika Skim Coa...   135
# 3   วิธีการแก้ไขคือ ให้ปิดทางระบายท่อน้ำทิ้ง แล้ว...   135
# 4   มาตรการป้องกันมีดังนี้:1. แบ่งพื้นที่สำหรับงา...   135

# %%
qa = [qa1, qa2, qa3, qa4, qa6, qa8, qa9, qa10]
qa_str = ['qa1', 'qa2', 'qa3', 'qa4', 'qa6', 'qa8', 'qa9', 'qa10']
for i, qa in enumerate(qa):
    print(qa_str[i])
    plot_numeric_distributions(qa, cols=['Page'], bins=20, ncols=1, kde=False, show_stats=True)
# Out:
# qa1
# qa2
# qa3
# qa4
# qa6
# qa8
# qa9
# qa10
